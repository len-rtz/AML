# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# # 8th exercise: <font color="#C70039">Work with a regular Generative Adversarial Network (GAN)</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: Lena Pickartz
# * Date:   24.11.2024
#
# <img src="https://www.researchgate.net/publication/338509383/figure/fig1/AS:845792709464064@1578664104008/Overview-of-generative-adversarial-network-GAN.ppm" style="float: center;" width="600">
#
# ---------------------------------
# **GENERAL NOTE 1**:
# Please make sure you are reading the entire notebook, since it contains a lot of information on your tasks (e.g. regarding the set of certain paramaters or a specific computational trick), and the written mark downs as well as comments contain a lot of information on how things work together as a whole.
#
# **GENERAL NOTE 2**:
# * Please, when commenting source code, just use English language only.
# * When describing an observation please use English language, too.
# * This applies to all exercises throughout this course.
#
# ---------------------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# The code implements a regular GAN that generates images using a random latent vector as input. While it works great we do not know the mapping of latent vector to the generated image.
#
# Conditional GANs, however, can be used to supply a label during taining so the latent vector can be associated with a specific label - making the generation of images predictable.
#
# The below coded GAN is using the so-called cifar10 data set, which is standard to many machine learning applications (60,000 32x32 color images in 10 different classes: CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck).
# Following the code trains and generates images based on that cifar10 data set, that is included in the Keras package.
# Further information on the data set can be found here: <a href="https://en.wikipedia.org/wiki/CIFAR-10"> cifar10 data set (wiki)</a>
#
# The code is adapted from the code by Jason Brownlee from his blogs on <a href="https://machinelearningmastery.com/">https://machinelearningmastery.com/</a>.
# I seriously urge everyone to follow his blogs and get inspired. Hence, original credit goes to Jason Brownlee.
#
# ---------------------------------
#
# ### <font color="FFC300">TASKS</font>:
# The tasks that you need to work on within this notebook are always indicated below as bullet points.
# If a task is more challenging and consists of several steps, this is indicated as well.
# Make sure you have worked down the task list and commented your doings.
# This should be done by using markdown.<br>
# <font color=red>Make sure you don't forget to specify your name and your matriculation number in the notebook.</font>
#
# **YOUR TASKS in this exercise are as follows**:
# 1. import the notebook to Google Colab or use your local machine.
# 2. make sure you specified you name and your matriculation number in the header below my name and date.
#     * set the date too and remove mine.
# 3. read the entire notebook carefully
#     * add comments whereever you feel it necessary for better understanding
#     * run the notebook for the first time.
# 4. train the GAN with a higher dimension of the latent space and over more epochs. Are the results improving?
# 5. What could be done to further improve the quality of the generated images?
# ---------------------------------

# %% [markdown]
# ### GAN
# #### Imports

# %%
import numpy as np
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras.datasets.cifar10 import load_data

# this import is needed because there is a problem with the Secure Socket Layer (SSL) certificate,
# It can be resolved using the below line of code
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ### Build the GAN architeture
#
# Use the "functional" way of defining the model for the conditional gan but use "sequential" for descriminator and generator as they are straight forward.

# %% [markdown]
# #### Define the standalone discriminator model
#
# Given an input image, the Discriminator outputs the likelihood of the image being real.
# Binary classification - true or false (1 or 0). So use the sigmoid activation.

# %%
def define_discriminator(in_shape=(32,32,3)):
    model = Sequential(name="discriminator")

    model.add(Conv2D(128, (3,3), strides=(2,2), padding='same', input_shape=in_shape)) #16x16x128
    model.add(LeakyReLU(alpha=0.2))

    model.add(Conv2D(128, (3,3), strides=(2,2), padding='same')) #8x8x128
    model.add(LeakyReLU(alpha=0.2))

    model.add(Flatten()) #shape of 8192
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid')) #shape of 1

    # Compile model since it is going to be trained directly and choose the optimizer
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    return model

test_discriminator = define_discriminator()
print(test_discriminator.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 16, 16, 128)         │           3,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │           8,193 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 159,361 (622.50 KB)
#  Trainable params: 159,361 (622.50 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# #### Define the standalone generator model
# Given the latent vector input, the Generator produces an image.(here: 32x32)
# The latent_dim, for example, can be 100, 1D array of size 100.
#
# Only Dense and conv2dlayers are being used. But the network can be more complicated based on the problem you are trying to solve. For example, you can use VGG as the basis for a super resolution GAN.

# %%
#latent_dim is the dimension of the latent vector (e.g., 100 - see below)
def define_generator(latent_dim):

    model = Sequential(name="generator")

    # Reshape the input latent vector into an 8x8 image as a starting point.
    # Hence n_nodes for the Dense layer are e.g. 128x8x8, so when reshaping the output
    # it would be 8x8x128 and that can be slowly upscaled to a 32x32 image as the output.
    n_nodes = 128 * 8 * 8  #8192 nodes
    model.add(Dense(n_nodes, input_dim=latent_dim)) #Dense layer so we can work with a 1D latent vector
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((8, 8, 128)))  #8x8x128 data set from the latent vector.
    # upsample to 16x16
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')) #16x16x128
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 32x32
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')) #32x32x128
    model.add(LeakyReLU(alpha=0.2))
    # generate
    model.add(Conv2D(3, (8,8), activation='tanh', padding='same')) #32x32x3
    return model  # the generator model not compiled as it is not directly trained as the discriminator.
                  # the generator is being trained via a GAN combined model (see below)

test_generator = define_generator(latent_dim=100)
print(test_generator.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 8192)                │         827,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 16, 16, 128)         │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_1 (Conv2DTranspose) │ (None, 32, 32, 128)         │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)            │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 3)           │          24,579 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,376,515 (5.25 MB)
#  Trainable params: 1,376,515 (5.25 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# Now, define the combined generator and discriminator model, for updating the generator.
# The discriminator is trained separately so here only the generator will be trained by keeping the discriminator constant.

# %%
def define_gan(generator, discriminator):
    # The discriminator is trained separately (see above). Hence, set it to not trainable.
    discriminator.trainable = False

    # Now, connect the generator and the discriminator
    model = Sequential()
    model.add(generator)
    model.add(discriminator)

    # Compile the combined model and Choose an optimizer
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt)

    return model

# %% [markdown]
# ### Load data
# Load the data set and plot parts of it in order to get a quick understanding.
#
# CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck

# %%
(trainX, trainy), (testX, testy) = load_data()

# plot 25=5x5 example images
for i in range(25):
    plt.subplot(5, 5, 1 + i)
    plt.axis('off')
    plt.imshow(trainX[i])
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
# Load the cifar images and build a training data set
def load_real_samples():
    (trainX, _), (_, _) = load_data()
    # convert to float and scale.
    X = trainX.astype('float32')
    # the generator uses tanh as activation function (see above),
    # so we need to rescale from [0,255] to [-1,1]
    # original images to -1 to 1 to match the output of generator.
    X = (X - 127.5) / 127.5

    return X

# %%
# Pick a batch of random real samples to train the GAN
# In fact, train the GAN on a half batch of real images and another half batch of fake images.
# For each real image assign the label=1 and for fake assign the label=0.
def generate_real_samples(dataset, n_samples):
    # choose random images
    ix = randint(0, dataset.shape[0], n_samples)
    # select the random images and assign it to X
    x = dataset[ix]
    # generate class labels and assign to y
    y = ones((n_samples, 1)) # label=1 indicates that the image is a real one
    return x, y

# %%
# Generate n_samples number of latent vectors as input for the generator
def generate_latent_points(latent_dim, n_samples):
    # generate points in the latent space
    x_input = randn(latent_dim * n_samples)
    # reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input

# %%
# Use the generator to generate n fake examples, with class labels
# Supply the generator, latent_dim and number of samples as input.
# Use the above latent point generator to generate latent points.
def generate_fake_samples(generator, latent_dim, n_samples):
    # generate points in latent space
    x_input = generate_latent_points(latent_dim, n_samples)
    # predict using generator to generate fake samples.
    x = generator.predict(x_input)
    # Class labels will be 0 as these samples are fake.
    y = zeros((n_samples, 1))  # label=0 indicates that the image is a fake one
    return x, y

# %% [markdown]
# ### Training function for the generator and discriminator
# Loop through a number of epochs to train the discriminator by first selecting a random batch of images from the true/real data set. Then, generate a set of images using the generator. Feed both sets of images into the discriminator. Finally, set the loss parameters for both the real and fake images, as well as the combined loss.

# %%
def train(g_model, d_model, gan_model, filename, dataset, latent_dim, n_epochs=100, n_batch=128):
    bat_per_epo = int(dataset.shape[0] / n_batch)
    half_batch = int(n_batch / 2)  #the discriminator model is updated for a half batch of real samples
                            #and a half batch of fake samples, combined a single batch.
    # manually enumerate epochs and bacthes.
    for i in range(n_epochs):
        # enumerate batches over the training set
        for j in range(bat_per_epo):

            # Train the discriminator on real and fake images, separately (half batch each)
            #Research showed that separate training is more effective.
            # get randomly selected 'real' samples
            X_real, y_real = generate_real_samples(dataset, half_batch)
            # update discriminator model weights
            ##train_on_batch allows you to update weights based on a collection
            #of samples you provide
            #Let us just capture loss and ignore accuracy value (2nd output below)
            d_loss_real, _ = d_model.train_on_batch(X_real, y_real)

            # generate 'fake' examples
            X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
            # update discriminator model weights
            d_loss_fake, _ = d_model.train_on_batch(X_fake, y_fake)

            #d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) #Average loss if you want to report single..

            # prepare points in latent space as input for the generator
            X_gan = generate_latent_points(latent_dim, n_batch)

            # The generator wants the discriminator to label the generated samples as valid ones.
            # This is where the generator is trying to trick discriminator into believing that
            # the generated image is true (hence value of 1 for y)
            y_gan = ones((n_batch, 1))

            # The generator is part of the combined model where it got directly linked with the discriminator
            # Train the generator with latent_dim as x and 1 as y.
            # Again, 1 as the output as it is adversarial and if the generator did a great
            # job of fooling the discriminator, then the output would be 1 (true).
            # Update the generator via the discriminator's error
            g_loss = gan_model.train_on_batch(X_gan, y_gan)

            # Print losses on this batch
            print('Epoch=',i+1, 'Batch=', j+1, '/',bat_per_epo, 'd1=', d_loss_real, 'd2=', d_loss_fake, 'g=', g_loss)

    # save the generator model
    g_model.save(filename)

# %% [markdown]
# ### Train the GAN

# %%
# size of the latent space
latent_dim = 100
# create the discriminator
discriminator = define_discriminator()
# create the generator
generator = define_generator(latent_dim)
# create the gan
gan_model = define_gan(generator, discriminator)
# load image data
dataset = load_real_samples()
# train model
n_epochs=5 #50
model_filename = "cifar_GAN." + str(n_epochs) + "_epochs.keras"
train(generator, discriminator, gan_model, model_filename, dataset, latent_dim, n_epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Epoch= 1 Batch= 1 / 390 d1= 0.6677575 d2= 0.6808344 g= [array(0.6808344, dtype=float32), array(0.6808344, dtype=float32), array(0.515625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7dd34290e710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7dd3393197e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch= 1 Batch= 2 / 390 d1= 0.6740938 d2= 0.6796268 g= [array(0.6796268, dtype=float32), array(0.6796268, dtype=float32), array(0.48046875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch= 1 Batch= 3 / 390 d1= 0.6763793 d2= 0.6800931 g= [array(0.6800931, dtype=float32), array(0.6800931, dtype=float32), array(0.45833334, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch= 1 Batch= 4 / 390 d1= 0.6778966 d2= 0.6809691 g= [array(0.6809691, dtype=float32), array(0.6809691, dtype=float32), array(0.44140625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch= 1 Batch= 5 / 390 d1= 0.67984617 d2= 0.6826482 g= [array(0.6826482, dtype=float32), array(0.6826482, dtype=float32), array(0.43125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 6 / 390 d1= 0.6802735 d2= 0.6830573 g= [array(0.6830573, dtype=float32), array(0.6830573, dtype=float32), array(0.42708334, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 7 / 390 d1= 0.6812285 d2= 0.68418044 g= [array(0.68418044, dtype=float32), array(0.68418044, dtype=float32), array(0.42857143, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 8 / 390 d1= 0.6821899 d2= 0.6851093 g= [array(0.6851093, dtype=float32), array(0.6851093, dtype=float32), array(0.42871094, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 9 / 390 d1= 0.68374807 d2= 0.68711674 g= [array(0.68711674, dtype=float32), array(0.68711674, dtype=float32), array(0.4253472, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 10 / 390 d1= 0.686131 d2= 0.68974745 g= [array(0.68974745, dtype=float32), array(0.68974745, dtype=float32), array(0.41796875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 11 / 390 d1= 0.6879234 d2= 0.69201547 g= [array(0.69201547, dtype=float32), array(0.69201547, dtype=float32), array(0.42045453, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 12 / 390 d1= 0.6910584 d2= 0.69556695 g= [array(0.69556695, dtype=float32), array(0.69556695, dtype=float32), array(0.4153646, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 13 / 390 d1= 0.694489 d2= 0.6995872 g= [array(0.6995872, dtype=float32), array(0.6995872, dtype=float32), array(0.4140625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 14 / 390 d1= 0.69801176 d2= 0.7034809 g= [array(0.7034809, dtype=float32), array(0.7034809, dtype=float32), array(0.41462055, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 15 / 390 d1= 0.702107 d2= 0.7078622 g= [array(0.7078622, dtype=float32), array(0.7078622, dtype=float32), array(0.4140625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 16 / 390 d1= 0.7066702 d2= 0.71338534 g= [array(0.71338534, dtype=float32), array(0.71338534, dtype=float32), array(0.41259766, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 17 / 390 d1= 0.7115987 d2= 0.71831864 g= [array(0.71831864, dtype=float32), array(0.71831864, dtype=float32), array(0.4140625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 18 / 390 d1= 0.716626 d2= 0.7233329 g= [array(0.7233329, dtype=float32), array(0.7233329, dtype=float32), array(0.41493055, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 19 / 390 d1= 0.7217334 d2= 0.7289514 g= [array(0.7289514, dtype=float32), array(0.7289514, dtype=float32), array(0.41282895, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 20 / 390 d1= 0.7271057 d2= 0.7341542 g= [array(0.7341542, dtype=float32), array(0.7341542, dtype=float32), array(0.41328126, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 21 / 390 d1= 0.7324059 d2= 0.7399043 g= [array(0.7399043, dtype=float32), array(0.7399043, dtype=float32), array(0.4125744, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 22 / 390 d1= 0.7382718 d2= 0.7456026 g= [array(0.7456026, dtype=float32), array(0.7456026, dtype=float32), array(0.41086647, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 23 / 390 d1= 0.7437481 d2= 0.751069 g= [array(0.751069, dtype=float32), array(0.751069, dtype=float32), array(0.4103261, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 24 / 390 d1= 0.7493479 d2= 0.7566669 g= [array(0.7566669, dtype=float32), array(0.7566669, dtype=float32), array(0.41015625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 25 / 390 d1= 0.75485337 d2= 0.762513 g= [array(0.762513, dtype=float32), array(0.762513, dtype=float32), array(0.4084375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 26 / 390 d1= 0.7606572 d2= 0.76783955 g= [array(0.76783955, dtype=float32), array(0.76783955, dtype=float32), array(0.40865386, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 27 / 390 d1= 0.7660537 d2= 0.7735032 g= [array(0.7735032, dtype=float32), array(0.7735032, dtype=float32), array(0.4074074, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 28 / 390 d1= 0.77148145 d2= 0.77876806 g= [array(0.77876806, dtype=float32), array(0.77876806, dtype=float32), array(0.40736607, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 29 / 390 d1= 0.77680844 d2= 0.78440875 g= [array(0.78440875, dtype=float32), array(0.78440875, dtype=float32), array(0.40759698, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 30 / 390 d1= 0.7822564 d2= 0.7898341 g= [array(0.7898341, dtype=float32), array(0.7898341, dtype=float32), array(0.40859374, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 31 / 390 d1= 0.7877966 d2= 0.7947868 g= [array(0.7947868, dtype=float32), array(0.7947868, dtype=float32), array(0.405998, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 32 / 390 d1= 0.79272157 d2= 0.8000249 g= [array(0.8000249, dtype=float32), array(0.8000249, dtype=float32), array(0.40527344, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 33 / 390 d1= 0.79786927 d2= 0.80491143 g= [array(0.80491143, dtype=float32), array(0.80491143, dtype=float32), array(0.40530303, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 34 / 390 d1= 0.8028238 d2= 0.81003904 g= [array(0.81003904, dtype=float32), array(0.81003904, dtype=float32), array(0.4048713, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 35 / 390 d1= 0.8080695 d2= 0.8151655 g= [array(0.8151655, dtype=float32), array(0.8151655, dtype=float32), array(0.4033482, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 36 / 390 d1= 0.8130106 d2= 0.8197658 g= [array(0.8197658, dtype=float32), array(0.8197658, dtype=float32), array(0.40364584, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 37 / 390 d1= 0.8176454 d2= 0.824553 g= [array(0.824553, dtype=float32), array(0.824553, dtype=float32), array(0.40266046, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 38 / 390 d1= 0.82238424 d2= 0.8291304 g= [array(0.8291304, dtype=float32), array(0.8291304, dtype=float32), array(0.40316612, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 39 / 390 d1= 0.8270553 d2= 0.83359146 g= [array(0.83359146, dtype=float32), array(0.83359146, dtype=float32), array(0.40264422, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 40 / 390 d1= 0.83147615 d2= 0.8378223 g= [array(0.8378223, dtype=float32), array(0.8378223, dtype=float32), array(0.40273437, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 41 / 390 d1= 0.83570087 d2= 0.8424129 g= [array(0.8424129, dtype=float32), array(0.8424129, dtype=float32), array(0.40262958, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 42 / 390 d1= 0.840289 d2= 0.84671074 g= [array(0.84671074, dtype=float32), array(0.84671074, dtype=float32), array(0.40234375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 43 / 390 d1= 0.8444645 d2= 0.8506702 g= [array(0.8506702, dtype=float32), array(0.8506702, dtype=float32), array(0.40334302, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 44 / 390 d1= 0.84851694 d2= 0.85484505 g= [array(0.85484505, dtype=float32), array(0.85484505, dtype=float32), array(0.40269887, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 45 / 390 d1= 0.8527501 d2= 0.85888994 g= [array(0.85888994, dtype=float32), array(0.85888994, dtype=float32), array(0.40260416, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 46 / 390 d1= 0.8567321 d2= 0.8629011 g= [array(0.8629011, dtype=float32), array(0.8629011, dtype=float32), array(0.40234375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 47 / 390 d1= 0.860694 d2= 0.86685073 g= [array(0.86685073, dtype=float32), array(0.86685073, dtype=float32), array(0.40226063, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 48 / 390 d1= 0.8647204 d2= 0.8707531 g= [array(0.8707531, dtype=float32), array(0.8707531, dtype=float32), array(0.4025065, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 49 / 390 d1= 0.86858237 d2= 0.8742408 g= [array(0.8742408, dtype=float32), array(0.8742408, dtype=float32), array(0.40322065, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 50 / 390 d1= 0.8721094 d2= 0.8778946 g= [array(0.8778946, dtype=float32), array(0.8778946, dtype=float32), array(0.40328124, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 51 / 390 d1= 0.8757541 d2= 0.8814548 g= [array(0.8814548, dtype=float32), array(0.8814548, dtype=float32), array(0.40303308, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 52 / 390 d1= 0.8793088 d2= 0.88486224 g= [array(0.88486224, dtype=float32), array(0.88486224, dtype=float32), array(0.40309495, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 53 / 390 d1= 0.88280046 d2= 0.8885852 g= [array(0.8885852, dtype=float32), array(0.8885852, dtype=float32), array(0.40256485, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 54 / 390 d1= 0.88644654 d2= 0.89220834 g= [array(0.89220834, dtype=float32), array(0.89220834, dtype=float32), array(0.40234375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 55 / 390 d1= 0.8901328 d2= 0.89576286 g= [array(0.89576286, dtype=float32), array(0.89576286, dtype=float32), array(0.4021307, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 56 / 390 d1= 0.89374983 d2= 0.89929867 g= [array(0.89929867, dtype=float32), array(0.89929867, dtype=float32), array(0.40122768, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 57 / 390 d1= 0.89716125 d2= 0.9025423 g= [array(0.9025423, dtype=float32), array(0.9025423, dtype=float32), array(0.40172696, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 58 / 390 d1= 0.9004508 d2= 0.9058877 g= [array(0.9058877, dtype=float32), array(0.9058877, dtype=float32), array(0.40153557, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 59 / 390 d1= 0.9038614 d2= 0.90937203 g= [array(0.90937203, dtype=float32), array(0.90937203, dtype=float32), array(0.40082097, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 60 / 390 d1= 0.90726465 d2= 0.9127242 g= [array(0.9127242, dtype=float32), array(0.9127242, dtype=float32), array(0.40117186, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 61 / 390 d1= 0.9106901 d2= 0.91599524 g= [array(0.91599524, dtype=float32), array(0.91599524, dtype=float32), array(0.4008709, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 62 / 390 d1= 0.9139611 d2= 0.9194576 g= [array(0.9194576, dtype=float32), array(0.9194576, dtype=float32), array(0.40070564, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 63 / 390 d1= 0.9173691 d2= 0.9225657 g= [array(0.9225657, dtype=float32), array(0.9225657, dtype=float32), array(0.40104166, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 64 / 390 d1= 0.9205699 d2= 0.9259439 g= [array(0.9259439, dtype=float32), array(0.9259439, dtype=float32), array(0.40124512, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 65 / 390 d1= 0.92396075 d2= 0.92918783 g= [array(0.92918783, dtype=float32), array(0.92918783, dtype=float32), array(0.40060097, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 66 / 390 d1= 0.92714626 d2= 0.93222296 g= [array(0.93222296, dtype=float32), array(0.93222296, dtype=float32), array(0.40092328, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 67 / 390 d1= 0.9302071 d2= 0.9354142 g= [array(0.9354142, dtype=float32), array(0.9354142, dtype=float32), array(0.4010028, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 68 / 390 d1= 0.93338823 d2= 0.9385514 g= [array(0.9385514, dtype=float32), array(0.9385514, dtype=float32), array(0.40130973, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 69 / 390 d1= 0.9365946 d2= 0.9415374 g= [array(0.9415374, dtype=float32), array(0.9415374, dtype=float32), array(0.40104166, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 70 / 390 d1= 0.93957067 d2= 0.94465166 g= [array(0.94465166, dtype=float32), array(0.94465166, dtype=float32), array(0.40100446, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 71 / 390 d1= 0.9426693 d2= 0.94788724 g= [array(0.94788724, dtype=float32), array(0.94788724, dtype=float32), array(0.4009683, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 72 / 390 d1= 0.94593376 d2= 0.9509957 g= [array(0.9509957, dtype=float32), array(0.9509957, dtype=float32), array(0.40060765, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 73 / 390 d1= 0.94896483 d2= 0.95408714 g= [array(0.95408714, dtype=float32), array(0.95408714, dtype=float32), array(0.40122002, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 74 / 390 d1= 0.9520605 d2= 0.9571207 g= [array(0.9571207, dtype=float32), array(0.9571207, dtype=float32), array(0.40107685, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 75 / 390 d1= 0.95505685 d2= 0.96006906 g= [array(0.96006906, dtype=float32), array(0.96006906, dtype=float32), array(0.40208334, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 76 / 390 d1= 0.95810795 d2= 0.96297324 g= [array(0.96297324, dtype=float32), array(0.96297324, dtype=float32), array(0.40172696, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 77 / 390 d1= 0.961023 d2= 0.9660009 g= [array(0.9660009, dtype=float32), array(0.9660009, dtype=float32), array(0.40137988, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 78 / 390 d1= 0.96401995 d2= 0.96885973 g= [array(0.96885973, dtype=float32), array(0.96885973, dtype=float32), array(0.401242, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 79 / 390 d1= 0.96690106 d2= 0.9719148 g= [array(0.9719148, dtype=float32), array(0.9719148, dtype=float32), array(0.40140426, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 80 / 390 d1= 0.96994776 d2= 0.9748243 g= [array(0.9748243, dtype=float32), array(0.9748243, dtype=float32), array(0.4013672, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 81 / 390 d1= 0.9729047 d2= 0.97776765 g= [array(0.97776765, dtype=float32), array(0.97776765, dtype=float32), array(0.40104166, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 82 / 390 d1= 0.97580516 d2= 0.98049366 g= [array(0.98049366, dtype=float32), array(0.98049366, dtype=float32), array(0.40091464, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 83 / 390 d1= 0.97853756 d2= 0.9831258 g= [array(0.9831258, dtype=float32), array(0.9831258, dtype=float32), array(0.40116715, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 84 / 390 d1= 0.9812367 d2= 0.98595077 g= [array(0.98595077, dtype=float32), array(0.98595077, dtype=float32), array(0.40122768, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 85 / 390 d1= 0.98404807 d2= 0.9888005 g= [array(0.9888005, dtype=float32), array(0.9888005, dtype=float32), array(0.40128675, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 86 / 390 d1= 0.9869405 d2= 0.9915361 g= [array(0.9915361, dtype=float32), array(0.9915361, dtype=float32), array(0.4007086, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 87 / 390 d1= 0.98961276 d2= 0.99434835 g= [array(0.99434835, dtype=float32), array(0.99434835, dtype=float32), array(0.40095186, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 88 / 390 d1= 0.9924511 d2= 0.9969317 g= [array(0.9969317, dtype=float32), array(0.9969317, dtype=float32), array(0.40065697, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 89 / 390 d1= 0.99503195 d2= 0.99965125 g= [array(0.99965125, dtype=float32), array(0.99965125, dtype=float32), array(0.40063202, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 90 / 390 d1= 0.997789 d2= 1.0022699 g= [array(1.0022699, dtype=float32), array(1.0022699, dtype=float32), array(0.4001736, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 91 / 390 d1= 1.0003952 d2= 1.0050188 g= [array(1.0050188, dtype=float32), array(1.0050188, dtype=float32), array(0.40041208, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 92 / 390 d1= 1.0031369 d2= 1.0077512 g= [array(1.0077512, dtype=float32), array(1.0077512, dtype=float32), array(0.40047553, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 93 / 390 d1= 1.0059139 d2= 1.010366 g= [array(1.010366, dtype=float32), array(1.010366, dtype=float32), array(0.40053764, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 94 / 390 d1= 1.008501 d2= 1.0130677 g= [array(1.0130677, dtype=float32), array(1.0130677, dtype=float32), array(0.4007646, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 95 / 390 d1= 1.0112143 d2= 1.0157391 g= [array(1.0157391, dtype=float32), array(1.0157391, dtype=float32), array(0.4004934, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 96 / 390 d1= 1.0138358 d2= 1.0181404 g= [array(1.0181404, dtype=float32), array(1.0181404, dtype=float32), array(0.40055338, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 97 / 390 d1= 1.0163044 d2= 1.020575 g= [array(1.020575, dtype=float32), array(1.020575, dtype=float32), array(0.40061212, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 98 / 390 d1= 1.0187749 d2= 1.0230476 g= [array(1.0230476, dtype=float32), array(1.0230476, dtype=float32), array(0.40043047, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 99 / 390 d1= 1.0212435 d2= 1.0255046 g= [array(1.0255046, dtype=float32), array(1.0255046, dtype=float32), array(0.4000947, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 100 / 390 d1= 1.023705 d2= 1.0281028 g= [array(1.0281028, dtype=float32), array(1.0281028, dtype=float32), array(0.39984375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 101 / 390 d1= 1.0263051 d2= 1.0306574 g= [array(1.0306574, dtype=float32), array(1.0306574, dtype=float32), array(0.39944306, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 102 / 390 d1= 1.0288686 d2= 1.0331948 g= [array(1.0331948, dtype=float32), array(1.0331948, dtype=float32), array(0.3995864, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 103 / 390 d1= 1.0314147 d2= 1.035738 g= [array(1.035738, dtype=float32), array(1.035738, dtype=float32), array(0.39942354, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 104 / 390 d1= 1.0339196 d2= 1.0382382 g= [array(1.0382382, dtype=float32), array(1.0382382, dtype=float32), array(0.39971453, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 105 / 390 d1= 1.0364648 d2= 1.040723 g= [array(1.040723, dtype=float32), array(1.040723, dtype=float32), array(0.39955357, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 106 / 390 d1= 1.0389506 d2= 1.0430956 g= [array(1.0430956, dtype=float32), array(1.0430956, dtype=float32), array(0.39939564, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 107 / 390 d1= 1.0413533 d2= 1.0455501 g= [array(1.0455501, dtype=float32), array(1.0455501, dtype=float32), array(0.3989486, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 108 / 390 d1= 1.043803 d2= 1.0479308 g= [array(1.0479308, dtype=float32), array(1.0479308, dtype=float32), array(0.39836517, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 109 / 390 d1= 1.0461754 d2= 1.0502048 g= [array(1.0502048, dtype=float32), array(1.0502048, dtype=float32), array(0.39807913, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 110 / 390 d1= 1.0484396 d2= 1.0525277 g= [array(1.0525277, dtype=float32), array(1.0525277, dtype=float32), array(0.39808238, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 111 / 390 d1= 1.0507902 d2= 1.0548972 g= [array(1.0548972, dtype=float32), array(1.0548972, dtype=float32), array(0.39787444, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 112 / 390 d1= 1.0531381 d2= 1.0571567 g= [array(1.0571567, dtype=float32), array(1.0571567, dtype=float32), array(0.398019, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 113 / 390 d1= 1.0553796 d2= 1.0593382 g= [array(1.0593382, dtype=float32), array(1.0593382, dtype=float32), array(0.3984375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 114 / 390 d1= 1.0576326 d2= 1.0616488 g= [array(1.0616488, dtype=float32), array(1.0616488, dtype=float32), array(0.39802632, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 115 / 390 d1= 1.0599401 d2= 1.0639632 g= [array(1.0639632, dtype=float32), array(1.0639632, dtype=float32), array(0.39782608, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 116 / 390 d1= 1.0622418 d2= 1.0662353 g= [array(1.0662353, dtype=float32), array(1.0662353, dtype=float32), array(0.39796606, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 117 / 390 d1= 1.0645136 d2= 1.068375 g= [array(1.068375, dtype=float32), array(1.068375, dtype=float32), array(0.39756945, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 118 / 390 d1= 1.066699 d2= 1.0705851 g= [array(1.0705851, dtype=float32), array(1.0705851, dtype=float32), array(0.39704713, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 119 / 390 d1= 1.0688856 d2= 1.0726662 g= [array(1.0726662, dtype=float32), array(1.0726662, dtype=float32), array(0.39686188, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 120 / 390 d1= 1.0709333 d2= 1.0746235 g= [array(1.0746235, dtype=float32), array(1.0746235, dtype=float32), array(0.39707032, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 121 / 390 d1= 1.072904 d2= 1.0766764 g= [array(1.0766764, dtype=float32), array(1.0766764, dtype=float32), array(0.3970816, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 122 / 390 d1= 1.0749619 d2= 1.0786955 g= [array(1.0786955, dtype=float32), array(1.0786955, dtype=float32), array(0.39709273, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 123 / 390 d1= 1.0770204 d2= 1.0808115 g= [array(1.0808115, dtype=float32), array(1.0808115, dtype=float32), array(0.39697662, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 124 / 390 d1= 1.0791057 d2= 1.0828882 g= [array(1.0828882, dtype=float32), array(1.0828882, dtype=float32), array(0.39711443, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 125 / 390 d1= 1.0811616 d2= 1.084913 g= [array(1.084913, dtype=float32), array(1.084913, dtype=float32), array(0.3975625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 126 / 390 d1= 1.0832458 d2= 1.0870252 g= [array(1.0870252, dtype=float32), array(1.0870252, dtype=float32), array(0.39763144, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 127 / 390 d1= 1.0853505 d2= 1.0891129 g= [array(1.0891129, dtype=float32), array(1.0891129, dtype=float32), array(0.39763778, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 128 / 390 d1= 1.0874331 d2= 1.0911918 g= [array(1.0911918, dtype=float32), array(1.0911918, dtype=float32), array(0.39782715, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 129 / 390 d1= 1.0895209 d2= 1.0931773 g= [array(1.0931773, dtype=float32), array(1.0931773, dtype=float32), array(0.3978319, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 130 / 390 d1= 1.0915153 d2= 1.0951478 g= [array(1.0951478, dtype=float32), array(1.0951478, dtype=float32), array(0.39771634, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 131 / 390 d1= 1.0935209 d2= 1.0971398 g= [array(1.0971398, dtype=float32), array(1.0971398, dtype=float32), array(0.39754295, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 132 / 390 d1= 1.0955225 d2= 1.0991787 g= [array(1.0991787, dtype=float32), array(1.0991787, dtype=float32), array(0.3971946, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 133 / 390 d1= 1.0975637 d2= 1.101091 g= [array(1.101091, dtype=float32), array(1.101091, dtype=float32), array(0.39702773, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 134 / 390 d1= 1.0994664 d2= 1.1030418 g= [array(1.1030418, dtype=float32), array(1.1030418, dtype=float32), array(0.39715484, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 135 / 390 d1= 1.1013944 d2= 1.1048894 g= [array(1.1048894, dtype=float32), array(1.1048894, dtype=float32), array(0.39722222, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 136 / 390 d1= 1.1032468 d2= 1.1067178 g= [array(1.1067178, dtype=float32), array(1.1067178, dtype=float32), array(0.3970014, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 137 / 390 d1= 1.1050941 d2= 1.108615 g= [array(1.108615, dtype=float32), array(1.108615, dtype=float32), array(0.397354, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 138 / 390 d1= 1.1070218 d2= 1.1104939 g= [array(1.1104939, dtype=float32), array(1.1104939, dtype=float32), array(0.3974751, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 139 / 390 d1= 1.1088663 d2= 1.1123487 g= [array(1.1123487, dtype=float32), array(1.1123487, dtype=float32), array(0.39753821, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 140 / 390 d1= 1.1107212 d2= 1.1142757 g= [array(1.1142757, dtype=float32), array(1.1142757, dtype=float32), array(0.39754465, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 141 / 390 d1= 1.1126903 d2= 1.1161225 g= [array(1.1161225, dtype=float32), array(1.1161225, dtype=float32), array(0.39732933, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 142 / 390 d1= 1.1145078 d2= 1.117958 g= [array(1.117958, dtype=float32), array(1.117958, dtype=float32), array(0.3972271, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 143 / 390 d1= 1.1163535 d2= 1.1198354 g= [array(1.1198354, dtype=float32), array(1.1198354, dtype=float32), array(0.3972902, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 144 / 390 d1= 1.118261 d2= 1.1215543 g= [array(1.1215543, dtype=float32), array(1.1215543, dtype=float32), array(0.39718968, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 145 / 390 d1= 1.1199355 d2= 1.1234452 g= [array(1.1234452, dtype=float32), array(1.1234452, dtype=float32), array(0.39746767, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 146 / 390 d1= 1.1218653 d2= 1.1252458 g= [array(1.1252458, dtype=float32), array(1.1252458, dtype=float32), array(0.39763483, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 147 / 390 d1= 1.1236643 d2= 1.12712 g= [array(1.12712, dtype=float32), array(1.12712, dtype=float32), array(0.39764032, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 148 / 390 d1= 1.1255206 d2= 1.1288844 g= [array(1.1288844, dtype=float32), array(1.1288844, dtype=float32), array(0.39790964, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 149 / 390 d1= 1.1273489 d2= 1.1307626 g= [array(1.1307626, dtype=float32), array(1.1307626, dtype=float32), array(0.39791316, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 150 / 390 d1= 1.129207 d2= 1.1324706 g= [array(1.1324706, dtype=float32), array(1.1324706, dtype=float32), array(0.39770833, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 151 / 390 d1= 1.1309193 d2= 1.134195 g= [array(1.134195, dtype=float32), array(1.134195, dtype=float32), array(0.39755794, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 152 / 390 d1= 1.1326504 d2= 1.135918 g= [array(1.135918, dtype=float32), array(1.135918, dtype=float32), array(0.39756373, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 153 / 390 d1= 1.1343912 d2= 1.1375746 g= [array(1.1375746, dtype=float32), array(1.1375746, dtype=float32), array(0.39741626, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 154 / 390 d1= 1.1360238 d2= 1.1392792 g= [array(1.1392792, dtype=float32), array(1.1392792, dtype=float32), array(0.39737216, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 155 / 390 d1= 1.137741 d2= 1.1408763 g= [array(1.1408763, dtype=float32), array(1.1408763, dtype=float32), array(0.39753023, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 156 / 390 d1= 1.139354 d2= 1.1425581 g= [array(1.1425581, dtype=float32), array(1.1425581, dtype=float32), array(0.39733574, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 157 / 390 d1= 1.141029 d2= 1.1442311 g= [array(1.1442311, dtype=float32), array(1.1442311, dtype=float32), array(0.39734274, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 158 / 390 d1= 1.142702 d2= 1.1459146 g= [array(1.1459146, dtype=float32), array(1.1459146, dtype=float32), array(0.39730024, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 159 / 390 d1= 1.1444069 d2= 1.1475829 g= [array(1.1475829, dtype=float32), array(1.1475829, dtype=float32), array(0.3972091, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 160 / 390 d1= 1.1460559 d2= 1.1492559 g= [array(1.1492559, dtype=float32), array(1.1492559, dtype=float32), array(0.39736328, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 161 / 390 d1= 1.1477541 d2= 1.1509024 g= [array(1.1509024, dtype=float32), array(1.1509024, dtype=float32), array(0.39712733, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 162 / 390 d1= 1.1493819 d2= 1.1524496 g= [array(1.1524496, dtype=float32), array(1.1524496, dtype=float32), array(0.39723188, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 163 / 390 d1= 1.1509281 d2= 1.1541396 g= [array(1.1541396, dtype=float32), array(1.1541396, dtype=float32), array(0.397431, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 164 / 390 d1= 1.1526239 d2= 1.1556193 g= [array(1.1556193, dtype=float32), array(1.1556193, dtype=float32), array(0.3975324, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 165 / 390 d1= 1.1541374 d2= 1.1572458 g= [array(1.1572458, dtype=float32), array(1.1572458, dtype=float32), array(0.39739582, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 166 / 390 d1= 1.1557482 d2= 1.1587478 g= [array(1.1587478, dtype=float32), array(1.1587478, dtype=float32), array(0.397308, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 167 / 390 d1= 1.1572714 d2= 1.1602575 g= [array(1.1602575, dtype=float32), array(1.1602575, dtype=float32), array(0.39731476, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 168 / 390 d1= 1.1587603 d2= 1.1617615 g= [array(1.1617615, dtype=float32), array(1.1617615, dtype=float32), array(0.3972749, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 169 / 390 d1= 1.1602831 d2= 1.163291 g= [array(1.163291, dtype=float32), array(1.163291, dtype=float32), array(0.3972818, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 170 / 390 d1= 1.1618164 d2= 1.1648172 g= [array(1.1648172, dtype=float32), array(1.1648172, dtype=float32), array(0.39719668, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 171 / 390 d1= 1.1633593 d2= 1.1663551 g= [array(1.1663551, dtype=float32), array(1.1663551, dtype=float32), array(0.39711258, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 172 / 390 d1= 1.164877 d2= 1.1678729 g= [array(1.1678729, dtype=float32), array(1.1678729, dtype=float32), array(0.39707485, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 173 / 390 d1= 1.1664151 d2= 1.1694756 g= [array(1.1694756, dtype=float32), array(1.1694756, dtype=float32), array(0.39699242, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 174 / 390 d1= 1.1680217 d2= 1.1710253 g= [array(1.1710253, dtype=float32), array(1.1710253, dtype=float32), array(0.39700073, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 175 / 390 d1= 1.1695716 d2= 1.1725773 g= [array(1.1725773, dtype=float32), array(1.1725773, dtype=float32), array(0.39705357, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 176 / 390 d1= 1.1711198 d2= 1.1740369 g= [array(1.1740369, dtype=float32), array(1.1740369, dtype=float32), array(0.39701703, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 177 / 390 d1= 1.1725872 d2= 1.1754599 g= [array(1.1754599, dtype=float32), array(1.1754599, dtype=float32), array(0.39706922, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 178 / 390 d1= 1.174022 d2= 1.1768702 g= [array(1.1768702, dtype=float32), array(1.1768702, dtype=float32), array(0.39716467, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 179 / 390 d1= 1.1754274 d2= 1.1782427 g= [array(1.1782427, dtype=float32), array(1.1782427, dtype=float32), array(0.3971718, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 180 / 390 d1= 1.1768074 d2= 1.179631 g= [array(1.179631, dtype=float32), array(1.179631, dtype=float32), array(0.397092, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 181 / 390 d1= 1.1781896 d2= 1.180978 g= [array(1.180978, dtype=float32), array(1.180978, dtype=float32), array(0.39705628, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 182 / 390 d1= 1.1795167 d2= 1.1823987 g= [array(1.1823987, dtype=float32), array(1.1823987, dtype=float32), array(0.3974073, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 183 / 390 d1= 1.1809859 d2= 1.1838434 g= [array(1.1838434, dtype=float32), array(1.1838434, dtype=float32), array(0.39737022, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 184 / 390 d1= 1.182426 d2= 1.1853733 g= [array(1.1853733, dtype=float32), array(1.1853733, dtype=float32), array(0.39746094, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 185 / 390 d1= 1.1839684 d2= 1.1868993 g= [array(1.1868993, dtype=float32), array(1.1868993, dtype=float32), array(0.39755067, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 186 / 390 d1= 1.1855052 d2= 1.1883448 g= [array(1.1883448, dtype=float32), array(1.1883448, dtype=float32), array(0.39747143, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 187 / 390 d1= 1.1869448 d2= 1.189773 g= [array(1.189773, dtype=float32), array(1.189773, dtype=float32), array(0.39735126, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 188 / 390 d1= 1.1883732 d2= 1.1913393 g= [array(1.1913393, dtype=float32), array(1.1913393, dtype=float32), array(0.39723238, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 189 / 390 d1= 1.1899375 d2= 1.1927873 g= [array(1.1927873, dtype=float32), array(1.1927873, dtype=float32), array(0.3971561, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 190 / 390 d1= 1.1913793 d2= 1.194143 g= [array(1.194143, dtype=float32), array(1.194143, dtype=float32), array(0.39745066, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 191 / 390 d1= 1.1927583 d2= 1.195573 g= [array(1.195573, dtype=float32), array(1.195573, dtype=float32), array(0.39733312, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 192 / 390 d1= 1.1941797 d2= 1.197024 g= [array(1.197024, dtype=float32), array(1.197024, dtype=float32), array(0.39737955, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 193 / 390 d1= 1.1956508 d2= 1.1985075 g= [array(1.1985075, dtype=float32), array(1.1985075, dtype=float32), array(0.3973041, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 194 / 390 d1= 1.1971288 d2= 1.1999421 g= [array(1.1999421, dtype=float32), array(1.1999421, dtype=float32), array(0.39726967, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 195 / 390 d1= 1.1985803 d2= 1.2014145 g= [array(1.2014145, dtype=float32), array(1.2014145, dtype=float32), array(0.39703527, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 196 / 390 d1= 1.2000502 d2= 1.2029032 g= [array(1.2029032, dtype=float32), array(1.2029032, dtype=float32), array(0.39680326, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 197 / 390 d1= 1.2015104 d2= 1.2043226 g= [array(1.2043226, dtype=float32), array(1.2043226, dtype=float32), array(0.39693052, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 198 / 390 d1= 1.2029628 d2= 1.2056631 g= [array(1.2056631, dtype=float32), array(1.2056631, dtype=float32), array(0.39697757, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 199 / 390 d1= 1.204318 d2= 1.2070627 g= [array(1.2070627, dtype=float32), array(1.2070627, dtype=float32), array(0.39674938, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 200 / 390 d1= 1.2057033 d2= 1.2084327 g= [array(1.2084327, dtype=float32), array(1.2084327, dtype=float32), array(0.39683592, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 201 / 390 d1= 1.2070594 d2= 1.2097386 g= [array(1.2097386, dtype=float32), array(1.2097386, dtype=float32), array(0.39688277, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 202 / 390 d1= 1.2083666 d2= 1.2109694 g= [array(1.2109694, dtype=float32), array(1.2109694, dtype=float32), array(0.3970065, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 203 / 390 d1= 1.2096243 d2= 1.2123646 g= [array(1.2123646, dtype=float32), array(1.2123646, dtype=float32), array(0.39693657, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 204 / 390 d1= 1.2110085 d2= 1.2137254 g= [array(1.2137254, dtype=float32), array(1.2137254, dtype=float32), array(0.39698222, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 205 / 390 d1= 1.2123826 d2= 1.215022 g= [array(1.215022, dtype=float32), array(1.215022, dtype=float32), array(0.39695123, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 206 / 390 d1= 1.2136844 d2= 1.2163438 g= [array(1.2163438, dtype=float32), array(1.2163438, dtype=float32), array(0.3969205, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 207 / 390 d1= 1.2150093 d2= 1.2176647 g= [array(1.2176647, dtype=float32), array(1.2176647, dtype=float32), array(0.39685234, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 208 / 390 d1= 1.2163223 d2= 1.218873 g= [array(1.218873, dtype=float32), array(1.218873, dtype=float32), array(0.39689752, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 209 / 390 d1= 1.2175434 d2= 1.2201328 g= [array(1.2201328, dtype=float32), array(1.2201328, dtype=float32), array(0.39697966, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 210 / 390 d1= 1.2188171 d2= 1.2214177 g= [array(1.2214177, dtype=float32), array(1.2214177, dtype=float32), array(0.3970238, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 211 / 390 d1= 1.2200843 d2= 1.2226641 g= [array(1.2226641, dtype=float32), array(1.2226641, dtype=float32), array(0.3969935, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 212 / 390 d1= 1.2213254 d2= 1.2238772 g= [array(1.2238772, dtype=float32), array(1.2238772, dtype=float32), array(0.39722142, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 213 / 390 d1= 1.2225593 d2= 1.2251481 g= [array(1.2251481, dtype=float32), array(1.2251481, dtype=float32), array(0.3970804, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 214 / 390 d1= 1.2238334 d2= 1.2264955 g= [array(1.2264955, dtype=float32), array(1.2264955, dtype=float32), array(0.39715976, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 215 / 390 d1= 1.2251743 d2= 1.227795 g= [array(1.227795, dtype=float32), array(1.227795, dtype=float32), array(0.3971657, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 216 / 390 d1= 1.2264763 d2= 1.2290494 g= [array(1.2290494, dtype=float32), array(1.2290494, dtype=float32), array(0.3971354, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 217 / 390 d1= 1.2277461 d2= 1.230354 g= [array(1.230354, dtype=float32), array(1.230354, dtype=float32), array(0.39717743, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 218 / 390 d1= 1.2290525 d2= 1.2315856 g= [array(1.2315856, dtype=float32), array(1.2315856, dtype=float32), array(0.39714736, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 219 / 390 d1= 1.230281 d2= 1.2328167 g= [array(1.2328167, dtype=float32), array(1.2328167, dtype=float32), array(0.39726028, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 220 / 390 d1= 1.2315123 d2= 1.2340157 g= [array(1.2340157, dtype=float32), array(1.2340157, dtype=float32), array(0.3972656, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 221 / 390 d1= 1.2327065 d2= 1.2352388 g= [array(1.2352388, dtype=float32), array(1.2352388, dtype=float32), array(0.39741233, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 222 / 390 d1= 1.2339343 d2= 1.236425 g= [array(1.236425, dtype=float32), array(1.236425, dtype=float32), array(0.3976633, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 223 / 390 d1= 1.2351437 d2= 1.2376748 g= [array(1.2376748, dtype=float32), array(1.2376748, dtype=float32), array(0.3974916, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 224 / 390 d1= 1.2363892 d2= 1.2389022 g= [array(1.2389022, dtype=float32), array(1.2389022, dtype=float32), array(0.39742607, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 225 / 390 d1= 1.2376071 d2= 1.2400844 g= [array(1.2400844, dtype=float32), array(1.2400844, dtype=float32), array(0.39739582, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 226 / 390 d1= 1.2388195 d2= 1.241351 g= [array(1.241351, dtype=float32), array(1.241351, dtype=float32), array(0.39729673, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 227 / 390 d1= 1.2400805 d2= 1.2426103 g= [array(1.2426103, dtype=float32), array(1.2426103, dtype=float32), array(0.39730176, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 228 / 390 d1= 1.2413404 d2= 1.2438562 g= [array(1.2438562, dtype=float32), array(1.2438562, dtype=float32), array(0.39723822, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 229 / 390 d1= 1.242575 d2= 1.2450573 g= [array(1.2450573, dtype=float32), array(1.2450573, dtype=float32), array(0.3973458, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 230 / 390 d1= 1.2437985 d2= 1.2462626 g= [array(1.2462626, dtype=float32), array(1.2462626, dtype=float32), array(0.39721468, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 231 / 390 d1= 1.2449987 d2= 1.2474275 g= [array(1.2474275, dtype=float32), array(1.2474275, dtype=float32), array(0.3972876, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 232 / 390 d1= 1.2461686 d2= 1.2486228 g= [array(1.2486228, dtype=float32), array(1.2486228, dtype=float32), array(0.39729255, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 233 / 390 d1= 1.2473658 d2= 1.2497928 g= [array(1.2497928, dtype=float32), array(1.2497928, dtype=float32), array(0.39729747, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 234 / 390 d1= 1.2485396 d2= 1.2510074 g= [array(1.2510074, dtype=float32), array(1.2510074, dtype=float32), array(0.39723557, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 235 / 390 d1= 1.2497512 d2= 1.2521625 g= [array(1.2521625, dtype=float32), array(1.2521625, dtype=float32), array(0.3972407, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 236 / 390 d1= 1.2509203 d2= 1.2533543 g= [array(1.2533543, dtype=float32), array(1.2533543, dtype=float32), array(0.39701402, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 237 / 390 d1= 1.2521126 d2= 1.2545468 g= [array(1.2545468, dtype=float32), array(1.2545468, dtype=float32), array(0.39692116, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# ...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 309 / 390 d1= 1.6673003 d2= 1.6676384 g= [array(1.6676384, dtype=float32), array(1.6676384, dtype=float32), array(0.3967153, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 310 / 390 d1= 1.667372 d2= 1.6677032 g= [array(1.6677032, dtype=float32), array(1.6677032, dtype=float32), array(0.396687, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 311 / 390 d1= 1.667435 d2= 1.6677729 g= [array(1.6677729, dtype=float32), array(1.6677729, dtype=float32), array(0.39670464, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 312 / 390 d1= 1.6675063 d2= 1.6678443 g= [array(1.6678443, dtype=float32), array(1.6678443, dtype=float32), array(0.3967014, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 313 / 390 d1= 1.6675754 d2= 1.6679058 g= [array(1.6679058, dtype=float32), array(1.6679058, dtype=float32), array(0.39669815, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 314 / 390 d1= 1.6676401 d2= 1.6679791 g= [array(1.6679791, dtype=float32), array(1.6679791, dtype=float32), array(0.39670324, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 315 / 390 d1= 1.6677098 d2= 1.6680366 g= [array(1.6680366, dtype=float32), array(1.6680366, dtype=float32), array(0.39670834, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 316 / 390 d1= 1.6677687 d2= 1.6681006 g= [array(1.6681006, dtype=float32), array(1.6681006, dtype=float32), array(0.39671758, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 317 / 390 d1= 1.6678333 d2= 1.6681602 g= [array(1.6681602, dtype=float32), array(1.6681602, dtype=float32), array(0.39671433, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 5 Batch= 318 / 390 d1= 1.6678929 d2= 1.6682216 g= [array(1.6682216, dtype=float32), array(1.6682216, dtype=float32), array(0.39669445, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 319 / 390 d1= 1.667956 d2= 1.6682835 g= [array(1.6682835, dtype=float32), array(1.6682835, dtype=float32), array(0.39667043, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 320 / 390 d1= 1.6680142 d2= 1.668351 g= [array(1.668351, dtype=float32), array(1.668351, dtype=float32), array(0.3966797, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 321 / 390 d1= 1.6680853 d2= 1.668412 g= [array(1.668412, dtype=float32), array(1.668412, dtype=float32), array(0.39668477, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 322 / 390 d1= 1.668145 d2= 1.66847 g= [array(1.66847, dtype=float32), array(1.66847, dtype=float32), array(0.3966774, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 323 / 390 d1= 1.6682028 d2= 1.6685272 g= [array(1.6685272, dtype=float32), array(1.6685272, dtype=float32), array(0.39668664, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 324 / 390 d1= 1.6682581 d2= 1.6685871 g= [array(1.6685871, dtype=float32), array(1.6685871, dtype=float32), array(0.39671245, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 325 / 390 d1= 1.6683197 d2= 1.6686479 g= [array(1.6686479, dtype=float32), array(1.6686479, dtype=float32), array(0.3967092, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 326 / 390 d1= 1.6683794 d2= 1.6687135 g= [array(1.6687135, dtype=float32), array(1.6687135, dtype=float32), array(0.39671013, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 327 / 390 d1= 1.6684499 d2= 1.6687771 g= [array(1.6687771, dtype=float32), array(1.6687771, dtype=float32), array(0.3966738, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 328 / 390 d1= 1.6685101 d2= 1.668841 g= [array(1.668841, dtype=float32), array(1.668841, dtype=float32), array(0.39668715, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 329 / 390 d1= 1.6685737 d2= 1.6689053 g= [array(1.6689053, dtype=float32), array(1.6689053, dtype=float32), array(0.3966922, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 330 / 390 d1= 1.6686409 d2= 1.6689687 g= [array(1.6689687, dtype=float32), array(1.6689687, dtype=float32), array(0.39668486, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 331 / 390 d1= 1.6687028 d2= 1.6690274 g= [array(1.6690274, dtype=float32), array(1.6690274, dtype=float32), array(0.39667752, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 332 / 390 d1= 1.6687628 d2= 1.6690899 g= [array(1.6690899, dtype=float32), array(1.6690899, dtype=float32), array(0.39669085, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 333 / 390 d1= 1.6688242 d2= 1.6691432 g= [array(1.6691432, dtype=float32), array(1.6691432, dtype=float32), array(0.39670414, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 334 / 390 d1= 1.6688763 d2= 1.6692064 g= [array(1.6692064, dtype=float32), array(1.6692064, dtype=float32), array(0.39670092, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 335 / 390 d1= 1.6689421 d2= 1.6692629 g= [array(1.6692629, dtype=float32), array(1.6692629, dtype=float32), array(0.39669773, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 336 / 390 d1= 1.6689985 d2= 1.6693202 g= [array(1.6693202, dtype=float32), array(1.6693202, dtype=float32), array(0.39669865, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 337 / 390 d1= 1.669051 d2= 1.6693718 g= [array(1.6693718, dtype=float32), array(1.6693718, dtype=float32), array(0.39672425, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 338 / 390 d1= 1.6691077 d2= 1.6694318 g= [array(1.6694318, dtype=float32), array(1.6694318, dtype=float32), array(0.3967293, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 339 / 390 d1= 1.6691687 d2= 1.6694971 g= [array(1.6694971, dtype=float32), array(1.6694971, dtype=float32), array(0.39672196, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 340 / 390 d1= 1.669233 d2= 1.6695584 g= [array(1.6695584, dtype=float32), array(1.6695584, dtype=float32), array(0.3967352, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 341 / 390 d1= 1.669294 d2= 1.6696258 g= [array(1.6696258, dtype=float32), array(1.6696258, dtype=float32), array(0.39673197, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 342 / 390 d1= 1.6693581 d2= 1.6696794 g= [array(1.6696794, dtype=float32), array(1.6696794, dtype=float32), array(0.39674932, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 343 / 390 d1= 1.6694139 d2= 1.6697394 g= [array(1.6697394, dtype=float32), array(1.6697394, dtype=float32), array(0.39677072, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 344 / 390 d1= 1.6694758 d2= 1.6698008 g= [array(1.6698008, dtype=float32), array(1.6698008, dtype=float32), array(0.3967716, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 345 / 390 d1= 1.6695385 d2= 1.6698632 g= [array(1.6698632, dtype=float32), array(1.6698632, dtype=float32), array(0.39674786, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 346 / 390 d1= 1.6696002 d2= 1.6699172 g= [array(1.6699172, dtype=float32), array(1.6699172, dtype=float32), array(0.39674056, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 347 / 390 d1= 1.6696547 d2= 1.6699752 g= [array(1.6699752, dtype=float32), array(1.6699752, dtype=float32), array(0.39673325, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 348 / 390 d1= 1.6697121 d2= 1.6700313 g= [array(1.6700313, dtype=float32), array(1.6700313, dtype=float32), array(0.39672187, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 349 / 390 d1= 1.6697654 d2= 1.6700929 g= [array(1.6700929, dtype=float32), array(1.6700929, dtype=float32), array(0.3967514, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 350 / 390 d1= 1.6698287 d2= 1.67015 g= [array(1.67015, dtype=float32), array(1.67015, dtype=float32), array(0.39676866, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 351 / 390 d1= 1.6698868 d2= 1.6702037 g= [array(1.6702037, dtype=float32), array(1.6702037, dtype=float32), array(0.3967818, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 352 / 390 d1= 1.6699419 d2= 1.6702698 g= [array(1.6702698, dtype=float32), array(1.6702698, dtype=float32), array(0.39678675, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 353 / 390 d1= 1.670007 d2= 1.6703364 g= [array(1.6703364, dtype=float32), array(1.6703364, dtype=float32), array(0.39678353, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 354 / 390 d1= 1.6700736 d2= 1.6704006 g= [array(1.6704006, dtype=float32), array(1.6704006, dtype=float32), array(0.39677623, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 355 / 390 d1= 1.6701379 d2= 1.6704648 g= [array(1.6704648, dtype=float32), array(1.6704648, dtype=float32), array(0.39678118, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 356 / 390 d1= 1.6702019 d2= 1.6705185 g= [array(1.6705185, dtype=float32), array(1.6705185, dtype=float32), array(0.3967698, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 357 / 390 d1= 1.6702559 d2= 1.670581 g= [array(1.670581, dtype=float32), array(1.670581, dtype=float32), array(0.3967666, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 358 / 390 d1= 1.6703188 d2= 1.6706407 g= [array(1.6706407, dtype=float32), array(1.6706407, dtype=float32), array(0.3967471, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 359 / 390 d1= 1.6703779 d2= 1.6706957 g= [array(1.6706957, dtype=float32), array(1.6706957, dtype=float32), array(0.39674392, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 360 / 390 d1= 1.6704335 d2= 1.670751 g= [array(1.670751, dtype=float32), array(1.670751, dtype=float32), array(0.39673665, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 361 / 390 d1= 1.6704895 d2= 1.6708031 g= [array(1.6708031, dtype=float32), array(1.6708031, dtype=float32), array(0.39673346, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 362 / 390 d1= 1.6705407 d2= 1.670854 g= [array(1.670854, dtype=float32), array(1.670854, dtype=float32), array(0.3967303, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 363 / 390 d1= 1.6705917 d2= 1.6709094 g= [array(1.6709094, dtype=float32), array(1.6709094, dtype=float32), array(0.3967393, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 364 / 390 d1= 1.6706474 d2= 1.670961 g= [array(1.670961, dtype=float32), array(1.670961, dtype=float32), array(0.39675644, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 365 / 390 d1= 1.6706975 d2= 1.6710134 g= [array(1.6710134, dtype=float32), array(1.6710134, dtype=float32), array(0.3967776, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 366 / 390 d1= 1.6707503 d2= 1.6710674 g= [array(1.6710674, dtype=float32), array(1.6710674, dtype=float32), array(0.39678657, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 367 / 390 d1= 1.6708065 d2= 1.6711282 g= [array(1.6711282, dtype=float32), array(1.6711282, dtype=float32), array(0.39678338, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 368 / 390 d1= 1.6708689 d2= 1.6711919 g= [array(1.6711919, dtype=float32), array(1.6711919, dtype=float32), array(0.39677614, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 369 / 390 d1= 1.6709318 d2= 1.6712505 g= [array(1.6712505, dtype=float32), array(1.6712505, dtype=float32), array(0.396777, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 370 / 390 d1= 1.6709902 d2= 1.6713159 g= [array(1.6713159, dtype=float32), array(1.6713159, dtype=float32), array(0.3967819, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 371 / 390 d1= 1.6710535 d2= 1.6713686 g= [array(1.6713686, dtype=float32), array(1.6713686, dtype=float32), array(0.3967949, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 372 / 390 d1= 1.6711048 d2= 1.6714208 g= [array(1.6714208, dtype=float32), array(1.6714208, dtype=float32), array(0.39682, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 373 / 390 d1= 1.671161 d2= 1.6714822 g= [array(1.6714822, dtype=float32), array(1.6714822, dtype=float32), array(0.39679658, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 374 / 390 d1= 1.671222 d2= 1.6715493 g= [array(1.6715493, dtype=float32), array(1.6715493, dtype=float32), array(0.3967934, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 375 / 390 d1= 1.6712909 d2= 1.6716081 g= [array(1.6716081, dtype=float32), array(1.6716081, dtype=float32), array(0.3967781, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 376 / 390 d1= 1.6713479 d2= 1.6716713 g= [array(1.6716713, dtype=float32), array(1.6716713, dtype=float32), array(0.3967709, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 377 / 390 d1= 1.6714094 d2= 1.6717271 g= [array(1.6717271, dtype=float32), array(1.6717271, dtype=float32), array(0.3967677, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 378 / 390 d1= 1.6714648 d2= 1.6717801 g= [array(1.6717801, dtype=float32), array(1.6717801, dtype=float32), array(0.39678067, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 379 / 390 d1= 1.671519 d2= 1.6718307 g= [array(1.6718307, dtype=float32), array(1.6718307, dtype=float32), array(0.39678958, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 380 / 390 d1= 1.67157 d2= 1.6718918 g= [array(1.6718918, dtype=float32), array(1.6718918, dtype=float32), array(0.39681056, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 381 / 390 d1= 1.6716311 d2= 1.6719503 g= [array(1.6719503, dtype=float32), array(1.6719503, dtype=float32), array(0.3967953, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 382 / 390 d1= 1.6716893 d2= 1.6720039 g= [array(1.6720039, dtype=float32), array(1.6720039, dtype=float32), array(0.3967921, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 383 / 390 d1= 1.6717459 d2= 1.6720605 g= [array(1.6720605, dtype=float32), array(1.6720605, dtype=float32), array(0.3967809, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 384 / 390 d1= 1.6718001 d2= 1.6721195 g= [array(1.6721195, dtype=float32), array(1.6721195, dtype=float32), array(0.3967858, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 385 / 390 d1= 1.6718616 d2= 1.6721798 g= [array(1.6721798, dtype=float32), array(1.6721798, dtype=float32), array(0.39675853, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 386 / 390 d1= 1.6719183 d2= 1.6722418 g= [array(1.6722418, dtype=float32), array(1.6722418, dtype=float32), array(0.39677945, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 387 / 390 d1= 1.6719831 d2= 1.6723 g= [array(1.6723, dtype=float32), array(1.6723, dtype=float32), array(0.39676827, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 388 / 390 d1= 1.6720401 d2= 1.6723568 g= [array(1.6723568, dtype=float32), array(1.6723568, dtype=float32), array(0.39677313, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 389 / 390 d1= 1.6720996 d2= 1.6724244 g= [array(1.6724244, dtype=float32), array(1.6724244, dtype=float32), array(0.39674994, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 390 / 390 d1= 1.6721678 d2= 1.6724795 g= [array(1.6724795, dtype=float32), array(1.6724795, dtype=float32), array(0.3967508, dtype=float32)]

# %%
from tensorflow.keras.models import load_model

# Now, load the generator model and generate images

# Plot generated images function
def show_plot(examples, n):
    for i in range(n * n):
        plt.subplot(n, n, 1 + i)
        plt.axis('off')
        plt.imshow(examples[i, :, :, :])
    plt.show()

# load model
model = load_model(model_filename) #Model trained for n epochs

# generate the latent vector
latent_points = generate_latent_points(100, 25)  #Latent dim and n_samples

# generate images from the latent vector
X = model.predict(latent_points)

# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
X = (X*255).astype(np.uint8)

# plot the generated images
# Note: CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck
show_plot(X, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 692ms/step

# %% [markdown]
# ## Train the GAN with a higher dimension of Latent Space and more epochs

# %%
# size of the latent space
latent_dim = 150
# create the discriminator
discriminator = define_discriminator()
# create the generator
generator = define_generator(latent_dim)
# create the gan
gan_model = define_gan(generator, discriminator)
# load image data
dataset = load_real_samples()
# train model
n_epochs=6 #50
model_filename = "cifar_GAN." + str(n_epochs) + "_epochs.keras"
train(generator, discriminator, gan_model, model_filename, dataset, latent_dim, n_epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Epoch= 1 Batch= 1 / 390 d1= 0.6779848 d2= 0.6863116 g= [array(0.6863116, dtype=float32), array(0.6863116, dtype=float32), array(0.4609375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x795cc43075b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x795cc43b2680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 18 / 390 d1= 0.7543822 d2= 0.76464057 g= [array(0.76464057, dtype=float32), array(0.76464057, dtype=float32), array(0.3450521, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 19 / 390 d1= 0.76233006 d2= 0.7727381 g= [array(0.7727381, dtype=float32), array(0.7727381, dtype=float32), array(0.34292763, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 20 / 390 d1= 0.77044964 d2= 0.77999395 g= [array(0.77999395, dtype=float32), array(0.77999395, dtype=float32), array(0.3425781, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 21 / 390 d1= 0.77772784 d2= 0.7879344 g= [array(0.7879344, dtype=float32), array(0.7879344, dtype=float32), array(0.33965772, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 22 / 390 d1= 0.78527164 d2= 0.79486936 g= [array(0.79486936, dtype=float32), array(0.79486936, dtype=float32), array(0.33984375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 23 / 390 d1= 0.7922462 d2= 0.80203706 g= [array(0.80203706, dtype=float32), array(0.80203706, dtype=float32), array(0.3396739, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 24 / 390 d1= 0.79939044 d2= 0.8089452 g= [array(0.8089452, dtype=float32), array(0.8089452, dtype=float32), array(0.33919272, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 25 / 390 d1= 0.8062576 d2= 0.815652 g= [array(0.815652, dtype=float32), array(0.815652, dtype=float32), array(0.3390625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 26 / 390 d1= 0.8130046 d2= 0.8217979 g= [array(0.8217979, dtype=float32), array(0.8217979, dtype=float32), array(0.3377404, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 27 / 390 d1= 0.81901044 d2= 0.82799107 g= [array(0.82799107, dtype=float32), array(0.82799107, dtype=float32), array(0.3365162, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 28 / 390 d1= 0.8253182 d2= 0.8338656 g= [array(0.8338656, dtype=float32), array(0.8338656, dtype=float32), array(0.33537945, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 29 / 390 d1= 0.8310632 d2= 0.83968645 g= [array(0.83968645, dtype=float32), array(0.83968645, dtype=float32), array(0.3353987, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 30 / 390 d1= 0.83716005 d2= 0.84573466 g= [array(0.84573466, dtype=float32), array(0.84573466, dtype=float32), array(0.33333334, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 31 / 390 d1= 0.84267044 d2= 0.85073674 g= [array(0.85073674, dtype=float32), array(0.85073674, dtype=float32), array(0.3356855, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 32 / 390 d1= 0.8479409 d2= 0.8560157 g= [array(0.8560157, dtype=float32), array(0.8560157, dtype=float32), array(0.33544922, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 33 / 390 d1= 0.8532798 d2= 0.8612624 g= [array(0.8612624, dtype=float32), array(0.8612624, dtype=float32), array(0.33522728, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 34 / 390 d1= 0.858438 d2= 0.86608094 g= [array(0.86608094, dtype=float32), array(0.86608094, dtype=float32), array(0.33639705, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 35 / 390 d1= 0.86338514 d2= 0.8708624 g= [array(0.8708624, dtype=float32), array(0.8708624, dtype=float32), array(0.33571428, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 36 / 390 d1= 0.8682046 d2= 0.8751518 g= [array(0.8751518, dtype=float32), array(0.8751518, dtype=float32), array(0.33485243, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 37 / 390 d1= 0.8723893 d2= 0.8798332 g= [array(0.8798332, dtype=float32), array(0.8798332, dtype=float32), array(0.3346706, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 38 / 390 d1= 0.87709075 d2= 0.88394094 g= [array(0.88394094, dtype=float32), array(0.88394094, dtype=float32), array(0.33408716, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 39 / 390 d1= 0.88121 d2= 0.88833934 g= [array(0.88833934, dtype=float32), array(0.88833934, dtype=float32), array(0.33433494, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 40 / 390 d1= 0.8857349 d2= 0.89239913 g= [array(0.89239913, dtype=float32), array(0.89239913, dtype=float32), array(0.3330078, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 41 / 390 d1= 0.8896984 d2= 0.8961072 g= [array(0.8961072, dtype=float32), array(0.8961072, dtype=float32), array(0.3332698, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 42 / 390 d1= 0.89343446 d2= 0.9000457 g= [array(0.9000457, dtype=float32), array(0.9000457, dtype=float32), array(0.33389136, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 43 / 390 d1= 0.89748394 d2= 0.9038131 g= [array(0.9038131, dtype=float32), array(0.9038131, dtype=float32), array(0.3332122, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 44 / 390 d1= 0.90111893 d2= 0.9073099 g= [array(0.9073099, dtype=float32), array(0.9073099, dtype=float32), array(0.3338068, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 45 / 390 d1= 0.9046815 d2= 0.9106381 g= [array(0.9106381, dtype=float32), array(0.9106381, dtype=float32), array(0.3342014, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 46 / 390 d1= 0.9081567 d2= 0.9141909 g= [array(0.9141909, dtype=float32), array(0.9141909, dtype=float32), array(0.33355978, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 47 / 390 d1= 0.91156894 d2= 0.91780084 g= [array(0.91780084, dtype=float32), array(0.91780084, dtype=float32), array(0.33410904, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 48 / 390 d1= 0.9151664 d2= 0.92106515 g= [array(0.92106515, dtype=float32), array(0.92106515, dtype=float32), array(0.3347982, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 49 / 390 d1= 0.91854703 d2= 0.92445445 g= [array(0.92445445, dtype=float32), array(0.92445445, dtype=float32), array(0.3338648, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 50 / 390 d1= 0.92185825 d2= 0.92742765 g= [array(0.92742765, dtype=float32), array(0.92742765, dtype=float32), array(0.33515626, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 51 / 390 d1= 0.92483073 d2= 0.930381 g= [array(0.930381, dtype=float32), array(0.930381, dtype=float32), array(0.33609068, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 52 / 390 d1= 0.9278825 d2= 0.9333772 g= [array(0.9333772, dtype=float32), array(0.9333772, dtype=float32), array(0.33623797, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 53 / 390 d1= 0.9308783 d2= 0.9363088 g= [array(0.9363088, dtype=float32), array(0.9363088, dtype=float32), array(0.3359375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 54 / 390 d1= 0.93391687 d2= 0.93922657 g= [array(0.93922657, dtype=float32), array(0.93922657, dtype=float32), array(0.33564815, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 55 / 390 d1= 0.9368251 d2= 0.94218016 g= [array(0.94218016, dtype=float32), array(0.94218016, dtype=float32), array(0.33551136, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 56 / 390 d1= 0.93985224 d2= 0.9451626 g= [array(0.9451626, dtype=float32), array(0.9451626, dtype=float32), array(0.33468193, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 57 / 390 d1= 0.9427088 d2= 0.9478315 g= [array(0.9478315, dtype=float32), array(0.9478315, dtype=float32), array(0.3352522, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 58 / 390 d1= 0.9454703 d2= 0.95045155 g= [array(0.95045155, dtype=float32), array(0.95045155, dtype=float32), array(0.3349946, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 59 / 390 d1= 0.9480947 d2= 0.952981 g= [array(0.952981, dtype=float32), array(0.952981, dtype=float32), array(0.33540785, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 60 / 390 d1= 0.9506752 d2= 0.9558065 g= [array(0.9558065, dtype=float32), array(0.9558065, dtype=float32), array(0.33528647, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 61 / 390 d1= 0.9535351 d2= 0.9585694 g= [array(0.9585694, dtype=float32), array(0.9585694, dtype=float32), array(0.33606556, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 62 / 390 d1= 0.95627016 d2= 0.9612207 g= [array(0.9612207, dtype=float32), array(0.9612207, dtype=float32), array(0.33681956, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 63 / 390 d1= 0.95899534 d2= 0.963719 g= [array(0.963719, dtype=float32), array(0.963719, dtype=float32), array(0.33630952, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 64 / 390 d1= 0.96139383 d2= 0.9661544 g= [array(0.9661544, dtype=float32), array(0.9661544, dtype=float32), array(0.33618164, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 65 / 390 d1= 0.96391714 d2= 0.96862394 g= [array(0.96862394, dtype=float32), array(0.96862394, dtype=float32), array(0.3361779, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 66 / 390 d1= 0.96639514 d2= 0.9708185 g= [array(0.9708185, dtype=float32), array(0.9708185, dtype=float32), array(0.33570075, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 67 / 390 d1= 0.9685957 d2= 0.97330624 g= [array(0.97330624, dtype=float32), array(0.97330624, dtype=float32), array(0.33605412, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 68 / 390 d1= 0.9711593 d2= 0.9757141 g= [array(0.9757141, dtype=float32), array(0.9757141, dtype=float32), array(0.33547795, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 69 / 390 d1= 0.97352046 d2= 0.9780863 g= [array(0.9780863, dtype=float32), array(0.9780863, dtype=float32), array(0.33537138, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 70 / 390 d1= 0.97587144 d2= 0.9804136 g= [array(0.9804136, dtype=float32), array(0.9804136, dtype=float32), array(0.3360491, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 71 / 390 d1= 0.9783453 d2= 0.98286813 g= [array(0.98286813, dtype=float32), array(0.98286813, dtype=float32), array(0.33560738, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 72 / 390 d1= 0.980701 d2= 0.9850435 g= [array(0.9850435, dtype=float32), array(0.9850435, dtype=float32), array(0.33572048, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 73 / 390 d1= 0.9829513 d2= 0.9873879 g= [array(0.9873879, dtype=float32), array(0.9873879, dtype=float32), array(0.3348673, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 74 / 390 d1= 0.9852862 d2= 0.9895825 g= [array(0.9895825, dtype=float32), array(0.9895825, dtype=float32), array(0.33445945, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 75 / 390 d1= 0.9874359 d2= 0.99157226 g= [array(0.99157226, dtype=float32), array(0.99157226, dtype=float32), array(0.335, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 76 / 390 d1= 0.98950183 d2= 0.99376947 g= [array(0.99376947, dtype=float32), array(0.99376947, dtype=float32), array(0.33501235, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 77 / 390 d1= 0.99165934 d2= 0.9960444 g= [array(0.9960444, dtype=float32), array(0.9960444, dtype=float32), array(0.3354302, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 78 / 390 d1= 0.99397385 d2= 0.9982703 g= [array(0.9982703, dtype=float32), array(0.9982703, dtype=float32), array(0.33573717, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 79 / 390 d1= 0.9962015 d2= 1.000292 g= [array(1.000292, dtype=float32), array(1.000292, dtype=float32), array(0.33554193, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 80 / 390 d1= 0.99826646 d2= 1.0024036 g= [array(1.0024036, dtype=float32), array(1.0024036, dtype=float32), array(0.33544922, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 81 / 390 d1= 1.0003935 d2= 1.0044197 g= [array(1.0044197, dtype=float32), array(1.0044197, dtype=float32), array(0.33526236, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 82 / 390 d1= 1.0024306 d2= 1.0065045 g= [array(1.0065045, dtype=float32), array(1.0065045, dtype=float32), array(0.33527058, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 83 / 390 d1= 1.0044599 d2= 1.008759 g= [array(1.008759, dtype=float32), array(1.008759, dtype=float32), array(0.33565512, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 84 / 390 d1= 1.0067288 d2= 1.0107199 g= [array(1.0107199, dtype=float32), array(1.0107199, dtype=float32), array(0.3360305, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 85 / 390 d1= 1.0087372 d2= 1.0127962 g= [array(1.0127962, dtype=float32), array(1.0127962, dtype=float32), array(0.3360294, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 86 / 390 d1= 1.0107733 d2= 1.0148716 g= [array(1.0148716, dtype=float32), array(1.0148716, dtype=float32), array(0.33630088, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 87 / 390 d1= 1.0128291 d2= 1.0168359 g= [array(1.0168359, dtype=float32), array(1.0168359, dtype=float32), array(0.3370151, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 88 / 390 d1= 1.0148516 d2= 1.0189176 g= [array(1.0189176, dtype=float32), array(1.0189176, dtype=float32), array(0.33700284, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 89 / 390 d1= 1.0169356 d2= 1.0209475 g= [array(1.0209475, dtype=float32), array(1.0209475, dtype=float32), array(0.337342, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 90 / 390 d1= 1.0189993 d2= 1.0230898 g= [array(1.0230898, dtype=float32), array(1.0230898, dtype=float32), array(0.33732638, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 91 / 390 d1= 1.021164 d2= 1.0250022 g= [array(1.0250022, dtype=float32), array(1.0250022, dtype=float32), array(0.33756867, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 92 / 390 d1= 1.0230669 d2= 1.027115 g= [array(1.027115, dtype=float32), array(1.027115, dtype=float32), array(0.33789062, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 93 / 390 d1= 1.0252291 d2= 1.029145 g= [array(1.029145, dtype=float32), array(1.029145, dtype=float32), array(0.3375336, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 94 / 390 d1= 1.0272986 d2= 1.0312278 g= [array(1.0312278, dtype=float32), array(1.0312278, dtype=float32), array(0.33718416, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 95 / 390 d1= 1.0293574 d2= 1.0331833 g= [array(1.0331833, dtype=float32), array(1.0331833, dtype=float32), array(0.33717105, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 96 / 390 d1= 1.0312699 d2= 1.0351145 g= [array(1.0351145, dtype=float32), array(1.0351145, dtype=float32), array(0.33764648, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 97 / 390 d1= 1.0332074 d2= 1.0369077 g= [array(1.0369077, dtype=float32), array(1.0369077, dtype=float32), array(0.33754832, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 98 / 390 d1= 1.0350366 d2= 1.0386525 g= [array(1.0386525, dtype=float32), array(1.0386525, dtype=float32), array(0.3380899, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 99 / 390 d1= 1.0368255 d2= 1.0404348 g= [array(1.0404348, dtype=float32), array(1.0404348, dtype=float32), array(0.33783144, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 100 / 390 d1= 1.0385859 d2= 1.0422989 g= [array(1.0422989, dtype=float32), array(1.0422989, dtype=float32), array(0.33773437, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 101 / 390 d1= 1.0404717 d2= 1.0443891 g= [array(1.0443891, dtype=float32), array(1.0443891, dtype=float32), array(0.33787128, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 102 / 390 d1= 1.0426184 d2= 1.0463686 g= [array(1.0463686, dtype=float32), array(1.0463686, dtype=float32), array(0.33754596, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 103 / 390 d1= 1.0445642 d2= 1.0482535 g= [array(1.0482535, dtype=float32), array(1.0482535, dtype=float32), array(0.3374545, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 104 / 390 d1= 1.0464586 d2= 1.0500039 g= [array(1.0500039, dtype=float32), array(1.0500039, dtype=float32), array(0.33721453, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 105 / 390 d1= 1.0482032 d2= 1.0519638 g= [array(1.0519638, dtype=float32), array(1.0519638, dtype=float32), array(0.33720237, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 106 / 390 d1= 1.0501399 d2= 1.0537018 g= [array(1.0537018, dtype=float32), array(1.0537018, dtype=float32), array(0.33741155, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 107 / 390 d1= 1.0518732 d2= 1.0554507 g= [array(1.0554507, dtype=float32), array(1.0554507, dtype=float32), array(0.33776286, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 108 / 390 d1= 1.0537298 d2= 1.0571465 g= [array(1.0571465, dtype=float32), array(1.0571465, dtype=float32), array(0.33760127, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 109 / 390 d1= 1.0553442 d2= 1.0590352 g= [array(1.0590352, dtype=float32), array(1.0590352, dtype=float32), array(0.33801606, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 110 / 390 d1= 1.0572777 d2= 1.060949 g= [array(1.060949, dtype=float32), array(1.060949, dtype=float32), array(0.33792615, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 111 / 390 d1= 1.059237 d2= 1.0628419 g= [array(1.0628419, dtype=float32), array(1.0628419, dtype=float32), array(0.33769706, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 112 / 390 d1= 1.0611448 d2= 1.0648305 g= [array(1.0648305, dtype=float32), array(1.0648305, dtype=float32), array(0.33768135, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 113 / 390 d1= 1.0630894 d2= 1.0667144 g= [array(1.0667144, dtype=float32), array(1.0667144, dtype=float32), array(0.3378042, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 114 / 390 d1= 1.0650146 d2= 1.0684191 g= [array(1.0684191, dtype=float32), array(1.0684191, dtype=float32), array(0.33765078, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 115 / 390 d1= 1.0667224 d2= 1.0702516 g= [array(1.0702516, dtype=float32), array(1.0702516, dtype=float32), array(0.33763587, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 116 / 390 d1= 1.0685201 d2= 1.0719562 g= [array(1.0719562, dtype=float32), array(1.0719562, dtype=float32), array(0.33775592, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 117 / 390 d1= 1.0702759 d2= 1.0738058 g= [array(1.0738058, dtype=float32), array(1.0738058, dtype=float32), array(0.33787394, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 118 / 390 d1= 1.0720834 d2= 1.0755656 g= [array(1.0755656, dtype=float32), array(1.0755656, dtype=float32), array(0.33818856, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 119 / 390 d1= 1.0739133 d2= 1.0773226 g= [array(1.0773226, dtype=float32), array(1.0773226, dtype=float32), array(0.33777574, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 120 / 390 d1= 1.0756825 d2= 1.0790681 g= [array(1.0790681, dtype=float32), array(1.0790681, dtype=float32), array(0.3376953, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 121 / 390 d1= 1.07741 d2= 1.0808889 g= [array(1.0808889, dtype=float32), array(1.0808889, dtype=float32), array(0.3374871, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 122 / 390 d1= 1.0792023 d2= 1.0824941 g= [array(1.0824941, dtype=float32), array(1.0824941, dtype=float32), array(0.33785862, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 123 / 390 d1= 1.0808274 d2= 1.0841981 g= [array(1.0841981, dtype=float32), array(1.0841981, dtype=float32), array(0.33816057, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 124 / 390 d1= 1.0825732 d2= 1.0860213 g= [array(1.0860213, dtype=float32), array(1.0860213, dtype=float32), array(0.33782762, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 125 / 390 d1= 1.0843682 d2= 1.0876584 g= [array(1.0876584, dtype=float32), array(1.0876584, dtype=float32), array(0.3379375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 126 / 390 d1= 1.0860162 d2= 1.0892614 g= [array(1.0892614, dtype=float32), array(1.0892614, dtype=float32), array(0.33816963, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 127 / 390 d1= 1.087676 d2= 1.0909939 g= [array(1.0909939, dtype=float32), array(1.0909939, dtype=float32), array(0.3378445, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 128 / 390 d1= 1.0893435 d2= 1.0925968 g= [array(1.0925968, dtype=float32), array(1.0925968, dtype=float32), array(0.33813477, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 129 / 390 d1= 1.0909566 d2= 1.0942899 g= [array(1.0942899, dtype=float32), array(1.0942899, dtype=float32), array(0.33829942, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 130 / 390 d1= 1.0926535 d2= 1.0961208 g= [array(1.0961208, dtype=float32), array(1.0961208, dtype=float32), array(0.33840144, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 131 / 390 d1= 1.0945022 d2= 1.0978426 g= [array(1.0978426, dtype=float32), array(1.0978426, dtype=float32), array(0.33862117, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 132 / 390 d1= 1.0962087 d2= 1.0995322 g= [array(1.0995322, dtype=float32), array(1.0995322, dtype=float32), array(0.33901516, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 133 / 390 d1= 1.097955 d2= 1.1011276 g= [array(1.1011276, dtype=float32), array(1.1011276, dtype=float32), array(0.338992, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 134 / 390 d1= 1.0995415 d2= 1.1028471 g= [array(1.1028471, dtype=float32), array(1.1028471, dtype=float32), array(0.3388526, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 135 / 390 d1= 1.1012632 d2= 1.1044397 g= [array(1.1044397, dtype=float32), array(1.1044397, dtype=float32), array(0.33877316, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 136 / 390 d1= 1.102872 d2= 1.106063 g= [array(1.106063, dtype=float32), array(1.106063, dtype=float32), array(0.33846506, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 137 / 390 d1= 1.1044693 d2= 1.1076177 g= [array(1.1076177, dtype=float32), array(1.1076177, dtype=float32), array(0.33878878, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 138 / 390 d1= 1.1060175 d2= 1.1090423 g= [array(1.1090423, dtype=float32), array(1.1090423, dtype=float32), array(0.33876812, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 139 / 390 d1= 1.1074592 d2= 1.1105047 g= [array(1.1105047, dtype=float32), array(1.1105047, dtype=float32), array(0.3391412, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 140 / 390 d1= 1.1089576 d2= 1.1120789 g= [array(1.1120789, dtype=float32), array(1.1120789, dtype=float32), array(0.3389509, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 141 / 390 d1= 1.1105355 d2= 1.1136265 g= [array(1.1136265, dtype=float32), array(1.1136265, dtype=float32), array(0.3387633, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 142 / 390 d1= 1.1120559 d2= 1.1152229 g= [array(1.1152229, dtype=float32), array(1.1152229, dtype=float32), array(0.3390185, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 143 / 390 d1= 1.1136413 d2= 1.1167486 g= [array(1.1167486, dtype=float32), array(1.1167486, dtype=float32), array(0.3392701, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 144 / 390 d1= 1.1152223 d2= 1.1183554 g= [array(1.1183554, dtype=float32), array(1.1183554, dtype=float32), array(0.33924696, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 145 / 390 d1= 1.1168125 d2= 1.1199284 g= [array(1.1199284, dtype=float32), array(1.1199284, dtype=float32), array(0.33943966, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 146 / 390 d1= 1.1184466 d2= 1.1215223 g= [array(1.1215223, dtype=float32), array(1.1215223, dtype=float32), array(0.33882704, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 147 / 390 d1= 1.1200377 d2= 1.1231557 g= [array(1.1231557, dtype=float32), array(1.1231557, dtype=float32), array(0.3387011, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 148 / 390 d1= 1.1216319 d2= 1.1247443 g= [array(1.1247443, dtype=float32), array(1.1247443, dtype=float32), array(0.33873522, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 149 / 390 d1= 1.1232513 d2= 1.1263393 g= [array(1.1263393, dtype=float32), array(1.1263393, dtype=float32), array(0.33855915, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 150 / 390 d1= 1.1248196 d2= 1.1278895 g= [array(1.1278895, dtype=float32), array(1.1278895, dtype=float32), array(0.33864585, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 151 / 390 d1= 1.1263775 d2= 1.1294359 g= [array(1.1294359, dtype=float32), array(1.1294359, dtype=float32), array(0.33867964, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 152 / 390 d1= 1.127917 d2= 1.1309054 g= [array(1.1309054, dtype=float32), array(1.1309054, dtype=float32), array(0.3389186, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 153 / 390 d1= 1.1293991 d2= 1.1323336 g= [array(1.1323336, dtype=float32), array(1.1323336, dtype=float32), array(0.3390523, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 154 / 390 d1= 1.1308293 d2= 1.1338121 g= [array(1.1338121, dtype=float32), array(1.1338121, dtype=float32), array(0.33908278, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 155 / 390 d1= 1.1323314 d2= 1.1352491 g= [array(1.1352491, dtype=float32), array(1.1352491, dtype=float32), array(0.3390625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 156 / 390 d1= 1.1337653 d2= 1.1366426 g= [array(1.1366426, dtype=float32), array(1.1366426, dtype=float32), array(0.33904245, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 157 / 390 d1= 1.1351604 d2= 1.1381401 g= [array(1.1381401, dtype=float32), array(1.1381401, dtype=float32), array(0.33907247, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 158 / 390 d1= 1.136663 d2= 1.1396405 g= [array(1.1396405, dtype=float32), array(1.1396405, dtype=float32), array(0.33900318, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 159 / 390 d1= 1.13821 d2= 1.1410937 g= [array(1.1410937, dtype=float32), array(1.1410937, dtype=float32), array(0.33849254, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 160 / 390 d1= 1.1396366 d2= 1.1425698 g= [array(1.1425698, dtype=float32), array(1.1425698, dtype=float32), array(0.3383789, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 161 / 390 d1= 1.141116 d2= 1.1439668 g= [array(1.1439668, dtype=float32), array(1.1439668, dtype=float32), array(0.33831522, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 162 / 390 d1= 1.142513 d2= 1.1453677 g= [array(1.1453677, dtype=float32), array(1.1453677, dtype=float32), array(0.3382523, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 163 / 390 d1= 1.1439325 d2= 1.14684 g= [array(1.14684, dtype=float32), array(1.14684, dtype=float32), array(0.33828604, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 164 / 390 d1= 1.1453817 d2= 1.1481787 g= [array(1.1481787, dtype=float32), array(1.1481787, dtype=float32), array(0.338367, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 165 / 390 d1= 1.1467266 d2= 1.1496274 g= [array(1.1496274, dtype=float32), array(1.1496274, dtype=float32), array(0.33839962, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 166 / 390 d1= 1.1481878 d2= 1.1508511 g= [array(1.1508511, dtype=float32), array(1.1508511, dtype=float32), array(0.33857304, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 167 / 390 d1= 1.1494405 d2= 1.1522628 g= [array(1.1522628, dtype=float32), array(1.1522628, dtype=float32), array(0.3384169, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 168 / 390 d1= 1.1508647 d2= 1.1535922 g= [array(1.1535922, dtype=float32), array(1.1535922, dtype=float32), array(0.33835566, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 169 / 390 d1= 1.1521703 d2= 1.1549759 g= [array(1.1549759, dtype=float32), array(1.1549759, dtype=float32), array(0.33838758, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 170 / 390 d1= 1.1535867 d2= 1.1563876 g= [array(1.1563876, dtype=float32), array(1.1563876, dtype=float32), array(0.33818933, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 171 / 390 d1= 1.1549865 d2= 1.1577842 g= [array(1.1577842, dtype=float32), array(1.1577842, dtype=float32), array(0.3379934, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 172 / 390 d1= 1.1563594 d2= 1.159115 g= [array(1.159115, dtype=float32), array(1.159115, dtype=float32), array(0.3380723, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 173 / 390 d1= 1.1577412 d2= 1.1605108 g= [array(1.1605108, dtype=float32), array(1.1605108, dtype=float32), array(0.33774385, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 174 / 390 d1= 1.1591346 d2= 1.1619194 g= [array(1.1619194, dtype=float32), array(1.1619194, dtype=float32), array(0.3375539, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 175 / 390 d1= 1.1605062 d2= 1.1631929 g= [array(1.1631929, dtype=float32), array(1.1631929, dtype=float32), array(0.33767858, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 176 / 390 d1= 1.1617992 d2= 1.1643941 g= [array(1.1643941, dtype=float32), array(1.1643941, dtype=float32), array(0.33780184, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 177 / 390 d1= 1.1629882 d2= 1.165751 g= [array(1.165751, dtype=float32), array(1.165751, dtype=float32), array(0.3378796, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 178 / 390 d1= 1.1643701 d2= 1.167094 g= [array(1.167094, dtype=float32), array(1.167094, dtype=float32), array(0.33791256, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 179 / 390 d1= 1.165716 d2= 1.1682982 g= [array(1.1682982, dtype=float32), array(1.1682982, dtype=float32), array(0.33803248, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 180 / 390 d1= 1.1669142 d2= 1.1696087 g= [array(1.1696087, dtype=float32), array(1.1696087, dtype=float32), array(0.33815104, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 181 / 390 d1= 1.1682413 d2= 1.1708589 g= [array(1.1708589, dtype=float32), array(1.1708589, dtype=float32), array(0.33813882, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 182 / 390 d1= 1.1694816 d2= 1.1720178 g= [array(1.1720178, dtype=float32), array(1.1720178, dtype=float32), array(0.33816963, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 183 / 390 d1= 1.1706673 d2= 1.1732523 g= [array(1.1732523, dtype=float32), array(1.1732523, dtype=float32), array(0.33777323, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 184 / 390 d1= 1.1718915 d2= 1.174421 g= [array(1.174421, dtype=float32), array(1.174421, dtype=float32), array(0.33789062, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 185 / 390 d1= 1.1730688 d2= 1.1756425 g= [array(1.1756425, dtype=float32), array(1.1756425, dtype=float32), array(0.33779562, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 186 / 390 d1= 1.1743035 d2= 1.1768125 g= [array(1.1768125, dtype=float32), array(1.1768125, dtype=float32), array(0.3376176, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 187 / 390 d1= 1.1754647 d2= 1.1780488 g= [array(1.1780488, dtype=float32), array(1.1780488, dtype=float32), array(0.3374415, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 188 / 390 d1= 1.1767056 d2= 1.1792591 g= [array(1.1792591, dtype=float32), array(1.1792591, dtype=float32), array(0.33739194, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 189 / 390 d1= 1.1779342 d2= 1.1805166 g= [array(1.1805166, dtype=float32), array(1.1805166, dtype=float32), array(0.33726025, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 190 / 390 d1= 1.1791811 d2= 1.18172 g= [array(1.18172, dtype=float32), array(1.18172, dtype=float32), array(0.3372944, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 191 / 390 d1= 1.1804008 d2= 1.1829436 g= [array(1.1829436, dtype=float32), array(1.1829436, dtype=float32), array(0.3372873, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 192 / 390 d1= 1.1816189 d2= 1.1841639 g= [array(1.1841639, dtype=float32), array(1.1841639, dtype=float32), array(0.33728027, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 193 / 390 d1= 1.1828463 d2= 1.1853195 g= [array(1.1853195, dtype=float32), array(1.1853195, dtype=float32), array(0.33723283, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 194 / 390 d1= 1.1840172 d2= 1.1864377 g= [array(1.1864377, dtype=float32), array(1.1864377, dtype=float32), array(0.33698454, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 195 / 390 d1= 1.1851225 d2= 1.1875116 g= [array(1.1875116, dtype=float32), array(1.1875116, dtype=float32), array(0.33709937, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 196 / 390 d1= 1.1861961 d2= 1.1886523 g= [array(1.1886523, dtype=float32), array(1.1886523, dtype=float32), array(0.33709344, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 197 / 390 d1= 1.1873606 d2= 1.1897393 g= [array(1.1897393, dtype=float32), array(1.1897393, dtype=float32), array(0.33688927, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 198 / 390 d1= 1.1884382 d2= 1.1909659 g= [array(1.1909659, dtype=float32), array(1.1909659, dtype=float32), array(0.3369634, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 199 / 390 d1= 1.1896751 d2= 1.1921264 g= [array(1.1921264, dtype=float32), array(1.1921264, dtype=float32), array(0.3368797, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 200 / 390 d1= 1.1908306 d2= 1.1931871 g= [array(1.1931871, dtype=float32), array(1.1931871, dtype=float32), array(0.33679688, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 201 / 390 d1= 1.1918795 d2= 1.1942182 g= [array(1.1942182, dtype=float32), array(1.1942182, dtype=float32), array(0.33694807, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 202 / 390 d1= 1.1929318 d2= 1.19532 g= [array(1.19532, dtype=float32), array(1.19532, dtype=float32), array(0.33678836, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 203 / 390 d1= 1.1940377 d2= 1.1963366 g= [array(1.1963366, dtype=float32), array(1.1963366, dtype=float32), array(0.33678418, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 204 / 390 d1= 1.19506 d2= 1.1974555 g= [array(1.1974555, dtype=float32), array(1.1974555, dtype=float32), array(0.3368183, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 205 / 390 d1= 1.1961989 d2= 1.1985914 g= [array(1.1985914, dtype=float32), array(1.1985914, dtype=float32), array(0.33666158, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 206 / 390 d1= 1.1972857 d2= 1.1997007 g= [array(1.1997007, dtype=float32), array(1.1997007, dtype=float32), array(0.33692354, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 207 / 390 d1= 1.1984115 d2= 1.2007141 g= [array(1.2007141, dtype=float32), array(1.2007141, dtype=float32), array(0.33706975, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 208 / 390 d1= 1.1994504 d2= 1.20184 g= [array(1.20184, dtype=float32), array(1.20184, dtype=float32), array(0.33710188, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 209 / 390 d1= 1.200576 d2= 1.2029005 g= [array(1.2029005, dtype=float32), array(1.2029005, dtype=float32), array(0.33713368, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 210 / 390 d1= 1.2016443 d2= 1.204039 g= [array(1.204039, dtype=float32), array(1.204039, dtype=float32), array(0.33709076, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 211 / 390 d1= 1.2028065 d2= 1.2050749 g= [array(1.2050749, dtype=float32), array(1.2050749, dtype=float32), array(0.3369372, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 212 / 390 d1= 1.2038256 d2= 1.2061349 g= [array(1.2061349, dtype=float32), array(1.2061349, dtype=float32), array(0.33696935, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 213 / 390 d1= 1.2048928 d2= 1.2071577 g= [array(1.2071577, dtype=float32), array(1.2071577, dtype=float32), array(0.33692783, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 214 / 390 d1= 1.2059149 d2= 1.2081009 g= [array(1.2081009, dtype=float32), array(1.2081009, dtype=float32), array(0.33674064, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 215 / 390 d1= 1.2068505 d2= 1.2091618 g= [array(1.2091618, dtype=float32), array(1.2091618, dtype=float32), array(0.33666423, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 216 / 390 d1= 1.2079043 d2= 1.2101752 g= [array(1.2101752, dtype=float32), array(1.2101752, dtype=float32), array(0.33680555, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 217 / 390 d1= 1.2089462 d2= 1.2111919 g= [array(1.2111919, dtype=float32), array(1.2111919, dtype=float32), array(0.33680156, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 218 / 390 d1= 1.2099648 d2= 1.2121761 g= [array(1.2121761, dtype=float32), array(1.2121761, dtype=float32), array(0.33665425, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 219 / 390 d1= 1.2109288 d2= 1.2131227 g= [array(1.2131227, dtype=float32), array(1.2131227, dtype=float32), array(0.33690068, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 220 / 390 d1= 1.2119095 d2= 1.2141495 g= [array(1.2141495, dtype=float32), array(1.2141495, dtype=float32), array(0.3368608, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 221 / 390 d1= 1.2129189 d2= 1.2150615 g= [array(1.2150615, dtype=float32), array(1.2150615, dtype=float32), array(0.33682126, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 222 / 390 d1= 1.213844 d2= 1.2160351 g= [array(1.2160351, dtype=float32), array(1.2160351, dtype=float32), array(0.3367469, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 223 / 390 d1= 1.2148184 d2= 1.2170196 g= [array(1.2170196, dtype=float32), array(1.2170196, dtype=float32), array(0.33674327, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 224 / 390 d1= 1.2158183 d2= 1.2179892 g= [array(1.2179892, dtype=float32), array(1.2179892, dtype=float32), array(0.33663505, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 225 / 390 d1= 1.2167825 d2= 1.2189703 g= [array(1.2189703, dtype=float32), array(1.2189703, dtype=float32), array(0.33666667, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 226 / 390 d1= 1.2177582 d2= 1.2198557 g= [array(1.2198557, dtype=float32), array(1.2198557, dtype=float32), array(0.33673257, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 227 / 390 d1= 1.2186301 d2= 1.2208463 g= [array(1.2208463, dtype=float32), array(1.2208463, dtype=float32), array(0.33686674, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 228 / 390 d1= 1.2196418 d2= 1.2217798 g= [array(1.2217798, dtype=float32), array(1.2217798, dtype=float32), array(0.337034, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 229 / 390 d1= 1.2205822 d2= 1.2227851 g= [array(1.2227851, dtype=float32), array(1.2227851, dtype=float32), array(0.33689275, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 230 / 390 d1= 1.2215945 d2= 1.223735 g= [array(1.223735, dtype=float32), array(1.223735, dtype=float32), array(0.3366848, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 231 / 390 d1= 1.2225305 d2= 1.2246851 g= [array(1.2246851, dtype=float32), array(1.2246851, dtype=float32), array(0.33681682, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 232 / 390 d1= 1.223493 d2= 1.22562 g= [array(1.22562, dtype=float32), array(1.22562, dtype=float32), array(0.33674568, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 233 / 390 d1= 1.2244222 d2= 1.2265798 g= [array(1.2265798, dtype=float32), array(1.2265798, dtype=float32), array(0.33674222, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 234 / 390 d1= 1.2253885 d2= 1.2275784 g= [array(1.2275784, dtype=float32), array(1.2275784, dtype=float32), array(0.33677217, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 235 / 390 d1= 1.2263967 d2= 1.228461 g= [array(1.228461, dtype=float32), array(1.228461, dtype=float32), array(0.33673537, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 236 / 390 d1= 1.2272666 d2= 1.2293673 g= [array(1.2293673, dtype=float32), array(1.2293673, dtype=float32), array(0.33689752, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 237 / 390 d1= 1.2281919 d2= 1.2301948 g= [array(1.2301948, dtype=float32), array(1.2301948, dtype=float32), array(0.33679456, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 238 / 390 d1= 1.2290225 d2= 1.2310381 g= [array(1.2310381, dtype=float32), array(1.2310381, dtype=float32), array(0.3369551, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 239 / 390 d1= 1.2298741 d2= 1.2319467 g= [array(1.2319467, dtype=float32), array(1.2319467, dtype=float32), array(0.33698353, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 240 / 390 d1= 1.2307816 d2= 1.2328372 g= [array(1.2328372, dtype=float32), array(1.2328372, dtype=float32), array(0.33704427, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 241 / 390 d1= 1.2316681 d2= 1.2337269 g= [array(1.2337269, dtype=float32), array(1.2337269, dtype=float32), array(0.3371045, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 242 / 390 d1= 1.2325774 d2= 1.2346556 g= [array(1.2346556, dtype=float32), array(1.2346556, dtype=float32), array(0.3370997, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 243 / 390 d1= 1.2335012 d2= 1.2355019 g= [array(1.2355019, dtype=float32), array(1.2355019, dtype=float32), array(0.33725566, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 244 / 390 d1= 1.2343655 d2= 1.2363291 g= [array(1.2363291, dtype=float32), array(1.2363291, dtype=float32), array(0.33712217, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 245 / 390 d1= 1.235189 d2= 1.2371846 g= [array(1.2371846, dtype=float32), array(1.2371846, dtype=float32), array(0.336926, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 246 / 390 d1= 1.2360495 d2= 1.2380742 g= [array(1.2380742, dtype=float32), array(1.2380742, dtype=float32), array(0.33679497, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 247 / 390 d1= 1.2369382 d2= 1.2389696 g= [array(1.2389696, dtype=float32), array(1.2389696, dtype=float32), array(0.33682314, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 248 / 390 d1= 1.2378404 d2= 1.23984 g= [array(1.23984, dtype=float32), array(1.23984, dtype=float32), array(0.33685106, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 249 / 390 d1= 1.2387075 d2= 1.240698 g= [array(1.240698, dtype=float32), array(1.240698, dtype=float32), array(0.336816, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 250 / 390 d1= 1.2395426 d2= 1.2414875 g= [array(1.2414875, dtype=float32), array(1.2414875, dtype=float32), array(0.33696875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 251 / 390 d1= 1.2403487 d2= 1.2423588 g= [array(1.2423588, dtype=float32), array(1.2423588, dtype=float32), array(0.33690238, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 252 / 390 d1= 1.2412245 d2= 1.2431765 g= [array(1.2431765, dtype=float32), array(1.2431765, dtype=float32), array(0.33692956, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# ...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 96 / 390 d1= 1.5755527 d2= 1.575772 g= [array(1.575772, dtype=float32), array(1.575772, dtype=float32), array(0.33704075, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 97 / 390 d1= 1.5755869 d2= 1.5758104 g= [array(1.5758104, dtype=float32), array(1.5758104, dtype=float32), array(0.33705312, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 98 / 390 d1= 1.5756259 d2= 1.5758532 g= [array(1.5758532, dtype=float32), array(1.5758532, dtype=float32), array(0.33704305, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 99 / 390 d1= 1.5756688 d2= 1.5758867 g= [array(1.5758867, dtype=float32), array(1.5758867, dtype=float32), array(0.337049, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 100 / 390 d1= 1.5757014 d2= 1.5759228 g= [array(1.5759228, dtype=float32), array(1.5759228, dtype=float32), array(0.33704853, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 101 / 390 d1= 1.5757372 d2= 1.5759592 g= [array(1.5759592, dtype=float32), array(1.5759592, dtype=float32), array(0.3370641, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 102 / 390 d1= 1.5757748 d2= 1.5759985 g= [array(1.5759985, dtype=float32), array(1.5759985, dtype=float32), array(0.33705083, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 103 / 390 d1= 1.5758159 d2= 1.5760373 g= [array(1.5760373, dtype=float32), array(1.5760373, dtype=float32), array(0.33704397, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 104 / 390 d1= 1.5758526 d2= 1.5760694 g= [array(1.5760694, dtype=float32), array(1.5760694, dtype=float32), array(0.33703074, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 105 / 390 d1= 1.5758855 d2= 1.5761119 g= [array(1.5761119, dtype=float32), array(1.5761119, dtype=float32), array(0.3370175, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 106 / 390 d1= 1.5759276 d2= 1.5761458 g= [array(1.5761458, dtype=float32), array(1.5761458, dtype=float32), array(0.33701706, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 107 / 390 d1= 1.5759617 d2= 1.5761844 g= [array(1.5761844, dtype=float32), array(1.5761844, dtype=float32), array(0.33701342, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 108 / 390 d1= 1.5760019 d2= 1.5762208 g= [array(1.5762208, dtype=float32), array(1.5762208, dtype=float32), array(0.33699384, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 109 / 390 d1= 1.5760388 d2= 1.5762562 g= [array(1.5762562, dtype=float32), array(1.5762562, dtype=float32), array(0.3369679, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 110 / 390 d1= 1.5760714 d2= 1.576291 g= [array(1.576291, dtype=float32), array(1.576291, dtype=float32), array(0.3369866, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 111 / 390 d1= 1.5761079 d2= 1.5763319 g= [array(1.5763319, dtype=float32), array(1.5763319, dtype=float32), array(0.3369798, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 112 / 390 d1= 1.5761468 d2= 1.5763645 g= [array(1.5763645, dtype=float32), array(1.5763645, dtype=float32), array(0.33698258, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 113 / 390 d1= 1.5761818 d2= 1.5763981 g= [array(1.5763981, dtype=float32), array(1.5763981, dtype=float32), array(0.3369694, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 114 / 390 d1= 1.576215 d2= 1.5764397 g= [array(1.5764397, dtype=float32), array(1.5764397, dtype=float32), array(0.33697852, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 115 / 390 d1= 1.5762568 d2= 1.5764797 g= [array(1.5764797, dtype=float32), array(1.5764797, dtype=float32), array(0.33696857, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 116 / 390 d1= 1.576294 d2= 1.5765125 g= [array(1.5765125, dtype=float32), array(1.5765125, dtype=float32), array(0.33698085, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 117 / 390 d1= 1.5763294 d2= 1.5765504 g= [array(1.5765504, dtype=float32), array(1.5765504, dtype=float32), array(0.33698043, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 118 / 390 d1= 1.5763671 d2= 1.5765866 g= [array(1.5765866, dtype=float32), array(1.5765866, dtype=float32), array(0.33698002, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 119 / 390 d1= 1.5763999 d2= 1.5766106 g= [array(1.5766106, dtype=float32), array(1.5766106, dtype=float32), array(0.33701453, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 120 / 390 d1= 1.5764279 d2= 1.5766482 g= [array(1.5766482, dtype=float32), array(1.5766482, dtype=float32), array(0.33700776, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 121 / 390 d1= 1.5764657 d2= 1.5766879 g= [array(1.5766879, dtype=float32), array(1.5766879, dtype=float32), array(0.33699778, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 122 / 390 d1= 1.5765051 d2= 1.576717 g= [array(1.576717, dtype=float32), array(1.576717, dtype=float32), array(0.3369942, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 123 / 390 d1= 1.5765351 d2= 1.5767523 g= [array(1.5767523, dtype=float32), array(1.5767523, dtype=float32), array(0.33699375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 124 / 390 d1= 1.57657 d2= 1.5767854 g= [array(1.5767854, dtype=float32), array(1.5767854, dtype=float32), array(0.33699334, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 125 / 390 d1= 1.5766025 d2= 1.5768132 g= [array(1.5768132, dtype=float32), array(1.5768132, dtype=float32), array(0.3370024, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 126 / 390 d1= 1.5766313 d2= 1.576849 g= [array(1.576849, dtype=float32), array(1.576849, dtype=float32), array(0.33698612, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 127 / 390 d1= 1.5766675 d2= 1.5768791 g= [array(1.5768791, dtype=float32), array(1.5768791, dtype=float32), array(0.33699206, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 128 / 390 d1= 1.5766956 d2= 1.5769079 g= [array(1.5769079, dtype=float32), array(1.5769079, dtype=float32), array(0.33700112, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 129 / 390 d1= 1.5767231 d2= 1.5769374 g= [array(1.5769374, dtype=float32), array(1.5769374, dtype=float32), array(0.33701968, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 130 / 390 d1= 1.5767559 d2= 1.5769713 g= [array(1.5769713, dtype=float32), array(1.5769713, dtype=float32), array(0.33701292, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 131 / 390 d1= 1.5767888 d2= 1.5770063 g= [array(1.5770063, dtype=float32), array(1.5770063, dtype=float32), array(0.3370093, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 132 / 390 d1= 1.5768242 d2= 1.5770526 g= [array(1.5770526, dtype=float32), array(1.5770526, dtype=float32), array(0.3370057, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 133 / 390 d1= 1.5768723 d2= 1.5770898 g= [array(1.5770898, dtype=float32), array(1.5770898, dtype=float32), array(0.33698317, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 134 / 390 d1= 1.5769081 d2= 1.5771319 g= [array(1.5771319, dtype=float32), array(1.5771319, dtype=float32), array(0.3369796, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 135 / 390 d1= 1.576948 d2= 1.5771681 g= [array(1.5771681, dtype=float32), array(1.5771681, dtype=float32), array(0.33698547, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 136 / 390 d1= 1.576986 d2= 1.5772017 g= [array(1.5772017, dtype=float32), array(1.5772017, dtype=float32), array(0.33697873, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 137 / 390 d1= 1.5770204 d2= 1.5772333 g= [array(1.5772333, dtype=float32), array(1.5772333, dtype=float32), array(0.33697203, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 138 / 390 d1= 1.5770519 d2= 1.5772719 g= [array(1.5772719, dtype=float32), array(1.5772719, dtype=float32), array(0.3369653, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 139 / 390 d1= 1.5770904 d2= 1.5773027 g= [array(1.5773027, dtype=float32), array(1.5773027, dtype=float32), array(0.33696172, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 140 / 390 d1= 1.5771216 d2= 1.5773399 g= [array(1.5773399, dtype=float32), array(1.5773399, dtype=float32), array(0.33695817, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 141 / 390 d1= 1.5771581 d2= 1.5773771 g= [array(1.5773771, dtype=float32), array(1.5773771, dtype=float32), array(0.3369609, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 142 / 390 d1= 1.5771949 d2= 1.5774125 g= [array(1.5774125, dtype=float32), array(1.5774125, dtype=float32), array(0.33696362, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 143 / 390 d1= 1.5772301 d2= 1.577444 g= [array(1.577444, dtype=float32), array(1.577444, dtype=float32), array(0.33696324, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 144 / 390 d1= 1.577263 d2= 1.5774763 g= [array(1.5774763, dtype=float32), array(1.5774763, dtype=float32), array(0.33695337, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 145 / 390 d1= 1.5772955 d2= 1.5775156 g= [array(1.5775156, dtype=float32), array(1.5775156, dtype=float32), array(0.33693725, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 146 / 390 d1= 1.5773336 d2= 1.5775465 g= [array(1.5775465, dtype=float32), array(1.5775465, dtype=float32), array(0.3369494, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 147 / 390 d1= 1.5773659 d2= 1.5775813 g= [array(1.5775813, dtype=float32), array(1.5775813, dtype=float32), array(0.33694586, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 148 / 390 d1= 1.5773983 d2= 1.5776066 g= [array(1.5776066, dtype=float32), array(1.5776066, dtype=float32), array(0.3369643, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 149 / 390 d1= 1.5774248 d2= 1.5776398 g= [array(1.5776398, dtype=float32), array(1.5776398, dtype=float32), array(0.33697018, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 150 / 390 d1= 1.5774604 d2= 1.5776727 g= [array(1.5776727, dtype=float32), array(1.5776727, dtype=float32), array(0.33696035, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 151 / 390 d1= 1.5774939 d2= 1.5777066 g= [array(1.5777066, dtype=float32), array(1.5777066, dtype=float32), array(0.33694425, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 152 / 390 d1= 1.5775256 d2= 1.5777429 g= [array(1.5777429, dtype=float32), array(1.5777429, dtype=float32), array(0.33694384, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 153 / 390 d1= 1.5775611 d2= 1.5777763 g= [array(1.5777763, dtype=float32), array(1.5777763, dtype=float32), array(0.33695284, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 154 / 390 d1= 1.5775969 d2= 1.5778131 g= [array(1.5778131, dtype=float32), array(1.5778131, dtype=float32), array(0.33694303, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 155 / 390 d1= 1.5776336 d2= 1.5778474 g= [array(1.5778474, dtype=float32), array(1.5778474, dtype=float32), array(0.33693638, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 156 / 390 d1= 1.5776672 d2= 1.5778823 g= [array(1.5778823, dtype=float32), array(1.5778823, dtype=float32), array(0.33692658, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 157 / 390 d1= 1.5777012 d2= 1.5779159 g= [array(1.5779159, dtype=float32), array(1.5779159, dtype=float32), array(0.33694497, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 158 / 390 d1= 1.5777358 d2= 1.5779546 g= [array(1.5779546, dtype=float32), array(1.5779546, dtype=float32), array(0.3369289, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 159 / 390 d1= 1.5777723 d2= 1.577988 g= [array(1.577988, dtype=float32), array(1.577988, dtype=float32), array(0.33694103, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 160 / 390 d1= 1.5778071 d2= 1.5780263 g= [array(1.5780263, dtype=float32), array(1.5780263, dtype=float32), array(0.3369375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 161 / 390 d1= 1.577846 d2= 1.578057 g= [array(1.578057, dtype=float32), array(1.578057, dtype=float32), array(0.3369246, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 162 / 390 d1= 1.5778766 d2= 1.5780917 g= [array(1.5780917, dtype=float32), array(1.5780917, dtype=float32), array(0.3369398, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 163 / 390 d1= 1.5779123 d2= 1.5781294 g= [array(1.5781294, dtype=float32), array(1.5781294, dtype=float32), array(0.33691445, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 164 / 390 d1= 1.5779483 d2= 1.5781668 g= [array(1.5781668, dtype=float32), array(1.5781668, dtype=float32), array(0.33692965, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 165 / 390 d1= 1.5779885 d2= 1.5782056 g= [array(1.5782056, dtype=float32), array(1.5782056, dtype=float32), array(0.33691368, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 166 / 390 d1= 1.5780268 d2= 1.5782388 g= [array(1.5782388, dtype=float32), array(1.5782388, dtype=float32), array(0.3368977, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 167 / 390 d1= 1.5780592 d2= 1.5782809 g= [array(1.5782809, dtype=float32), array(1.5782809, dtype=float32), array(0.33689108, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 168 / 390 d1= 1.5781019 d2= 1.5783131 g= [array(1.5783131, dtype=float32), array(1.5783131, dtype=float32), array(0.33686888, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 169 / 390 d1= 1.578134 d2= 1.5783466 g= [array(1.5783466, dtype=float32), array(1.5783466, dtype=float32), array(0.3368654, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 170 / 390 d1= 1.5781674 d2= 1.5783796 g= [array(1.5783796, dtype=float32), array(1.5783796, dtype=float32), array(0.33686194, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 171 / 390 d1= 1.5781989 d2= 1.5784092 g= [array(1.5784092, dtype=float32), array(1.5784092, dtype=float32), array(0.33686468, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 172 / 390 d1= 1.5782297 d2= 1.5784415 g= [array(1.5784415, dtype=float32), array(1.5784415, dtype=float32), array(0.33685496, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 173 / 390 d1= 1.5782615 d2= 1.5784769 g= [array(1.5784769, dtype=float32), array(1.5784769, dtype=float32), array(0.3368577, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 174 / 390 d1= 1.5782974 d2= 1.5785146 g= [array(1.5785146, dtype=float32), array(1.5785146, dtype=float32), array(0.33684492, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 175 / 390 d1= 1.578336 d2= 1.5785528 g= [array(1.5785528, dtype=float32), array(1.5785528, dtype=float32), array(0.3368228, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 7 Batch= 176 / 390 d1= 1.5783736 d2= 1.5785965 g= [array(1.5785965, dtype=float32), array(1.5785965, dtype=float32), array(0.33680692, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
from tensorflow.keras.models import load_model

# Now, load the generator model and generate images

# Plot generated images function
def show_plot(examples, n):
    for i in range(n * n):
        plt.subplot(n, n, 1 + i)
        plt.axis('off')
        plt.imshow(examples[i, :, :, :])
    plt.show()

# load model
model = load_model(model_filename) #Model trained for n epochs

# generate the latent vector
latent_points = generate_latent_points(100, 25)  #Latent dim and n_samples

# generate images from the latent vector
X = model.predict(latent_points)

# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
X = (X*255).astype(np.uint8)

# plot the generated images
# Note: CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck
show_plot(X, 5)
