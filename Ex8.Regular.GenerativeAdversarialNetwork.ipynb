# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# # 8th exercise: <font color="#C70039">Work with a regular Generative Adversarial Network (GAN)</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: Gernot Heisenberg
# * Editor of notebook: Lena Pickartz (11330741)
# * Date:   24.11.2024
#
# <img src="https://www.researchgate.net/publication/338509383/figure/fig1/AS:845792709464064@1578664104008/Overview-of-generative-adversarial-network-GAN.ppm" style="float: center;" width="600">
#
# ---------------------------------
# **GENERAL NOTE 1**:
# Please make sure you are reading the entire notebook, since it contains a lot of information on your tasks (e.g. regarding the set of certain paramaters or a specific computational trick), and the written mark downs as well as comments contain a lot of information on how things work together as a whole.
#
# **GENERAL NOTE 2**:
# * Please, when commenting source code, just use English language only.
# * When describing an observation please use English language, too.
# * This applies to all exercises throughout this course.
#
# ---------------------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# The code implements a regular GAN that generates images using a random latent vector as input. While it works great we do not know the mapping of latent vector to the generated image.
#
# Conditional GANs, however, can be used to supply a label during taining so the latent vector can be associated with a specific label - making the generation of images predictable.
#
# The below coded GAN is using the so-called cifar10 data set, which is standard to many machine learning applications (60,000 32x32 color images in 10 different classes: CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck).
# Following the code trains and generates images based on that cifar10 data set, that is included in the Keras package.
# Further information on the data set can be found here: <a href="https://en.wikipedia.org/wiki/CIFAR-10"> cifar10 data set (wiki)</a>
#
# The code is adapted from the code by Jason Brownlee from his blogs on <a href="https://machinelearningmastery.com/">https://machinelearningmastery.com/</a>.
# I seriously urge everyone to follow his blogs and get inspired. Hence, original credit goes to Jason Brownlee.
#
# ---------------------------------
#
# ### <font color="FFC300">TASKS</font>:
# The tasks that you need to work on within this notebook are always indicated below as bullet points.
# If a task is more challenging and consists of several steps, this is indicated as well.
# Make sure you have worked down the task list and commented your doings.
# This should be done by using markdown.<br>
# <font color=red>Make sure you don't forget to specify your name and your matriculation number in the notebook.</font>
#
# **YOUR TASKS in this exercise are as follows**:
# 1. import the notebook to Google Colab or use your local machine.
# 2. make sure you specified you name and your matriculation number in the header below my name and date.
#     * set the date too and remove mine.
# 3. read the entire notebook carefully
#     * add comments whereever you feel it necessary for better understanding
#     * run the notebook for the first time.
# 4. train the GAN with a higher dimension of the latent space and over more epochs. Are the results improving?
# 5. What could be done to further improve the quality of the generated images?
# ---------------------------------

# %% [markdown]
# ### GAN
# #### Imports

# %%
import numpy as np
from numpy import zeros
from numpy import ones
from numpy.random import randn
from numpy.random import randint

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras.datasets.cifar10 import load_data

# this import is needed because there is a problem with the Secure Socket Layer (SSL) certificate,
# It can be resolved using the below line of code
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ### Build the GAN architeture
#
# Use the "functional" way of defining the model for the conditional gan but use "sequential" for descriminator and generator as they are straight forward.

# %% [markdown]
# #### Define the standalone discriminator model
#
# Given an input image, the Discriminator outputs the likelihood of the image being real.
# Binary classification - true or false (1 or 0). So use the sigmoid activation.

# %%
def define_discriminator(in_shape=(32,32,3)):
    model = Sequential(name="discriminator")

    model.add(Conv2D(128, (3,3), strides=(2,2), padding='same', input_shape=in_shape)) #16x16x128
    model.add(LeakyReLU(alpha=0.2))

    model.add(Conv2D(128, (3,3), strides=(2,2), padding='same')) #8x8x128
    model.add(LeakyReLU(alpha=0.2))

    model.add(Flatten()) #shape of 8192
    model.add(Dropout(0.4))
    model.add(Dense(1, activation='sigmoid')) #shape of 1

    # Compile model since it is going to be trained directly and choose the optimizer
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    return model

test_discriminator = define_discriminator()
print(test_discriminator.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 16, 16, 128)         │           3,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │           8,193 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 159,361 (622.50 KB)
#  Trainable params: 159,361 (622.50 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# #### Define the standalone generator model
# Given the latent vector input, the Generator produces an image.(here: 32x32)
# The latent_dim, for example, can be 100, 1D array of size 100.
#
# Only Dense and conv2dlayers are being used. But the network can be more complicated based on the problem you are trying to solve. For example, you can use VGG as the basis for a super resolution GAN.

# %%
#latent_dim is the dimension of the latent vector (e.g., 100 - see below)
def define_generator(latent_dim):

    model = Sequential(name="generator")

    # Reshape the input latent vector into an 8x8 image as a starting point.
    # Hence n_nodes for the Dense layer are e.g. 128x8x8, so when reshaping the output
    # it would be 8x8x128 and that can be slowly upscaled to a 32x32 image as the output.
    n_nodes = 128 * 8 * 8  #8192 nodes
    model.add(Dense(n_nodes, input_dim=latent_dim)) #Dense layer so we can work with a 1D latent vector
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((8, 8, 128)))  #8x8x128 data set from the latent vector.
    # upsample to 16x16
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')) #16x16x128
    model.add(LeakyReLU(alpha=0.2))
    # upsample to 32x32
    model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')) #32x32x128
    model.add(LeakyReLU(alpha=0.2))
    # generate
    model.add(Conv2D(3, (8,8), activation='tanh', padding='same')) #32x32x3
    return model  # the generator model not compiled as it is not directly trained as the discriminator.
                  # the generator is being trained via a GAN combined model (see below)

test_generator = define_generator(latent_dim=100)
print(test_generator.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 8192)                │         827,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 8192)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose (Conv2DTranspose)   │ (None, 16, 16, 128)         │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_transpose_1 (Conv2DTranspose) │ (None, 32, 32, 128)         │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)            │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 3)           │          24,579 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,376,515 (5.25 MB)
#  Trainable params: 1,376,515 (5.25 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# Now, define the combined generator and discriminator model, for updating the generator.
# The discriminator is trained separately so here only the generator will be trained by keeping the discriminator constant.

# %%
def define_gan(generator, discriminator):
    # The discriminator is trained separately (see above). Hence, set it to not trainable.
    discriminator.trainable = False

    # Now, connect the generator and the discriminator
    model = Sequential()
    model.add(generator)
    model.add(discriminator)

    # Compile the combined model and Choose an optimizer
    opt = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=opt)

    return model

# %% [markdown]
# ### Load data
# Load the data set and plot parts of it in order to get a quick understanding.
#
# CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck

# %%
(trainX, trainy), (testX, testy) = load_data()

# plot 25=5x5 example images
for i in range(25):
    plt.subplot(5, 5, 1 + i)
    plt.axis('off')
    plt.imshow(trainX[i])
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step

# %%
# Load the cifar images and build a training data set
def load_real_samples():
    (trainX, _), (_, _) = load_data()
    # convert to float and scale.
    X = trainX.astype('float32')
    # the generator uses tanh as activation function (see above),
    # so we need to rescale from [0,255] to [-1,1]
    # original images to -1 to 1 to match the output of generator.
    X = (X - 127.5) / 127.5

    return X

# %%
# Pick a batch of random real samples to train the GAN
# In fact, train the GAN on a half batch of real images and another half batch of fake images.
# For each real image assign the label=1 and for fake assign the label=0.
def generate_real_samples(dataset, n_samples):
    # choose random images
    ix = randint(0, dataset.shape[0], n_samples)
    # select the random images and assign it to X
    x = dataset[ix]
    # generate class labels and assign to y
    y = ones((n_samples, 1)) # label=1 indicates that the image is a real one
    return x, y

# %%
# Generate n_samples number of latent vectors as input for the generator
def generate_latent_points(latent_dim, n_samples):
    # generate points in the latent space
    x_input = randn(latent_dim * n_samples)
    # reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)
    return x_input

# %%
# Use the generator to generate n fake examples, with class labels
# Supply the generator, latent_dim and number of samples as input.
# Use the above latent point generator to generate latent points.
def generate_fake_samples(generator, latent_dim, n_samples):
    # generate points in latent space
    x_input = generate_latent_points(latent_dim, n_samples)
    # predict using generator to generate fake samples.
    x = generator.predict(x_input)
    # Class labels will be 0 as these samples are fake.
    y = zeros((n_samples, 1))  # label=0 indicates that the image is a fake one
    return x, y

# %% [markdown]
# ### Training function for the generator and discriminator
# Loop through a number of epochs to train the discriminator by first selecting a random batch of images from the true/real data set. Then, generate a set of images using the generator. Feed both sets of images into the discriminator. Finally, set the loss parameters for both the real and fake images, as well as the combined loss.

# %%
def train(g_model, d_model, gan_model, filename, dataset, latent_dim, n_epochs=100, n_batch=128):
    bat_per_epo = int(dataset.shape[0] / n_batch)
    half_batch = int(n_batch / 2)  #the discriminator model is updated for a half batch of real samples
                            #and a half batch of fake samples, combined a single batch.
    # manually enumerate epochs and bacthes.
    for i in range(n_epochs):
        # enumerate batches over the training set
        for j in range(bat_per_epo):

            # Train the discriminator on real and fake images, separately (half batch each)
            #Research showed that separate training is more effective.
            # get randomly selected 'real' samples
            X_real, y_real = generate_real_samples(dataset, half_batch)
            # update discriminator model weights
            ##train_on_batch allows you to update weights based on a collection
            #of samples you provide
            #Let us just capture loss and ignore accuracy value (2nd output below)
            d_loss_real, _ = d_model.train_on_batch(X_real, y_real)

            # generate 'fake' examples
            X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
            # update discriminator model weights
            d_loss_fake, _ = d_model.train_on_batch(X_fake, y_fake)

            #d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) #Average loss if you want to report single..

            # prepare points in latent space as input for the generator
            X_gan = generate_latent_points(latent_dim, n_batch)

            # The generator wants the discriminator to label the generated samples as valid ones.
            # This is where the generator is trying to trick discriminator into believing that
            # the generated image is true (hence value of 1 for y)
            y_gan = ones((n_batch, 1))

            # The generator is part of the combined model where it got directly linked with the discriminator
            # Train the generator with latent_dim as x and 1 as y.
            # Again, 1 as the output as it is adversarial and if the generator did a great
            # job of fooling the discriminator, then the output would be 1 (true).
            # Update the generator via the discriminator's error
            g_loss = gan_model.train_on_batch(X_gan, y_gan)

            # Print losses on this batch
            print('Epoch=',i+1, 'Batch=', j+1, '/',bat_per_epo, 'd1=', d_loss_real, 'd2=', d_loss_fake, 'g=', g_loss)

    # save the generator model
    g_model.save(filename)

# %% [markdown]
# ### Train the GAN

# %%
# size of the latent space
latent_dim = 100
# create the discriminator
discriminator = define_discriminator()
# create the generator
generator = define_generator(latent_dim)
# create the gan
gan_model = define_gan(generator, discriminator)
# load image data
dataset = load_real_samples()
# train model
n_epochs=5 #50
model_filename = "cifar_GAN." + str(n_epochs) + "_epochs.keras"
train(generator, discriminator, gan_model, model_filename, dataset, latent_dim, n_epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Epoch= 1 Batch= 1 / 390 d1= 0.6677575 d2= 0.6808344 g= [array(0.6808344, dtype=float32), array(0.6808344, dtype=float32), array(0.515625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7dd34290e710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7dd3393197e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch= 1 Batch= 2 / 390 d1= 0.6740938 d2= 0.6796268 g= [array(0.6796268, dtype=float32), array(0.6796268, dtype=float32), array(0.48046875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch= 1 Batch= 3 / 390 d1= 0.6763793 d2= 0.6800931 g= [array(0.6800931, dtype=float32), array(0.6800931, dtype=float32), array(0.45833334, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch= 1 Batch= 4 / 390 d1= 0.6778966 d2= 0.6809691 g= [array(0.6809691, dtype=float32), array(0.6809691, dtype=float32), array(0.44140625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch= 1 Batch= 5 / 390 d1= 0.67984617 d2= 0.6826482 g= [array(0.6826482, dtype=float32), array(0.6826482, dtype=float32), array(0.43125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 6 / 390 d1= 0.6802735 d2= 0.6830573 g= [array(0.6830573, dtype=float32), array(0.6830573, dtype=float32), array(0.42708334, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 7 / 390 d1= 0.6812285 d2= 0.68418044 g= [array(0.68418044, dtype=float32), array(0.68418044, dtype=float32), array(0.42857143, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 8 / 390 d1= 0.6821899 d2= 0.6851093 g= [array(0.6851093, dtype=float32), array(0.6851093, dtype=float32), array(0.42871094, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 9 / 390 d1= 0.68374807 d2= 0.68711674 g= [array(0.68711674, dtype=float32), array(0.68711674, dtype=float32), array(0.4253472, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 10 / 390 d1= 0.686131 d2= 0.68974745 g= [array(0.68974745, dtype=float32), array(0.68974745, dtype=float32), array(0.41796875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 11 / 390 d1= 0.6879234 d2= 0.69201547 g= [array(0.69201547, dtype=float32), array(0.69201547, dtype=float32), array(0.42045453, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 12 / 390 d1= 0.6910584 d2= 0.69556695 g= [array(0.69556695, dtype=float32), array(0.69556695, dtype=float32), array(0.4153646, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 13 / 390 d1= 0.694489 d2= 0.6995872 g= [array(0.6995872, dtype=float32), array(0.6995872, dtype=float32), array(0.4140625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 14 / 390 d1= 0.69801176 d2= 0.7034809 g= [array(0.7034809, dtype=float32), array(0.7034809, dtype=float32), array(0.41462055, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 15 / 390 d1= 0.702107 d2= 0.7078622 g= [array(0.7078622, dtype=float32), array(0.7078622, dtype=float32), array(0.4140625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 16 / 390 d1= 0.7066702 d2= 0.71338534 g= [array(0.71338534, dtype=float32), array(0.71338534, dtype=float32), array(0.41259766, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 17 / 390 d1= 0.7115987 d2= 0.71831864 g= [array(0.71831864, dtype=float32), array(0.71831864, dtype=float32), array(0.4140625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 18 / 390 d1= 0.716626 d2= 0.7233329 g= [array(0.7233329, dtype=float32), array(0.7233329, dtype=float32), array(0.41493055, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 19 / 390 d1= 0.7217334 d2= 0.7289514 g= [array(0.7289514, dtype=float32), array(0.7289514, dtype=float32), array(0.41282895, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 20 / 390 d1= 0.7271057 d2= 0.7341542 g= [array(0.7341542, dtype=float32), array(0.7341542, dtype=float32), array(0.41328126, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 21 / 390 d1= 0.7324059 d2= 0.7399043 g= [array(0.7399043, dtype=float32), array(0.7399043, dtype=float32), array(0.4125744, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 22 / 390 d1= 0.7382718 d2= 0.7456026 g= [array(0.7456026, dtype=float32), array(0.7456026, dtype=float32), array(0.41086647, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 23 / 390 d1= 0.7437481 d2= 0.751069 g= [array(0.751069, dtype=float32), array(0.751069, dtype=float32), array(0.4103261, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 24 / 390 d1= 0.7493479 d2= 0.7566669 g= [array(0.7566669, dtype=float32), array(0.7566669, dtype=float32), array(0.41015625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 25 / 390 d1= 0.75485337 d2= 0.762513 g= [array(0.762513, dtype=float32), array(0.762513, dtype=float32), array(0.4084375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 26 / 390 d1= 0.7606572 d2= 0.76783955 g= [array(0.76783955, dtype=float32), array(0.76783955, dtype=float32), array(0.40865386, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 27 / 390 d1= 0.7660537 d2= 0.7735032 g= [array(0.7735032, dtype=float32), array(0.7735032, dtype=float32), array(0.4074074, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 28 / 390 d1= 0.77148145 d2= 0.77876806 g= [array(0.77876806, dtype=float32), array(0.77876806, dtype=float32), array(0.40736607, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 29 / 390 d1= 0.77680844 d2= 0.78440875 g= [array(0.78440875, dtype=float32), array(0.78440875, dtype=float32), array(0.40759698, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 30 / 390 d1= 0.7822564 d2= 0.7898341 g= [array(0.7898341, dtype=float32), array(0.7898341, dtype=float32), array(0.40859374, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 31 / 390 d1= 0.7877966 d2= 0.7947868 g= [array(0.7947868, dtype=float32), array(0.7947868, dtype=float32), array(0.405998, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 32 / 390 d1= 0.79272157 d2= 0.8000249 g= [array(0.8000249, dtype=float32), array(0.8000249, dtype=float32), array(0.40527344, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 33 / 390 d1= 0.79786927 d2= 0.80491143 g= [array(0.80491143, dtype=float32), array(0.80491143, dtype=float32), array(0.40530303, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 34 / 390 d1= 0.8028238 d2= 0.81003904 g= [array(0.81003904, dtype=float32), array(0.81003904, dtype=float32), array(0.4048713, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 35 / 390 d1= 0.8080695 d2= 0.8151655 g= [array(0.8151655, dtype=float32), array(0.8151655, dtype=float32), array(0.4033482, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 36 / 390 d1= 0.8130106 d2= 0.8197658 g= [array(0.8197658, dtype=float32), array(0.8197658, dtype=float32), array(0.40364584, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 37 / 390 d1= 0.8176454 d2= 0.824553 g= [array(0.824553, dtype=float32), array(0.824553, dtype=float32), array(0.40266046, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 38 / 390 d1= 0.82238424 d2= 0.8291304 g= [array(0.8291304, dtype=float32), array(0.8291304, dtype=float32), array(0.40316612, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 39 / 390 d1= 0.8270553 d2= 0.83359146 g= [array(0.83359146, dtype=float32), array(0.83359146, dtype=float32), array(0.40264422, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 40 / 390 d1= 0.83147615 d2= 0.8378223 g= [array(0.8378223, dtype=float32), array(0.8378223, dtype=float32), array(0.40273437, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 41 / 390 d1= 0.83570087 d2= 0.8424129 g= [array(0.8424129, dtype=float32), array(0.8424129, dtype=float32), array(0.40262958, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 42 / 390 d1= 0.840289 d2= 0.84671074 g= [array(0.84671074, dtype=float32), array(0.84671074, dtype=float32), array(0.40234375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 43 / 390 d1= 0.8444645 d2= 0.8506702 g= [array(0.8506702, dtype=float32), array(0.8506702, dtype=float32), array(0.40334302, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 44 / 390 d1= 0.84851694 d2= 0.85484505 g= [array(0.85484505, dtype=float32), array(0.85484505, dtype=float32), array(0.40269887, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 45 / 390 d1= 0.8527501 d2= 0.85888994 g= [array(0.85888994, dtype=float32), array(0.85888994, dtype=float32), array(0.40260416, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 46 / 390 d1= 0.8567321 d2= 0.8629011 g= [array(0.8629011, dtype=float32), array(0.8629011, dtype=float32), array(0.40234375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 47 / 390 d1= 0.860694 d2= 0.86685073 g= [array(0.86685073, dtype=float32), array(0.86685073, dtype=float32), array(0.40226063, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 48 / 390 d1= 0.8647204 d2= 0.8707531 g= [array(0.8707531, dtype=float32), array(0.8707531, dtype=float32), array(0.4025065, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 49 / 390 d1= 0.86858237 d2= 0.8742408 g= [array(0.8742408, dtype=float32), array(0.8742408, dtype=float32), array(0.40322065, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 50 / 390 d1= 0.8721094 d2= 0.8778946 g= [array(0.8778946, dtype=float32), array(0.8778946, dtype=float32), array(0.40328124, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 51 / 390 d1= 0.8757541 d2= 0.8814548 g= [array(0.8814548, dtype=float32), array(0.8814548, dtype=float32), array(0.40303308, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 52 / 390 d1= 0.8793088 d2= 0.88486224 g= [array(0.88486224, dtype=float32), array(0.88486224, dtype=float32), array(0.40309495, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 53 / 390 d1= 0.88280046 d2= 0.8885852 g= [array(0.8885852, dtype=float32), array(0.8885852, dtype=float32), array(0.40256485, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 54 / 390 d1= 0.88644654 d2= 0.89220834 g= [array(0.89220834, dtype=float32), array(0.89220834, dtype=float32), array(0.40234375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 55 / 390 d1= 0.8901328 d2= 0.89576286 g= [array(0.89576286, dtype=float32), array(0.89576286, dtype=float32), array(0.4021307, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 56 / 390 d1= 0.89374983 d2= 0.89929867 g= [array(0.89929867, dtype=float32), array(0.89929867, dtype=float32), array(0.40122768, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 57 / 390 d1= 0.89716125 d2= 0.9025423 g= [array(0.9025423, dtype=float32), array(0.9025423, dtype=float32), array(0.40172696, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 58 / 390 d1= 0.9004508 d2= 0.9058877 g= [array(0.9058877, dtype=float32), array(0.9058877, dtype=float32), array(0.40153557, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 59 / 390 d1= 0.9038614 d2= 0.90937203 g= [array(0.90937203, dtype=float32), array(0.90937203, dtype=float32), array(0.40082097, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 60 / 390 d1= 0.90726465 d2= 0.9127242 g= [array(0.9127242, dtype=float32), array(0.9127242, dtype=float32), array(0.40117186, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 61 / 390 d1= 0.9106901 d2= 0.91599524 g= [array(0.91599524, dtype=float32), array(0.91599524, dtype=float32), array(0.4008709, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 62 / 390 d1= 0.9139611 d2= 0.9194576 g= [array(0.9194576, dtype=float32), array(0.9194576, dtype=float32), array(0.40070564, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 63 / 390 d1= 0.9173691 d2= 0.9225657 g= [array(0.9225657, dtype=float32), array(0.9225657, dtype=float32), array(0.40104166, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 64 / 390 d1= 0.9205699 d2= 0.9259439 g= [array(0.9259439, dtype=float32), array(0.9259439, dtype=float32), array(0.40124512, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 65 / 390 d1= 0.92396075 d2= 0.92918783 g= [array(0.92918783, dtype=float32), array(0.92918783, dtype=float32), array(0.40060097, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 66 / 390 d1= 0.92714626 d2= 0.93222296 g= [array(0.93222296, dtype=float32), array(0.93222296, dtype=float32), array(0.40092328, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 67 / 390 d1= 0.9302071 d2= 0.9354142 g= [array(0.9354142, dtype=float32), array(0.9354142, dtype=float32), array(0.4010028, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 68 / 390 d1= 0.93338823 d2= 0.9385514 g= [array(0.9385514, dtype=float32), array(0.9385514, dtype=float32), array(0.40130973, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 69 / 390 d1= 0.9365946 d2= 0.9415374 g= [array(0.9415374, dtype=float32), array(0.9415374, dtype=float32), array(0.40104166, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 70 / 390 d1= 0.93957067 d2= 0.94465166 g= [array(0.94465166, dtype=float32), array(0.94465166, dtype=float32), array(0.40100446, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 71 / 390 d1= 0.9426693 d2= 0.94788724 g= [array(0.94788724, dtype=float32), array(0.94788724, dtype=float32), array(0.4009683, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 72 / 390 d1= 0.94593376 d2= 0.9509957 g= [array(0.9509957, dtype=float32), array(0.9509957, dtype=float32), array(0.40060765, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 73 / 390 d1= 0.94896483 d2= 0.95408714 g= [array(0.95408714, dtype=float32), array(0.95408714, dtype=float32), array(0.40122002, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 74 / 390 d1= 0.9520605 d2= 0.9571207 g= [array(0.9571207, dtype=float32), array(0.9571207, dtype=float32), array(0.40107685, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 75 / 390 d1= 0.95505685 d2= 0.96006906 g= [array(0.96006906, dtype=float32), array(0.96006906, dtype=float32), array(0.40208334, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 76 / 390 d1= 0.95810795 d2= 0.96297324 g= [array(0.96297324, dtype=float32), array(0.96297324, dtype=float32), array(0.40172696, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 77 / 390 d1= 0.961023 d2= 0.9660009 g= [array(0.9660009, dtype=float32), array(0.9660009, dtype=float32), array(0.40137988, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 78 / 390 d1= 0.96401995 d2= 0.96885973 g= [array(0.96885973, dtype=float32), array(0.96885973, dtype=float32), array(0.401242, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 79 / 390 d1= 0.96690106 d2= 0.9719148 g= [array(0.9719148, dtype=float32), array(0.9719148, dtype=float32), array(0.40140426, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 80 / 390 d1= 0.96994776 d2= 0.9748243 g= [array(0.9748243, dtype=float32), array(0.9748243, dtype=float32), array(0.4013672, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 81 / 390 d1= 0.9729047 d2= 0.97776765 g= [array(0.97776765, dtype=float32), array(0.97776765, dtype=float32), array(0.40104166, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 82 / 390 d1= 0.97580516 d2= 0.98049366 g= [array(0.98049366, dtype=float32), array(0.98049366, dtype=float32), array(0.40091464, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 83 / 390 d1= 0.97853756 d2= 0.9831258 g= [array(0.9831258, dtype=float32), array(0.9831258, dtype=float32), array(0.40116715, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 84 / 390 d1= 0.9812367 d2= 0.98595077 g= [array(0.98595077, dtype=float32), array(0.98595077, dtype=float32), array(0.40122768, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 85 / 390 d1= 0.98404807 d2= 0.9888005 g= [array(0.9888005, dtype=float32), array(0.9888005, dtype=float32), array(0.40128675, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 86 / 390 d1= 0.9869405 d2= 0.9915361 g= [array(0.9915361, dtype=float32), array(0.9915361, dtype=float32), array(0.4007086, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 87 / 390 d1= 0.98961276 d2= 0.99434835 g= [array(0.99434835, dtype=float32), array(0.99434835, dtype=float32), array(0.40095186, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 88 / 390 d1= 0.9924511 d2= 0.9969317 g= [array(0.9969317, dtype=float32), array(0.9969317, dtype=float32), array(0.40065697, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 89 / 390 d1= 0.99503195 d2= 0.99965125 g= [array(0.99965125, dtype=float32), array(0.99965125, dtype=float32), array(0.40063202, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 90 / 390 d1= 0.997789 d2= 1.0022699 g= [array(1.0022699, dtype=float32), array(1.0022699, dtype=float32), array(0.4001736, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 91 / 390 d1= 1.0003952 d2= 1.0050188 g= [array(1.0050188, dtype=float32), array(1.0050188, dtype=float32), array(0.40041208, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 92 / 390 d1= 1.0031369 d2= 1.0077512 g= [array(1.0077512, dtype=float32), array(1.0077512, dtype=float32), array(0.40047553, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 93 / 390 d1= 1.0059139 d2= 1.010366 g= [array(1.010366, dtype=float32), array(1.010366, dtype=float32), array(0.40053764, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 94 / 390 d1= 1.008501 d2= 1.0130677 g= [array(1.0130677, dtype=float32), array(1.0130677, dtype=float32), array(0.4007646, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 95 / 390 d1= 1.0112143 d2= 1.0157391 g= [array(1.0157391, dtype=float32), array(1.0157391, dtype=float32), array(0.4004934, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 96 / 390 d1= 1.0138358 d2= 1.0181404 g= [array(1.0181404, dtype=float32), array(1.0181404, dtype=float32), array(0.40055338, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 97 / 390 d1= 1.0163044 d2= 1.020575 g= [array(1.020575, dtype=float32), array(1.020575, dtype=float32), array(0.40061212, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 98 / 390 d1= 1.0187749 d2= 1.0230476 g= [array(1.0230476, dtype=float32), array(1.0230476, dtype=float32), array(0.40043047, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 99 / 390 d1= 1.0212435 d2= 1.0255046 g= [array(1.0255046, dtype=float32), array(1.0255046, dtype=float32), array(0.4000947, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 100 / 390 d1= 1.023705 d2= 1.0281028 g= [array(1.0281028, dtype=float32), array(1.0281028, dtype=float32), array(0.39984375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 101 / 390 d1= 1.0263051 d2= 1.0306574 g= [array(1.0306574, dtype=float32), array(1.0306574, dtype=float32), array(0.39944306, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 102 / 390 d1= 1.0288686 d2= 1.0331948 g= [array(1.0331948, dtype=float32), array(1.0331948, dtype=float32), array(0.3995864, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 103 / 390 d1= 1.0314147 d2= 1.035738 g= [array(1.035738, dtype=float32), array(1.035738, dtype=float32), array(0.39942354, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 104 / 390 d1= 1.0339196 d2= 1.0382382 g= [array(1.0382382, dtype=float32), array(1.0382382, dtype=float32), array(0.39971453, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 105 / 390 d1= 1.0364648 d2= 1.040723 g= [array(1.040723, dtype=float32), array(1.040723, dtype=float32), array(0.39955357, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 106 / 390 d1= 1.0389506 d2= 1.0430956 g= [array(1.0430956, dtype=float32), array(1.0430956, dtype=float32), array(0.39939564, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 107 / 390 d1= 1.0413533 d2= 1.0455501 g= [array(1.0455501, dtype=float32), array(1.0455501, dtype=float32), array(0.3989486, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 108 / 390 d1= 1.043803 d2= 1.0479308 g= [array(1.0479308, dtype=float32), array(1.0479308, dtype=float32), array(0.39836517, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 109 / 390 d1= 1.0461754 d2= 1.0502048 g= [array(1.0502048, dtype=float32), array(1.0502048, dtype=float32), array(0.39807913, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 110 / 390 d1= 1.0484396 d2= 1.0525277 g= [array(1.0525277, dtype=float32), array(1.0525277, dtype=float32), array(0.39808238, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 111 / 390 d1= 1.0507902 d2= 1.0548972 g= [array(1.0548972, dtype=float32), array(1.0548972, dtype=float32), array(0.39787444, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 112 / 390 d1= 1.0531381 d2= 1.0571567 g= [array(1.0571567, dtype=float32), array(1.0571567, dtype=float32), array(0.398019, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 113 / 390 d1= 1.0553796 d2= 1.0593382 g= [array(1.0593382, dtype=float32), array(1.0593382, dtype=float32), array(0.3984375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 114 / 390 d1= 1.0576326 d2= 1.0616488 g= [array(1.0616488, dtype=float32), array(1.0616488, dtype=float32), array(0.39802632, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 115 / 390 d1= 1.0599401 d2= 1.0639632 g= [array(1.0639632, dtype=float32), array(1.0639632, dtype=float32), array(0.39782608, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 116 / 390 d1= 1.0622418 d2= 1.0662353 g= [array(1.0662353, dtype=float32), array(1.0662353, dtype=float32), array(0.39796606, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 117 / 390 d1= 1.0645136 d2= 1.068375 g= [array(1.068375, dtype=float32), array(1.068375, dtype=float32), array(0.39756945, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 118 / 390 d1= 1.066699 d2= 1.0705851 g= [array(1.0705851, dtype=float32), array(1.0705851, dtype=float32), array(0.39704713, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 119 / 390 d1= 1.0688856 d2= 1.0726662 g= [array(1.0726662, dtype=float32), array(1.0726662, dtype=float32), array(0.39686188, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 120 / 390 d1= 1.0709333 d2= 1.0746235 g= [array(1.0746235, dtype=float32), array(1.0746235, dtype=float32), array(0.39707032, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 121 / 390 d1= 1.072904 d2= 1.0766764 g= [array(1.0766764, dtype=float32), array(1.0766764, dtype=float32), array(0.3970816, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 122 / 390 d1= 1.0749619 d2= 1.0786955 g= [array(1.0786955, dtype=float32), array(1.0786955, dtype=float32), array(0.39709273, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 123 / 390 d1= 1.0770204 d2= 1.0808115 g= [array(1.0808115, dtype=float32), array(1.0808115, dtype=float32), array(0.39697662, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 124 / 390 d1= 1.0791057 d2= 1.0828882 g= [array(1.0828882, dtype=float32), array(1.0828882, dtype=float32), array(0.39711443, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 125 / 390 d1= 1.0811616 d2= 1.084913 g= [array(1.084913, dtype=float32), array(1.084913, dtype=float32), array(0.3975625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 126 / 390 d1= 1.0832458 d2= 1.0870252 g= [array(1.0870252, dtype=float32), array(1.0870252, dtype=float32), array(0.39763144, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 127 / 390 d1= 1.0853505 d2= 1.0891129 g= [array(1.0891129, dtype=float32), array(1.0891129, dtype=float32), array(0.39763778, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 128 / 390 d1= 1.0874331 d2= 1.0911918 g= [array(1.0911918, dtype=float32), array(1.0911918, dtype=float32), array(0.39782715, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 129 / 390 d1= 1.0895209 d2= 1.0931773 g= [array(1.0931773, dtype=float32), array(1.0931773, dtype=float32), array(0.3978319, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 130 / 390 d1= 1.0915153 d2= 1.0951478 g= [array(1.0951478, dtype=float32), array(1.0951478, dtype=float32), array(0.39771634, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 131 / 390 d1= 1.0935209 d2= 1.0971398 g= [array(1.0971398, dtype=float32), array(1.0971398, dtype=float32), array(0.39754295, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 132 / 390 d1= 1.0955225 d2= 1.0991787 g= [array(1.0991787, dtype=float32), array(1.0991787, dtype=float32), array(0.3971946, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 133 / 390 d1= 1.0975637 d2= 1.101091 g= [array(1.101091, dtype=float32), array(1.101091, dtype=float32), array(0.39702773, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 134 / 390 d1= 1.0994664 d2= 1.1030418 g= [array(1.1030418, dtype=float32), array(1.1030418, dtype=float32), array(0.39715484, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 135 / 390 d1= 1.1013944 d2= 1.1048894 g= [array(1.1048894, dtype=float32), array(1.1048894, dtype=float32), array(0.39722222, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 136 / 390 d1= 1.1032468 d2= 1.1067178 g= [array(1.1067178, dtype=float32), array(1.1067178, dtype=float32), array(0.3970014, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 137 / 390 d1= 1.1050941 d2= 1.108615 g= [array(1.108615, dtype=float32), array(1.108615, dtype=float32), array(0.397354, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 138 / 390 d1= 1.1070218 d2= 1.1104939 g= [array(1.1104939, dtype=float32), array(1.1104939, dtype=float32), array(0.3974751, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 139 / 390 d1= 1.1088663 d2= 1.1123487 g= [array(1.1123487, dtype=float32), array(1.1123487, dtype=float32), array(0.39753821, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 140 / 390 d1= 1.1107212 d2= 1.1142757 g= [array(1.1142757, dtype=float32), array(1.1142757, dtype=float32), array(0.39754465, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 141 / 390 d1= 1.1126903 d2= 1.1161225 g= [array(1.1161225, dtype=float32), array(1.1161225, dtype=float32), array(0.39732933, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 142 / 390 d1= 1.1145078 d2= 1.117958 g= [array(1.117958, dtype=float32), array(1.117958, dtype=float32), array(0.3972271, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 143 / 390 d1= 1.1163535 d2= 1.1198354 g= [array(1.1198354, dtype=float32), array(1.1198354, dtype=float32), array(0.3972902, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 144 / 390 d1= 1.118261 d2= 1.1215543 g= [array(1.1215543, dtype=float32), array(1.1215543, dtype=float32), array(0.39718968, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 145 / 390 d1= 1.1199355 d2= 1.1234452 g= [array(1.1234452, dtype=float32), array(1.1234452, dtype=float32), array(0.39746767, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 146 / 390 d1= 1.1218653 d2= 1.1252458 g= [array(1.1252458, dtype=float32), array(1.1252458, dtype=float32), array(0.39763483, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 147 / 390 d1= 1.1236643 d2= 1.12712 g= [array(1.12712, dtype=float32), array(1.12712, dtype=float32), array(0.39764032, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 148 / 390 d1= 1.1255206 d2= 1.1288844 g= [array(1.1288844, dtype=float32), array(1.1288844, dtype=float32), array(0.39790964, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 149 / 390 d1= 1.1273489 d2= 1.1307626 g= [array(1.1307626, dtype=float32), array(1.1307626, dtype=float32), array(0.39791316, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 150 / 390 d1= 1.129207 d2= 1.1324706 g= [array(1.1324706, dtype=float32), array(1.1324706, dtype=float32), array(0.39770833, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 151 / 390 d1= 1.1309193 d2= 1.134195 g= [array(1.134195, dtype=float32), array(1.134195, dtype=float32), array(0.39755794, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 152 / 390 d1= 1.1326504 d2= 1.135918 g= [array(1.135918, dtype=float32), array(1.135918, dtype=float32), array(0.39756373, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 153 / 390 d1= 1.1343912 d2= 1.1375746 g= [array(1.1375746, dtype=float32), array(1.1375746, dtype=float32), array(0.39741626, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 154 / 390 d1= 1.1360238 d2= 1.1392792 g= [array(1.1392792, dtype=float32), array(1.1392792, dtype=float32), array(0.39737216, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 155 / 390 d1= 1.137741 d2= 1.1408763 g= [array(1.1408763, dtype=float32), array(1.1408763, dtype=float32), array(0.39753023, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 156 / 390 d1= 1.139354 d2= 1.1425581 g= [array(1.1425581, dtype=float32), array(1.1425581, dtype=float32), array(0.39733574, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 157 / 390 d1= 1.141029 d2= 1.1442311 g= [array(1.1442311, dtype=float32), array(1.1442311, dtype=float32), array(0.39734274, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 158 / 390 d1= 1.142702 d2= 1.1459146 g= [array(1.1459146, dtype=float32), array(1.1459146, dtype=float32), array(0.39730024, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 159 / 390 d1= 1.1444069 d2= 1.1475829 g= [array(1.1475829, dtype=float32), array(1.1475829, dtype=float32), array(0.3972091, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 160 / 390 d1= 1.1460559 d2= 1.1492559 g= [array(1.1492559, dtype=float32), array(1.1492559, dtype=float32), array(0.39736328, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 161 / 390 d1= 1.1477541 d2= 1.1509024 g= [array(1.1509024, dtype=float32), array(1.1509024, dtype=float32), array(0.39712733, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 162 / 390 d1= 1.1493819 d2= 1.1524496 g= [array(1.1524496, dtype=float32), array(1.1524496, dtype=float32), array(0.39723188, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 163 / 390 d1= 1.1509281 d2= 1.1541396 g= [array(1.1541396, dtype=float32), array(1.1541396, dtype=float32), array(0.397431, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 164 / 390 d1= 1.1526239 d2= 1.1556193 g= [array(1.1556193, dtype=float32), array(1.1556193, dtype=float32), array(0.3975324, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 165 / 390 d1= 1.1541374 d2= 1.1572458 g= [array(1.1572458, dtype=float32), array(1.1572458, dtype=float32), array(0.39739582, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 166 / 390 d1= 1.1557482 d2= 1.1587478 g= [array(1.1587478, dtype=float32), array(1.1587478, dtype=float32), array(0.397308, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 167 / 390 d1= 1.1572714 d2= 1.1602575 g= [array(1.1602575, dtype=float32), array(1.1602575, dtype=float32), array(0.39731476, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 168 / 390 d1= 1.1587603 d2= 1.1617615 g= [array(1.1617615, dtype=float32), array(1.1617615, dtype=float32), array(0.3972749, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 169 / 390 d1= 1.1602831 d2= 1.163291 g= [array(1.163291, dtype=float32), array(1.163291, dtype=float32), array(0.3972818, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 170 / 390 d1= 1.1618164 d2= 1.1648172 g= [array(1.1648172, dtype=float32), array(1.1648172, dtype=float32), array(0.39719668, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 171 / 390 d1= 1.1633593 d2= 1.1663551 g= [array(1.1663551, dtype=float32), array(1.1663551, dtype=float32), array(0.39711258, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 172 / 390 d1= 1.164877 d2= 1.1678729 g= [array(1.1678729, dtype=float32), array(1.1678729, dtype=float32), array(0.39707485, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 173 / 390 d1= 1.1664151 d2= 1.1694756 g= [array(1.1694756, dtype=float32), array(1.1694756, dtype=float32), array(0.39699242, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 174 / 390 d1= 1.1680217 d2= 1.1710253 g= [array(1.1710253, dtype=float32), array(1.1710253, dtype=float32), array(0.39700073, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 175 / 390 d1= 1.1695716 d2= 1.1725773 g= [array(1.1725773, dtype=float32), array(1.1725773, dtype=float32), array(0.39705357, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 176 / 390 d1= 1.1711198 d2= 1.1740369 g= [array(1.1740369, dtype=float32), array(1.1740369, dtype=float32), array(0.39701703, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 177 / 390 d1= 1.1725872 d2= 1.1754599 g= [array(1.1754599, dtype=float32), array(1.1754599, dtype=float32), array(0.39706922, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 178 / 390 d1= 1.174022 d2= 1.1768702 g= [array(1.1768702, dtype=float32), array(1.1768702, dtype=float32), array(0.39716467, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 179 / 390 d1= 1.1754274 d2= 1.1782427 g= [array(1.1782427, dtype=float32), array(1.1782427, dtype=float32), array(0.3971718, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 180 / 390 d1= 1.1768074 d2= 1.179631 g= [array(1.179631, dtype=float32), array(1.179631, dtype=float32), array(0.397092, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 181 / 390 d1= 1.1781896 d2= 1.180978 g= [array(1.180978, dtype=float32), array(1.180978, dtype=float32), array(0.39705628, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 182 / 390 d1= 1.1795167 d2= 1.1823987 g= [array(1.1823987, dtype=float32), array(1.1823987, dtype=float32), array(0.3974073, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 183 / 390 d1= 1.1809859 d2= 1.1838434 g= [array(1.1838434, dtype=float32), array(1.1838434, dtype=float32), array(0.39737022, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 184 / 390 d1= 1.182426 d2= 1.1853733 g= [array(1.1853733, dtype=float32), array(1.1853733, dtype=float32), array(0.39746094, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 185 / 390 d1= 1.1839684 d2= 1.1868993 g= [array(1.1868993, dtype=float32), array(1.1868993, dtype=float32), array(0.39755067, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 186 / 390 d1= 1.1855052 d2= 1.1883448 g= [array(1.1883448, dtype=float32), array(1.1883448, dtype=float32), array(0.39747143, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 187 / 390 d1= 1.1869448 d2= 1.189773 g= [array(1.189773, dtype=float32), array(1.189773, dtype=float32), array(0.39735126, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 188 / 390 d1= 1.1883732 d2= 1.1913393 g= [array(1.1913393, dtype=float32), array(1.1913393, dtype=float32), array(0.39723238, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 189 / 390 d1= 1.1899375 d2= 1.1927873 g= [array(1.1927873, dtype=float32), array(1.1927873, dtype=float32), array(0.3971561, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 190 / 390 d1= 1.1913793 d2= 1.194143 g= [array(1.194143, dtype=float32), array(1.194143, dtype=float32), array(0.39745066, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 191 / 390 d1= 1.1927583 d2= 1.195573 g= [array(1.195573, dtype=float32), array(1.195573, dtype=float32), array(0.39733312, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 192 / 390 d1= 1.1941797 d2= 1.197024 g= [array(1.197024, dtype=float32), array(1.197024, dtype=float32), array(0.39737955, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 193 / 390 d1= 1.1956508 d2= 1.1985075 g= [array(1.1985075, dtype=float32), array(1.1985075, dtype=float32), array(0.3973041, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 194 / 390 d1= 1.1971288 d2= 1.1999421 g= [array(1.1999421, dtype=float32), array(1.1999421, dtype=float32), array(0.39726967, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 195 / 390 d1= 1.1985803 d2= 1.2014145 g= [array(1.2014145, dtype=float32), array(1.2014145, dtype=float32), array(0.39703527, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 196 / 390 d1= 1.2000502 d2= 1.2029032 g= [array(1.2029032, dtype=float32), array(1.2029032, dtype=float32), array(0.39680326, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 197 / 390 d1= 1.2015104 d2= 1.2043226 g= [array(1.2043226, dtype=float32), array(1.2043226, dtype=float32), array(0.39693052, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 198 / 390 d1= 1.2029628 d2= 1.2056631 g= [array(1.2056631, dtype=float32), array(1.2056631, dtype=float32), array(0.39697757, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 199 / 390 d1= 1.204318 d2= 1.2070627 g= [array(1.2070627, dtype=float32), array(1.2070627, dtype=float32), array(0.39674938, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 200 / 390 d1= 1.2057033 d2= 1.2084327 g= [array(1.2084327, dtype=float32), array(1.2084327, dtype=float32), array(0.39683592, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 201 / 390 d1= 1.2070594 d2= 1.2097386 g= [array(1.2097386, dtype=float32), array(1.2097386, dtype=float32), array(0.39688277, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 202 / 390 d1= 1.2083666 d2= 1.2109694 g= [array(1.2109694, dtype=float32), array(1.2109694, dtype=float32), array(0.3970065, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 203 / 390 d1= 1.2096243 d2= 1.2123646 g= [array(1.2123646, dtype=float32), array(1.2123646, dtype=float32), array(0.39693657, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 204 / 390 d1= 1.2110085 d2= 1.2137254 g= [array(1.2137254, dtype=float32), array(1.2137254, dtype=float32), array(0.39698222, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 205 / 390 d1= 1.2123826 d2= 1.215022 g= [array(1.215022, dtype=float32), array(1.215022, dtype=float32), array(0.39695123, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 206 / 390 d1= 1.2136844 d2= 1.2163438 g= [array(1.2163438, dtype=float32), array(1.2163438, dtype=float32), array(0.3969205, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 207 / 390 d1= 1.2150093 d2= 1.2176647 g= [array(1.2176647, dtype=float32), array(1.2176647, dtype=float32), array(0.39685234, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 208 / 390 d1= 1.2163223 d2= 1.218873 g= [array(1.218873, dtype=float32), array(1.218873, dtype=float32), array(0.39689752, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 209 / 390 d1= 1.2175434 d2= 1.2201328 g= [array(1.2201328, dtype=float32), array(1.2201328, dtype=float32), array(0.39697966, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 210 / 390 d1= 1.2188171 d2= 1.2214177 g= [array(1.2214177, dtype=float32), array(1.2214177, dtype=float32), array(0.3970238, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 211 / 390 d1= 1.2200843 d2= 1.2226641 g= [array(1.2226641, dtype=float32), array(1.2226641, dtype=float32), array(0.3969935, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 212 / 390 d1= 1.2213254 d2= 1.2238772 g= [array(1.2238772, dtype=float32), array(1.2238772, dtype=float32), array(0.39722142, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 213 / 390 d1= 1.2225593 d2= 1.2251481 g= [array(1.2251481, dtype=float32), array(1.2251481, dtype=float32), array(0.3970804, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 214 / 390 d1= 1.2238334 d2= 1.2264955 g= [array(1.2264955, dtype=float32), array(1.2264955, dtype=float32), array(0.39715976, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 215 / 390 d1= 1.2251743 d2= 1.227795 g= [array(1.227795, dtype=float32), array(1.227795, dtype=float32), array(0.3971657, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 216 / 390 d1= 1.2264763 d2= 1.2290494 g= [array(1.2290494, dtype=float32), array(1.2290494, dtype=float32), array(0.3971354, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 217 / 390 d1= 1.2277461 d2= 1.230354 g= [array(1.230354, dtype=float32), array(1.230354, dtype=float32), array(0.39717743, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 218 / 390 d1= 1.2290525 d2= 1.2315856 g= [array(1.2315856, dtype=float32), array(1.2315856, dtype=float32), array(0.39714736, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 219 / 390 d1= 1.230281 d2= 1.2328167 g= [array(1.2328167, dtype=float32), array(1.2328167, dtype=float32), array(0.39726028, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 220 / 390 d1= 1.2315123 d2= 1.2340157 g= [array(1.2340157, dtype=float32), array(1.2340157, dtype=float32), array(0.3972656, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 221 / 390 d1= 1.2327065 d2= 1.2352388 g= [array(1.2352388, dtype=float32), array(1.2352388, dtype=float32), array(0.39741233, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 222 / 390 d1= 1.2339343 d2= 1.236425 g= [array(1.236425, dtype=float32), array(1.236425, dtype=float32), array(0.3976633, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 223 / 390 d1= 1.2351437 d2= 1.2376748 g= [array(1.2376748, dtype=float32), array(1.2376748, dtype=float32), array(0.3974916, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 224 / 390 d1= 1.2363892 d2= 1.2389022 g= [array(1.2389022, dtype=float32), array(1.2389022, dtype=float32), array(0.39742607, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 225 / 390 d1= 1.2376071 d2= 1.2400844 g= [array(1.2400844, dtype=float32), array(1.2400844, dtype=float32), array(0.39739582, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 226 / 390 d1= 1.2388195 d2= 1.241351 g= [array(1.241351, dtype=float32), array(1.241351, dtype=float32), array(0.39729673, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 227 / 390 d1= 1.2400805 d2= 1.2426103 g= [array(1.2426103, dtype=float32), array(1.2426103, dtype=float32), array(0.39730176, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 228 / 390 d1= 1.2413404 d2= 1.2438562 g= [array(1.2438562, dtype=float32), array(1.2438562, dtype=float32), array(0.39723822, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 229 / 390 d1= 1.242575 d2= 1.2450573 g= [array(1.2450573, dtype=float32), array(1.2450573, dtype=float32), array(0.3973458, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 230 / 390 d1= 1.2437985 d2= 1.2462626 g= [array(1.2462626, dtype=float32), array(1.2462626, dtype=float32), array(0.39721468, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 231 / 390 d1= 1.2449987 d2= 1.2474275 g= [array(1.2474275, dtype=float32), array(1.2474275, dtype=float32), array(0.3972876, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 232 / 390 d1= 1.2461686 d2= 1.2486228 g= [array(1.2486228, dtype=float32), array(1.2486228, dtype=float32), array(0.39729255, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 233 / 390 d1= 1.2473658 d2= 1.2497928 g= [array(1.2497928, dtype=float32), array(1.2497928, dtype=float32), array(0.39729747, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 234 / 390 d1= 1.2485396 d2= 1.2510074 g= [array(1.2510074, dtype=float32), array(1.2510074, dtype=float32), array(0.39723557, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 235 / 390 d1= 1.2497512 d2= 1.2521625 g= [array(1.2521625, dtype=float32), array(1.2521625, dtype=float32), array(0.3972407, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 236 / 390 d1= 1.2509203 d2= 1.2533543 g= [array(1.2533543, dtype=float32), array(1.2533543, dtype=float32), array(0.39701402, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 237 / 390 d1= 1.2521126 d2= 1.2545468 g= [array(1.2545468, dtype=float32), array(1.2545468, dtype=float32), array(0.39692116, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# ...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 309 / 390 d1= 1.6673003 d2= 1.6676384 g= [array(1.6676384, dtype=float32), array(1.6676384, dtype=float32), array(0.3967153, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 310 / 390 d1= 1.667372 d2= 1.6677032 g= [array(1.6677032, dtype=float32), array(1.6677032, dtype=float32), array(0.396687, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 311 / 390 d1= 1.667435 d2= 1.6677729 g= [array(1.6677729, dtype=float32), array(1.6677729, dtype=float32), array(0.39670464, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 312 / 390 d1= 1.6675063 d2= 1.6678443 g= [array(1.6678443, dtype=float32), array(1.6678443, dtype=float32), array(0.3967014, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 313 / 390 d1= 1.6675754 d2= 1.6679058 g= [array(1.6679058, dtype=float32), array(1.6679058, dtype=float32), array(0.39669815, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 314 / 390 d1= 1.6676401 d2= 1.6679791 g= [array(1.6679791, dtype=float32), array(1.6679791, dtype=float32), array(0.39670324, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 315 / 390 d1= 1.6677098 d2= 1.6680366 g= [array(1.6680366, dtype=float32), array(1.6680366, dtype=float32), array(0.39670834, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 316 / 390 d1= 1.6677687 d2= 1.6681006 g= [array(1.6681006, dtype=float32), array(1.6681006, dtype=float32), array(0.39671758, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 317 / 390 d1= 1.6678333 d2= 1.6681602 g= [array(1.6681602, dtype=float32), array(1.6681602, dtype=float32), array(0.39671433, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 5 Batch= 318 / 390 d1= 1.6678929 d2= 1.6682216 g= [array(1.6682216, dtype=float32), array(1.6682216, dtype=float32), array(0.39669445, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 319 / 390 d1= 1.667956 d2= 1.6682835 g= [array(1.6682835, dtype=float32), array(1.6682835, dtype=float32), array(0.39667043, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 320 / 390 d1= 1.6680142 d2= 1.668351 g= [array(1.668351, dtype=float32), array(1.668351, dtype=float32), array(0.3966797, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 321 / 390 d1= 1.6680853 d2= 1.668412 g= [array(1.668412, dtype=float32), array(1.668412, dtype=float32), array(0.39668477, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 322 / 390 d1= 1.668145 d2= 1.66847 g= [array(1.66847, dtype=float32), array(1.66847, dtype=float32), array(0.3966774, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 323 / 390 d1= 1.6682028 d2= 1.6685272 g= [array(1.6685272, dtype=float32), array(1.6685272, dtype=float32), array(0.39668664, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 324 / 390 d1= 1.6682581 d2= 1.6685871 g= [array(1.6685871, dtype=float32), array(1.6685871, dtype=float32), array(0.39671245, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 325 / 390 d1= 1.6683197 d2= 1.6686479 g= [array(1.6686479, dtype=float32), array(1.6686479, dtype=float32), array(0.3967092, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 326 / 390 d1= 1.6683794 d2= 1.6687135 g= [array(1.6687135, dtype=float32), array(1.6687135, dtype=float32), array(0.39671013, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 327 / 390 d1= 1.6684499 d2= 1.6687771 g= [array(1.6687771, dtype=float32), array(1.6687771, dtype=float32), array(0.3966738, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 328 / 390 d1= 1.6685101 d2= 1.668841 g= [array(1.668841, dtype=float32), array(1.668841, dtype=float32), array(0.39668715, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 329 / 390 d1= 1.6685737 d2= 1.6689053 g= [array(1.6689053, dtype=float32), array(1.6689053, dtype=float32), array(0.3966922, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 330 / 390 d1= 1.6686409 d2= 1.6689687 g= [array(1.6689687, dtype=float32), array(1.6689687, dtype=float32), array(0.39668486, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 331 / 390 d1= 1.6687028 d2= 1.6690274 g= [array(1.6690274, dtype=float32), array(1.6690274, dtype=float32), array(0.39667752, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 332 / 390 d1= 1.6687628 d2= 1.6690899 g= [array(1.6690899, dtype=float32), array(1.6690899, dtype=float32), array(0.39669085, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 333 / 390 d1= 1.6688242 d2= 1.6691432 g= [array(1.6691432, dtype=float32), array(1.6691432, dtype=float32), array(0.39670414, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 334 / 390 d1= 1.6688763 d2= 1.6692064 g= [array(1.6692064, dtype=float32), array(1.6692064, dtype=float32), array(0.39670092, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 335 / 390 d1= 1.6689421 d2= 1.6692629 g= [array(1.6692629, dtype=float32), array(1.6692629, dtype=float32), array(0.39669773, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 336 / 390 d1= 1.6689985 d2= 1.6693202 g= [array(1.6693202, dtype=float32), array(1.6693202, dtype=float32), array(0.39669865, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 337 / 390 d1= 1.669051 d2= 1.6693718 g= [array(1.6693718, dtype=float32), array(1.6693718, dtype=float32), array(0.39672425, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 338 / 390 d1= 1.6691077 d2= 1.6694318 g= [array(1.6694318, dtype=float32), array(1.6694318, dtype=float32), array(0.3967293, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 339 / 390 d1= 1.6691687 d2= 1.6694971 g= [array(1.6694971, dtype=float32), array(1.6694971, dtype=float32), array(0.39672196, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 340 / 390 d1= 1.669233 d2= 1.6695584 g= [array(1.6695584, dtype=float32), array(1.6695584, dtype=float32), array(0.3967352, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 341 / 390 d1= 1.669294 d2= 1.6696258 g= [array(1.6696258, dtype=float32), array(1.6696258, dtype=float32), array(0.39673197, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 342 / 390 d1= 1.6693581 d2= 1.6696794 g= [array(1.6696794, dtype=float32), array(1.6696794, dtype=float32), array(0.39674932, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 343 / 390 d1= 1.6694139 d2= 1.6697394 g= [array(1.6697394, dtype=float32), array(1.6697394, dtype=float32), array(0.39677072, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 344 / 390 d1= 1.6694758 d2= 1.6698008 g= [array(1.6698008, dtype=float32), array(1.6698008, dtype=float32), array(0.3967716, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 345 / 390 d1= 1.6695385 d2= 1.6698632 g= [array(1.6698632, dtype=float32), array(1.6698632, dtype=float32), array(0.39674786, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 346 / 390 d1= 1.6696002 d2= 1.6699172 g= [array(1.6699172, dtype=float32), array(1.6699172, dtype=float32), array(0.39674056, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 347 / 390 d1= 1.6696547 d2= 1.6699752 g= [array(1.6699752, dtype=float32), array(1.6699752, dtype=float32), array(0.39673325, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 348 / 390 d1= 1.6697121 d2= 1.6700313 g= [array(1.6700313, dtype=float32), array(1.6700313, dtype=float32), array(0.39672187, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 349 / 390 d1= 1.6697654 d2= 1.6700929 g= [array(1.6700929, dtype=float32), array(1.6700929, dtype=float32), array(0.3967514, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 350 / 390 d1= 1.6698287 d2= 1.67015 g= [array(1.67015, dtype=float32), array(1.67015, dtype=float32), array(0.39676866, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 351 / 390 d1= 1.6698868 d2= 1.6702037 g= [array(1.6702037, dtype=float32), array(1.6702037, dtype=float32), array(0.3967818, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 352 / 390 d1= 1.6699419 d2= 1.6702698 g= [array(1.6702698, dtype=float32), array(1.6702698, dtype=float32), array(0.39678675, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 353 / 390 d1= 1.670007 d2= 1.6703364 g= [array(1.6703364, dtype=float32), array(1.6703364, dtype=float32), array(0.39678353, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 354 / 390 d1= 1.6700736 d2= 1.6704006 g= [array(1.6704006, dtype=float32), array(1.6704006, dtype=float32), array(0.39677623, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 355 / 390 d1= 1.6701379 d2= 1.6704648 g= [array(1.6704648, dtype=float32), array(1.6704648, dtype=float32), array(0.39678118, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 356 / 390 d1= 1.6702019 d2= 1.6705185 g= [array(1.6705185, dtype=float32), array(1.6705185, dtype=float32), array(0.3967698, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 357 / 390 d1= 1.6702559 d2= 1.670581 g= [array(1.670581, dtype=float32), array(1.670581, dtype=float32), array(0.3967666, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 358 / 390 d1= 1.6703188 d2= 1.6706407 g= [array(1.6706407, dtype=float32), array(1.6706407, dtype=float32), array(0.3967471, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 359 / 390 d1= 1.6703779 d2= 1.6706957 g= [array(1.6706957, dtype=float32), array(1.6706957, dtype=float32), array(0.39674392, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 360 / 390 d1= 1.6704335 d2= 1.670751 g= [array(1.670751, dtype=float32), array(1.670751, dtype=float32), array(0.39673665, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 361 / 390 d1= 1.6704895 d2= 1.6708031 g= [array(1.6708031, dtype=float32), array(1.6708031, dtype=float32), array(0.39673346, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 362 / 390 d1= 1.6705407 d2= 1.670854 g= [array(1.670854, dtype=float32), array(1.670854, dtype=float32), array(0.3967303, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 363 / 390 d1= 1.6705917 d2= 1.6709094 g= [array(1.6709094, dtype=float32), array(1.6709094, dtype=float32), array(0.3967393, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 364 / 390 d1= 1.6706474 d2= 1.670961 g= [array(1.670961, dtype=float32), array(1.670961, dtype=float32), array(0.39675644, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 365 / 390 d1= 1.6706975 d2= 1.6710134 g= [array(1.6710134, dtype=float32), array(1.6710134, dtype=float32), array(0.3967776, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 366 / 390 d1= 1.6707503 d2= 1.6710674 g= [array(1.6710674, dtype=float32), array(1.6710674, dtype=float32), array(0.39678657, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 367 / 390 d1= 1.6708065 d2= 1.6711282 g= [array(1.6711282, dtype=float32), array(1.6711282, dtype=float32), array(0.39678338, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 368 / 390 d1= 1.6708689 d2= 1.6711919 g= [array(1.6711919, dtype=float32), array(1.6711919, dtype=float32), array(0.39677614, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 369 / 390 d1= 1.6709318 d2= 1.6712505 g= [array(1.6712505, dtype=float32), array(1.6712505, dtype=float32), array(0.396777, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 370 / 390 d1= 1.6709902 d2= 1.6713159 g= [array(1.6713159, dtype=float32), array(1.6713159, dtype=float32), array(0.3967819, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 371 / 390 d1= 1.6710535 d2= 1.6713686 g= [array(1.6713686, dtype=float32), array(1.6713686, dtype=float32), array(0.3967949, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 372 / 390 d1= 1.6711048 d2= 1.6714208 g= [array(1.6714208, dtype=float32), array(1.6714208, dtype=float32), array(0.39682, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 373 / 390 d1= 1.671161 d2= 1.6714822 g= [array(1.6714822, dtype=float32), array(1.6714822, dtype=float32), array(0.39679658, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 374 / 390 d1= 1.671222 d2= 1.6715493 g= [array(1.6715493, dtype=float32), array(1.6715493, dtype=float32), array(0.3967934, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 375 / 390 d1= 1.6712909 d2= 1.6716081 g= [array(1.6716081, dtype=float32), array(1.6716081, dtype=float32), array(0.3967781, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 376 / 390 d1= 1.6713479 d2= 1.6716713 g= [array(1.6716713, dtype=float32), array(1.6716713, dtype=float32), array(0.3967709, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 377 / 390 d1= 1.6714094 d2= 1.6717271 g= [array(1.6717271, dtype=float32), array(1.6717271, dtype=float32), array(0.3967677, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 378 / 390 d1= 1.6714648 d2= 1.6717801 g= [array(1.6717801, dtype=float32), array(1.6717801, dtype=float32), array(0.39678067, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 379 / 390 d1= 1.671519 d2= 1.6718307 g= [array(1.6718307, dtype=float32), array(1.6718307, dtype=float32), array(0.39678958, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 380 / 390 d1= 1.67157 d2= 1.6718918 g= [array(1.6718918, dtype=float32), array(1.6718918, dtype=float32), array(0.39681056, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 381 / 390 d1= 1.6716311 d2= 1.6719503 g= [array(1.6719503, dtype=float32), array(1.6719503, dtype=float32), array(0.3967953, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 382 / 390 d1= 1.6716893 d2= 1.6720039 g= [array(1.6720039, dtype=float32), array(1.6720039, dtype=float32), array(0.3967921, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 383 / 390 d1= 1.6717459 d2= 1.6720605 g= [array(1.6720605, dtype=float32), array(1.6720605, dtype=float32), array(0.3967809, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 384 / 390 d1= 1.6718001 d2= 1.6721195 g= [array(1.6721195, dtype=float32), array(1.6721195, dtype=float32), array(0.3967858, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 385 / 390 d1= 1.6718616 d2= 1.6721798 g= [array(1.6721798, dtype=float32), array(1.6721798, dtype=float32), array(0.39675853, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 386 / 390 d1= 1.6719183 d2= 1.6722418 g= [array(1.6722418, dtype=float32), array(1.6722418, dtype=float32), array(0.39677945, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 387 / 390 d1= 1.6719831 d2= 1.6723 g= [array(1.6723, dtype=float32), array(1.6723, dtype=float32), array(0.39676827, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 388 / 390 d1= 1.6720401 d2= 1.6723568 g= [array(1.6723568, dtype=float32), array(1.6723568, dtype=float32), array(0.39677313, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 389 / 390 d1= 1.6720996 d2= 1.6724244 g= [array(1.6724244, dtype=float32), array(1.6724244, dtype=float32), array(0.39674994, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 5 Batch= 390 / 390 d1= 1.6721678 d2= 1.6724795 g= [array(1.6724795, dtype=float32), array(1.6724795, dtype=float32), array(0.3967508, dtype=float32)]

# %%
from tensorflow.keras.models import load_model

# Now, load the generator model and generate images

# Plot generated images function
def show_plot(examples, n):
    for i in range(n * n):
        plt.subplot(n, n, 1 + i)
        plt.axis('off')
        plt.imshow(examples[i, :, :, :])
    plt.show()

# load model
model = load_model(model_filename) #Model trained for n epochs

# generate the latent vector
latent_points = generate_latent_points(100, 25)  #Latent dim and n_samples

# generate images from the latent vector
X = model.predict(latent_points)

# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
X = (X*255).astype(np.uint8)

# plot the generated images
# Note: CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck
show_plot(X, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 692ms/step

# %% [markdown]
# ## Train the GAN with a higher dimension of Latent Space and more epochs

# %%
# size of the latent space
latent_dim = 150
# create the discriminator
discriminator = define_discriminator()
# create the generator
generator = define_generator(latent_dim)
# create the gan
gan_model = define_gan(generator, discriminator)
# load image data
dataset = load_real_samples()
# train model
n_epochs=6 #50
model_filename = "cifar_GAN." + str(n_epochs) + "_epochs.keras"
train(generator, discriminator, gan_model, model_filename, dataset, latent_dim, n_epochs)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Epoch= 1 Batch= 1 / 390 d1= 0.71148556 d2= 0.7016058 g= [array(0.7016058, dtype=float32), array(0.7016058, dtype=float32), array(0.5078125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7c24c09a8d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x7c24c09abd90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch= 1 Batch= 2 / 390 d1= 0.7066312 d2= 0.7040638 g= [array(0.7040638, dtype=float32), array(0.7040638, dtype=float32), array(0.31640625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch= 1 Batch= 3 / 390 d1= 0.7062835 d2= 0.7053688 g= [array(0.7053688, dtype=float32), array(0.7053688, dtype=float32), array(0.26041666, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch= 1 Batch= 4 / 390 d1= 0.70762044 d2= 0.70748615 g= [array(0.70748615, dtype=float32), array(0.70748615, dtype=float32), array(0.23046875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch= 1 Batch= 5 / 390 d1= 0.7083938 d2= 0.708847 g= [array(0.708847, dtype=float32), array(0.708847, dtype=float32), array(0.2125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch= 1 Batch= 6 / 390 d1= 0.7084997 d2= 0.70964605 g= [array(0.70964605, dtype=float32), array(0.70964605, dtype=float32), array(0.21484375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 7 / 390 d1= 0.7097088 d2= 0.71136606 g= [array(0.71136606, dtype=float32), array(0.71136606, dtype=float32), array(0.20870535, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 8 / 390 d1= 0.7113682 d2= 0.71361244 g= [array(0.71361244, dtype=float32), array(0.71361244, dtype=float32), array(0.203125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 9 / 390 d1= 0.7134434 d2= 0.71623933 g= [array(0.71623933, dtype=float32), array(0.71623933, dtype=float32), array(0.2013889, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 10 / 390 d1= 0.7156493 d2= 0.719075 g= [array(0.719075, dtype=float32), array(0.719075, dtype=float32), array(0.20234375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 11 / 390 d1= 0.7188601 d2= 0.72309107 g= [array(0.72309107, dtype=float32), array(0.72309107, dtype=float32), array(0.19673295, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 12 / 390 d1= 0.72284746 d2= 0.72775275 g= [array(0.72775275, dtype=float32), array(0.72775275, dtype=float32), array(0.19335938, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 13 / 390 d1= 0.7274529 d2= 0.73288053 g= [array(0.73288053, dtype=float32), array(0.73288053, dtype=float32), array(0.1875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 14 / 390 d1= 0.7320491 d2= 0.73784065 g= [array(0.73784065, dtype=float32), array(0.73784065, dtype=float32), array(0.1858259, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 15 / 390 d1= 0.73734117 d2= 0.74333274 g= [array(0.74333274, dtype=float32), array(0.74333274, dtype=float32), array(0.1796875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 16 / 390 d1= 0.74257976 d2= 0.7487359 g= [array(0.7487359, dtype=float32), array(0.7487359, dtype=float32), array(0.1796875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 17 / 390 d1= 0.7475633 d2= 0.75390106 g= [array(0.75390106, dtype=float32), array(0.75390106, dtype=float32), array(0.17922795, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 18 / 390 d1= 0.7530086 d2= 0.76020527 g= [array(0.76020527, dtype=float32), array(0.76020527, dtype=float32), array(0.1749132, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 19 / 390 d1= 0.75911725 d2= 0.7658155 g= [array(0.7658155, dtype=float32), array(0.7658155, dtype=float32), array(0.17351973, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 20 / 390 d1= 0.76464444 d2= 0.7717123 g= [array(0.7717123, dtype=float32), array(0.7717123, dtype=float32), array(0.171875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 21 / 390 d1= 0.7702104 d2= 0.77727944 g= [array(0.77727944, dtype=float32), array(0.77727944, dtype=float32), array(0.171875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 22 / 390 d1= 0.7758608 d2= 0.78305507 g= [array(0.78305507, dtype=float32), array(0.78305507, dtype=float32), array(0.17045455, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 23 / 390 d1= 0.78183264 d2= 0.78927296 g= [array(0.78927296, dtype=float32), array(0.78927296, dtype=float32), array(0.16745923, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 24 / 390 d1= 0.7877617 d2= 0.7951513 g= [array(0.7951513, dtype=float32), array(0.7951513, dtype=float32), array(0.16569011, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 25 / 390 d1= 0.7935498 d2= 0.8003978 g= [array(0.8003978, dtype=float32), array(0.8003978, dtype=float32), array(0.1653125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 26 / 390 d1= 0.7989032 d2= 0.80599177 g= [array(0.80599177, dtype=float32), array(0.80599177, dtype=float32), array(0.1640625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 27 / 390 d1= 0.8044141 d2= 0.8110897 g= [array(0.8110897, dtype=float32), array(0.8110897, dtype=float32), array(0.16319445, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 28 / 390 d1= 0.80929065 d2= 0.8160967 g= [array(0.8160967, dtype=float32), array(0.8160967, dtype=float32), array(0.1640625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 29 / 390 d1= 0.8141949 d2= 0.8209741 g= [array(0.8209741, dtype=float32), array(0.8209741, dtype=float32), array(0.16540948, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 30 / 390 d1= 0.81920856 d2= 0.8259497 g= [array(0.8259497, dtype=float32), array(0.8259497, dtype=float32), array(0.16510417, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 31 / 390 d1= 0.8242275 d2= 0.83084196 g= [array(0.83084196, dtype=float32), array(0.83084196, dtype=float32), array(0.16456653, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 32 / 390 d1= 0.82912695 d2= 0.83541435 g= [array(0.83541435, dtype=float32), array(0.83541435, dtype=float32), array(0.16381836, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 33 / 390 d1= 0.83366036 d2= 0.83976537 g= [array(0.83976537, dtype=float32), array(0.83976537, dtype=float32), array(0.16193181, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 34 / 390 d1= 0.8379792 d2= 0.8440628 g= [array(0.8440628, dtype=float32), array(0.8440628, dtype=float32), array(0.1606158, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 35 / 390 d1= 0.84216654 d2= 0.84820855 g= [array(0.84820855, dtype=float32), array(0.84820855, dtype=float32), array(0.16049106, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 36 / 390 d1= 0.84623754 d2= 0.8522383 g= [array(0.8522383, dtype=float32), array(0.8522383, dtype=float32), array(0.16059028, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 37 / 390 d1= 0.8502023 d2= 0.8564488 g= [array(0.8564488, dtype=float32), array(0.8564488, dtype=float32), array(0.16195102, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 38 / 390 d1= 0.8545472 d2= 0.86057806 g= [array(0.86057806, dtype=float32), array(0.86057806, dtype=float32), array(0.16324013, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 39 / 390 d1= 0.8587018 d2= 0.86459684 g= [array(0.86459684, dtype=float32), array(0.86459684, dtype=float32), array(0.16346154, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 40 / 390 d1= 0.86270654 d2= 0.8686137 g= [array(0.8686137, dtype=float32), array(0.8686137, dtype=float32), array(0.16328125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 41 / 390 d1= 0.86675274 d2= 0.872412 g= [array(0.872412, dtype=float32), array(0.872412, dtype=float32), array(0.16272865, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 42 / 390 d1= 0.8704051 d2= 0.87621677 g= [array(0.87621677, dtype=float32), array(0.87621677, dtype=float32), array(0.16313244, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 43 / 390 d1= 0.87425876 d2= 0.8799597 g= [array(0.8799597, dtype=float32), array(0.8799597, dtype=float32), array(0.16351745, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 44 / 390 d1= 0.8780215 d2= 0.8835129 g= [array(0.8835129, dtype=float32), array(0.8835129, dtype=float32), array(0.16370739, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 45 / 390 d1= 0.88165444 d2= 0.8872636 g= [array(0.8872636, dtype=float32), array(0.8872636, dtype=float32), array(0.16440973, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 46 / 390 d1= 0.88526666 d2= 0.8907019 g= [array(0.8907019, dtype=float32), array(0.8907019, dtype=float32), array(0.16508152, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 47 / 390 d1= 0.8889755 d2= 0.8943354 g= [array(0.8943354, dtype=float32), array(0.8943354, dtype=float32), array(0.16356383, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 48 / 390 d1= 0.8924057 d2= 0.89762074 g= [array(0.89762074, dtype=float32), array(0.89762074, dtype=float32), array(0.16357422, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 49 / 390 d1= 0.89585406 d2= 0.90083915 g= [array(0.90083915, dtype=float32), array(0.90083915, dtype=float32), array(0.16214924, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 50 / 390 d1= 0.89890033 d2= 0.9040287 g= [array(0.9040287, dtype=float32), array(0.9040287, dtype=float32), array(0.16296875, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 51 / 390 d1= 0.90222037 d2= 0.9074416 g= [array(0.9074416, dtype=float32), array(0.9074416, dtype=float32), array(0.16207108, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 52 / 390 d1= 0.90567195 d2= 0.91085255 g= [array(0.91085255, dtype=float32), array(0.91085255, dtype=float32), array(0.16120793, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 53 / 390 d1= 0.9091064 d2= 0.9144578 g= [array(0.9144578, dtype=float32), array(0.9144578, dtype=float32), array(0.15949292, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 54 / 390 d1= 0.9125404 d2= 0.9175837 g= [array(0.9175837, dtype=float32), array(0.9175837, dtype=float32), array(0.15972222, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 55 / 390 d1= 0.915745 d2= 0.9207671 g= [array(0.9207671, dtype=float32), array(0.9207671, dtype=float32), array(0.15994318, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 56 / 390 d1= 0.9189727 d2= 0.92364985 g= [array(0.92364985, dtype=float32), array(0.92364985, dtype=float32), array(0.15973772, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 57 / 390 d1= 0.92176527 d2= 0.92634517 g= [array(0.92634517, dtype=float32), array(0.92634517, dtype=float32), array(0.15953948, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 58 / 390 d1= 0.92447364 d2= 0.9291847 g= [array(0.9291847, dtype=float32), array(0.9291847, dtype=float32), array(0.15948276, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 59 / 390 d1= 0.9273395 d2= 0.93200445 g= [array(0.93200445, dtype=float32), array(0.93200445, dtype=float32), array(0.1598252, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 60 / 390 d1= 0.9301577 d2= 0.9346579 g= [array(0.9346579, dtype=float32), array(0.9346579, dtype=float32), array(0.16002604, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 61 / 390 d1= 0.9329064 d2= 0.93740135 g= [array(0.93740135, dtype=float32), array(0.93740135, dtype=float32), array(0.15945184, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 62 / 390 d1= 0.9355798 d2= 0.9401701 g= [array(0.9401701, dtype=float32), array(0.9401701, dtype=float32), array(0.1594002, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 63 / 390 d1= 0.938368 d2= 0.9429077 g= [array(0.9429077, dtype=float32), array(0.9429077, dtype=float32), array(0.1592262, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 64 / 390 d1= 0.9410764 d2= 0.9455669 g= [array(0.9455669, dtype=float32), array(0.9455669, dtype=float32), array(0.15979004, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 65 / 390 d1= 0.9436987 d2= 0.9482184 g= [array(0.9482184, dtype=float32), array(0.9482184, dtype=float32), array(0.16021635, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 66 / 390 d1= 0.9464376 d2= 0.9507268 g= [array(0.9507268, dtype=float32), array(0.9507268, dtype=float32), array(0.160393, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch= 1 Batch= 67 / 390 d1= 0.9489041 d2= 0.9531968 g= [array(0.9531968, dtype=float32), array(0.9531968, dtype=float32), array(0.16044776, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 68 / 390 d1= 0.9514521 d2= 0.9556823 g= [array(0.9556823, dtype=float32), array(0.9556823, dtype=float32), array(0.16038603, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 69 / 390 d1= 0.9539717 d2= 0.9583266 g= [array(0.9583266, dtype=float32), array(0.9583266, dtype=float32), array(0.15975997, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 70 / 390 d1= 0.9565512 d2= 0.96074647 g= [array(0.96074647, dtype=float32), array(0.96074647, dtype=float32), array(0.159375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 71 / 390 d1= 0.95902973 d2= 0.9631333 g= [array(0.9631333, dtype=float32), array(0.9631333, dtype=float32), array(0.15889084, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 72 / 390 d1= 0.96137136 d2= 0.9653469 g= [array(0.9653469, dtype=float32), array(0.9653469, dtype=float32), array(0.1592882, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 73 / 390 d1= 0.963613 d2= 0.9677743 g= [array(0.9677743, dtype=float32), array(0.9677743, dtype=float32), array(0.15946062, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 74 / 390 d1= 0.9660415 d2= 0.970224 g= [array(0.970224, dtype=float32), array(0.970224, dtype=float32), array(0.16005068, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 75 / 390 d1= 0.9684833 d2= 0.9724526 g= [array(0.9724526, dtype=float32), array(0.9724526, dtype=float32), array(0.16010417, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 76 / 390 d1= 0.9708073 d2= 0.97493774 g= [array(0.97493774, dtype=float32), array(0.97493774, dtype=float32), array(0.15923108, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 77 / 390 d1= 0.9732758 d2= 0.9771778 g= [array(0.9771778, dtype=float32), array(0.9771778, dtype=float32), array(0.15858361, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 78 / 390 d1= 0.97542655 d2= 0.97936845 g= [array(0.97936845, dtype=float32), array(0.97936845, dtype=float32), array(0.1592548, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 79 / 390 d1= 0.97766095 d2= 0.9816385 g= [array(0.9816385, dtype=float32), array(0.9816385, dtype=float32), array(0.15971123, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 80 / 390 d1= 0.9800089 d2= 0.98392737 g= [array(0.98392737, dtype=float32), array(0.98392737, dtype=float32), array(0.1595703, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 81 / 390 d1= 0.98225737 d2= 0.98615426 g= [array(0.98615426, dtype=float32), array(0.98615426, dtype=float32), array(0.15923996, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 82 / 390 d1= 0.98450744 d2= 0.9883771 g= [array(0.9883771, dtype=float32), array(0.9883771, dtype=float32), array(0.15891768, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 83 / 390 d1= 0.98670554 d2= 0.9904137 g= [array(0.9904137, dtype=float32), array(0.9904137, dtype=float32), array(0.15860316, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 84 / 390 d1= 0.9888369 d2= 0.99253845 g= [array(0.99253845, dtype=float32), array(0.99253845, dtype=float32), array(0.15801711, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 85 / 390 d1= 0.99085075 d2= 0.9946362 g= [array(0.9946362, dtype=float32), array(0.9946362, dtype=float32), array(0.1586397, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 86 / 390 d1= 0.99300086 d2= 0.9966191 g= [array(0.9966191, dtype=float32), array(0.9966191, dtype=float32), array(0.15843023, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 87 / 390 d1= 0.9950188 d2= 0.9988603 g= [array(0.9988603, dtype=float32), array(0.9988603, dtype=float32), array(0.15831538, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 88 / 390 d1= 0.99720836 d2= 1.0009165 g= [array(1.0009165, dtype=float32), array(1.0009165, dtype=float32), array(0.15838069, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 89 / 390 d1= 0.99926937 d2= 1.0029002 g= [array(1.0029002, dtype=float32), array(1.0029002, dtype=float32), array(0.1585323, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 90 / 390 d1= 1.0013046 d2= 1.0050179 g= [array(1.0050179, dtype=float32), array(1.0050179, dtype=float32), array(0.15842015, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 91 / 390 d1= 1.0033741 d2= 1.0071354 g= [array(1.0071354, dtype=float32), array(1.0071354, dtype=float32), array(0.1587397, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 92 / 390 d1= 1.0055547 d2= 1.0090673 g= [array(1.0090673, dtype=float32), array(1.0090673, dtype=float32), array(0.15845788, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 93 / 390 d1= 1.0074548 d2= 1.0110072 g= [array(1.0110072, dtype=float32), array(1.0110072, dtype=float32), array(0.15893817, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 94 / 390 d1= 1.0094566 d2= 1.0129571 g= [array(1.0129571, dtype=float32), array(1.0129571, dtype=float32), array(0.15874335, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 95 / 390 d1= 1.0113733 d2= 1.0146948 g= [array(1.0146948, dtype=float32), array(1.0146948, dtype=float32), array(0.15871711, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 96 / 390 d1= 1.0130974 d2= 1.0166394 g= [array(1.0166394, dtype=float32), array(1.0166394, dtype=float32), array(0.15901692, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 97 / 390 d1= 1.0150663 d2= 1.0184997 g= [array(1.0184997, dtype=float32), array(1.0184997, dtype=float32), array(0.15931056, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 98 / 390 d1= 1.0169598 d2= 1.0205002 g= [array(1.0205002, dtype=float32), array(1.0205002, dtype=float32), array(0.15896046, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 99 / 390 d1= 1.0189079 d2= 1.022428 g= [array(1.022428, dtype=float32), array(1.022428, dtype=float32), array(0.15940657, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 100 / 390 d1= 1.0208809 d2= 1.024284 g= [array(1.024284, dtype=float32), array(1.024284, dtype=float32), array(0.15984374, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 101 / 390 d1= 1.0227631 d2= 1.0261616 g= [array(1.0261616, dtype=float32), array(1.0261616, dtype=float32), array(0.15957612, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 102 / 390 d1= 1.0246005 d2= 1.0279608 g= [array(1.0279608, dtype=float32), array(1.0279608, dtype=float32), array(0.16007966, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 103 / 390 d1= 1.0264279 d2= 1.029743 g= [array(1.029743, dtype=float32), array(1.029743, dtype=float32), array(0.15981492, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 104 / 390 d1= 1.0282507 d2= 1.0315851 g= [array(1.0315851, dtype=float32), array(1.0315851, dtype=float32), array(0.15985577, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 105 / 390 d1= 1.0300922 d2= 1.0333445 g= [array(1.0333445, dtype=float32), array(1.0333445, dtype=float32), array(0.159375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 106 / 390 d1= 1.0318176 d2= 1.0350821 g= [array(1.0350821, dtype=float32), array(1.0350821, dtype=float32), array(0.15956663, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 107 / 390 d1= 1.0335771 d2= 1.036888 g= [array(1.036888, dtype=float32), array(1.036888, dtype=float32), array(0.15946262, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 108 / 390 d1= 1.0353984 d2= 1.038761 g= [array(1.038761, dtype=float32), array(1.038761, dtype=float32), array(0.1592882, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 109 / 390 d1= 1.0372825 d2= 1.0406529 g= [array(1.0406529, dtype=float32), array(1.0406529, dtype=float32), array(0.15918864, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 110 / 390 d1= 1.0391494 d2= 1.0425495 g= [array(1.0425495, dtype=float32), array(1.0425495, dtype=float32), array(0.159375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 111 / 390 d1= 1.0410358 d2= 1.0442574 g= [array(1.0442574, dtype=float32), array(1.0442574, dtype=float32), array(0.15948762, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 112 / 390 d1= 1.0427291 d2= 1.0458035 g= [array(1.0458035, dtype=float32), array(1.0458035, dtype=float32), array(0.159947, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 113 / 390 d1= 1.0443558 d2= 1.0474172 g= [array(1.0474172, dtype=float32), array(1.0474172, dtype=float32), array(0.15984513, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 114 / 390 d1= 1.0459538 d2= 1.0492004 g= [array(1.0492004, dtype=float32), array(1.0492004, dtype=float32), array(0.15974507, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 115 / 390 d1= 1.0477186 d2= 1.050903 g= [array(1.050903, dtype=float32), array(1.050903, dtype=float32), array(0.15991847, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 116 / 390 d1= 1.0494132 d2= 1.0526235 g= [array(1.0526235, dtype=float32), array(1.0526235, dtype=float32), array(0.1603583, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 117 / 390 d1= 1.0511826 d2= 1.0543977 g= [array(1.0543977, dtype=float32), array(1.0543977, dtype=float32), array(0.16018964, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 118 / 390 d1= 1.0529822 d2= 1.0562379 g= [array(1.0562379, dtype=float32), array(1.0562379, dtype=float32), array(0.15989143, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 119 / 390 d1= 1.0547872 d2= 1.0579064 g= [array(1.0579064, dtype=float32), array(1.0579064, dtype=float32), array(0.16018908, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 120 / 390 d1= 1.0564857 d2= 1.0596665 g= [array(1.0596665, dtype=float32), array(1.0596665, dtype=float32), array(0.16015625, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 121 / 390 d1= 1.0582527 d2= 1.0614119 g= [array(1.0614119, dtype=float32), array(1.0614119, dtype=float32), array(0.15973657, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 122 / 390 d1= 1.0599892 d2= 1.063145 g= [array(1.063145, dtype=float32), array(1.063145, dtype=float32), array(0.159708, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 123 / 390 d1= 1.0617048 d2= 1.0646996 g= [array(1.0646996, dtype=float32), array(1.0646996, dtype=float32), array(0.15999746, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 124 / 390 d1= 1.0632839 d2= 1.0663486 g= [array(1.0663486, dtype=float32), array(1.0663486, dtype=float32), array(0.15977822, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 125 / 390 d1= 1.064934 d2= 1.0679646 g= [array(1.0679646, dtype=float32), array(1.0679646, dtype=float32), array(0.1599375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 126 / 390 d1= 1.0665526 d2= 1.0694677 g= [array(1.0694677, dtype=float32), array(1.0694677, dtype=float32), array(0.15997024, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 127 / 390 d1= 1.068064 d2= 1.07111 g= [array(1.07111, dtype=float32), array(1.07111, dtype=float32), array(0.15981792, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 128 / 390 d1= 1.0697426 d2= 1.0726652 g= [array(1.0726652, dtype=float32), array(1.0726652, dtype=float32), array(0.15966797, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 129 / 390 d1= 1.0712956 d2= 1.0742303 g= [array(1.0742303, dtype=float32), array(1.0742303, dtype=float32), array(0.15994428, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 130 / 390 d1= 1.0728431 d2= 1.0757618 g= [array(1.0757618, dtype=float32), array(1.0757618, dtype=float32), array(0.15961538, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 131 / 390 d1= 1.0743742 d2= 1.0774374 g= [array(1.0774374, dtype=float32), array(1.0774374, dtype=float32), array(0.15970898, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 132 / 390 d1= 1.0760567 d2= 1.0789979 g= [array(1.0789979, dtype=float32), array(1.0789979, dtype=float32), array(0.1595052, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 133 / 390 d1= 1.077667 d2= 1.0806555 g= [array(1.0806555, dtype=float32), array(1.0806555, dtype=float32), array(0.15889333, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 134 / 390 d1= 1.0792258 d2= 1.0821204 g= [array(1.0821204, dtype=float32), array(1.0821204, dtype=float32), array(0.1591068, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 135 / 390 d1= 1.08078 d2= 1.0836838 g= [array(1.0836838, dtype=float32), array(1.0836838, dtype=float32), array(0.15873842, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 136 / 390 d1= 1.0822865 d2= 1.0852314 g= [array(1.0852314, dtype=float32), array(1.0852314, dtype=float32), array(0.15883502, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 137 / 390 d1= 1.0839057 d2= 1.0868284 g= [array(1.0868284, dtype=float32), array(1.0868284, dtype=float32), array(0.15875912, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 138 / 390 d1= 1.0854821 d2= 1.0882876 g= [array(1.0882876, dtype=float32), array(1.0882876, dtype=float32), array(0.15885417, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 139 / 390 d1= 1.0869544 d2= 1.0898538 g= [array(1.0898538, dtype=float32), array(1.0898538, dtype=float32), array(0.15861061, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 140 / 390 d1= 1.0885105 d2= 1.0913128 g= [array(1.0913128, dtype=float32), array(1.0913128, dtype=float32), array(0.15842634, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 141 / 390 d1= 1.0899934 d2= 1.0927972 g= [array(1.0927972, dtype=float32), array(1.0927972, dtype=float32), array(0.1584109, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 142 / 390 d1= 1.0914798 d2= 1.0943571 g= [array(1.0943571, dtype=float32), array(1.0943571, dtype=float32), array(0.15795554, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 143 / 390 d1= 1.0930666 d2= 1.0959696 g= [array(1.0959696, dtype=float32), array(1.0959696, dtype=float32), array(0.15756118, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 144 / 390 d1= 1.0946089 d2= 1.097408 g= [array(1.097408, dtype=float32), array(1.097408, dtype=float32), array(0.15766059, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 145 / 390 d1= 1.0960561 d2= 1.0989541 g= [array(1.0989541, dtype=float32), array(1.0989541, dtype=float32), array(0.1578125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 146 / 390 d1= 1.0976726 d2= 1.1004617 g= [array(1.1004617, dtype=float32), array(1.1004617, dtype=float32), array(0.15774828, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 147 / 390 d1= 1.0991633 d2= 1.1018962 g= [array(1.1018962, dtype=float32), array(1.1018962, dtype=float32), array(0.15725978, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 148 / 390 d1= 1.1005585 d2= 1.1032557 g= [array(1.1032557, dtype=float32), array(1.1032557, dtype=float32), array(0.1574641, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 149 / 390 d1= 1.1019543 d2= 1.1046479 g= [array(1.1046479, dtype=float32), array(1.1046479, dtype=float32), array(0.15724623, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 150 / 390 d1= 1.1033685 d2= 1.1062094 g= [array(1.1062094, dtype=float32), array(1.1062094, dtype=float32), array(0.15692708, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 151 / 390 d1= 1.1048898 d2= 1.1077403 g= [array(1.1077403, dtype=float32), array(1.1077403, dtype=float32), array(0.15743998, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 152 / 390 d1= 1.1064245 d2= 1.1091924 g= [array(1.1091924, dtype=float32), array(1.1091924, dtype=float32), array(0.15748355, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 153 / 390 d1= 1.1078889 d2= 1.1106482 g= [array(1.1106482, dtype=float32), array(1.1106482, dtype=float32), array(0.15757762, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 154 / 390 d1= 1.1093727 d2= 1.1121022 g= [array(1.1121022, dtype=float32), array(1.1121022, dtype=float32), array(0.1574168, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 155 / 390 d1= 1.1108328 d2= 1.1135981 g= [array(1.1135981, dtype=float32), array(1.1135981, dtype=float32), array(0.15715726, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 156 / 390 d1= 1.1123443 d2= 1.1151015 g= [array(1.1151015, dtype=float32), array(1.1151015, dtype=float32), array(0.15720153, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 157 / 390 d1= 1.1138432 d2= 1.1165643 g= [array(1.1165643, dtype=float32), array(1.1165643, dtype=float32), array(0.15699641, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 158 / 390 d1= 1.1152989 d2= 1.1179627 g= [array(1.1179627, dtype=float32), array(1.1179627, dtype=float32), array(0.15694225, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch= 1 Batch= 159 / 390 d1= 1.116665 d2= 1.1193205 g= [array(1.1193205, dtype=float32), array(1.1193205, dtype=float32), array(0.15703617, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 160 / 390 d1= 1.1180549 d2= 1.1207116 g= [array(1.1207116, dtype=float32), array(1.1207116, dtype=float32), array(0.15698242, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 161 / 390 d1= 1.1194614 d2= 1.122099 g= [array(1.122099, dtype=float32), array(1.122099, dtype=float32), array(0.15707493, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 162 / 390 d1= 1.1208302 d2= 1.1234494 g= [array(1.1234494, dtype=float32), array(1.1234494, dtype=float32), array(0.15706983, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 163 / 390 d1= 1.1221957 d2= 1.1248411 g= [array(1.1248411, dtype=float32), array(1.1248411, dtype=float32), array(0.15716065, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 164 / 390 d1= 1.1235864 d2= 1.1261623 g= [array(1.1261623, dtype=float32), array(1.1261623, dtype=float32), array(0.15705983, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 165 / 390 d1= 1.1249104 d2= 1.1274803 g= [array(1.1274803, dtype=float32), array(1.1274803, dtype=float32), array(0.15686554, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 166 / 390 d1= 1.1261994 d2= 1.1288534 g= [array(1.1288534, dtype=float32), array(1.1288534, dtype=float32), array(0.1571442, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 167 / 390 d1= 1.1276219 d2= 1.1302431 g= [array(1.1302431, dtype=float32), array(1.1302431, dtype=float32), array(0.15713885, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 168 / 390 d1= 1.1289945 d2= 1.131674 g= [array(1.131674, dtype=float32), array(1.131674, dtype=float32), array(0.15708706, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 169 / 390 d1= 1.1304301 d2= 1.1330191 g= [array(1.1330191, dtype=float32), array(1.1330191, dtype=float32), array(0.15722078, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 170 / 390 d1= 1.1317782 d2= 1.1343602 g= [array(1.1343602, dtype=float32), array(1.1343602, dtype=float32), array(0.15726103, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 171 / 390 d1= 1.1331205 d2= 1.1355969 g= [array(1.1355969, dtype=float32), array(1.1355969, dtype=float32), array(0.1573008, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 172 / 390 d1= 1.1343508 d2= 1.1368815 g= [array(1.1368815, dtype=float32), array(1.1368815, dtype=float32), array(0.15756722, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 173 / 390 d1= 1.1356578 d2= 1.1382358 g= [array(1.1382358, dtype=float32), array(1.1382358, dtype=float32), array(0.15737897, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 174 / 390 d1= 1.1369929 d2= 1.1395361 g= [array(1.1395361, dtype=float32), array(1.1395361, dtype=float32), array(0.15764189, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 175 / 390 d1= 1.1383424 d2= 1.1409587 g= [array(1.1409587, dtype=float32), array(1.1409587, dtype=float32), array(0.15741071, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 176 / 390 d1= 1.1397415 d2= 1.1423606 g= [array(1.1423606, dtype=float32), array(1.1423606, dtype=float32), array(0.15767045, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 177 / 390 d1= 1.1411324 d2= 1.143732 g= [array(1.143732, dtype=float32), array(1.143732, dtype=float32), array(0.15792726, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 178 / 390 d1= 1.1425312 d2= 1.1450938 g= [array(1.1450938, dtype=float32), array(1.1450938, dtype=float32), array(0.15796173, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 179 / 390 d1= 1.1438911 d2= 1.1464514 g= [array(1.1464514, dtype=float32), array(1.1464514, dtype=float32), array(0.15803945, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 180 / 390 d1= 1.145253 d2= 1.1477737 g= [array(1.1477737, dtype=float32), array(1.1477737, dtype=float32), array(0.15811633, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 181 / 390 d1= 1.1465682 d2= 1.1491389 g= [array(1.1491389, dtype=float32), array(1.1491389, dtype=float32), array(0.15806285, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 182 / 390 d1= 1.1479256 d2= 1.150448 g= [array(1.150448, dtype=float32), array(1.150448, dtype=float32), array(0.15822458, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 183 / 390 d1= 1.1492805 d2= 1.1518916 g= [array(1.1518916, dtype=float32), array(1.1518916, dtype=float32), array(0.1582138, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 184 / 390 d1= 1.1507089 d2= 1.1531601 g= [array(1.1531601, dtype=float32), array(1.1531601, dtype=float32), array(0.1581182, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 185 / 390 d1= 1.1519626 d2= 1.1544306 g= [array(1.1544306, dtype=float32), array(1.1544306, dtype=float32), array(0.15819257, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 186 / 390 d1= 1.153259 d2= 1.1557177 g= [array(1.1557177, dtype=float32), array(1.1557177, dtype=float32), array(0.15826613, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 187 / 390 d1= 1.1545465 d2= 1.1570163 g= [array(1.1570163, dtype=float32), array(1.1570163, dtype=float32), array(0.15813002, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 188 / 390 d1= 1.1558449 d2= 1.1582752 g= [array(1.1582752, dtype=float32), array(1.1582752, dtype=float32), array(0.15799534, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 189 / 390 d1= 1.1571039 d2= 1.1595287 g= [array(1.1595287, dtype=float32), array(1.1595287, dtype=float32), array(0.15777943, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 190 / 390 d1= 1.1583587 d2= 1.1608394 g= [array(1.1608394, dtype=float32), array(1.1608394, dtype=float32), array(0.1578125, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 191 / 390 d1= 1.159672 d2= 1.1620743 g= [array(1.1620743, dtype=float32), array(1.1620743, dtype=float32), array(0.15768161, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 192 / 390 d1= 1.1608961 d2= 1.163406 g= [array(1.163406, dtype=float32), array(1.163406, dtype=float32), array(0.15767415, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 193 / 390 d1= 1.1622474 d2= 1.1646919 g= [array(1.1646919, dtype=float32), array(1.1646919, dtype=float32), array(0.15758581, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 194 / 390 d1= 1.1635243 d2= 1.1658715 g= [array(1.1658715, dtype=float32), array(1.1658715, dtype=float32), array(0.15753865, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 195 / 390 d1= 1.1647161 d2= 1.1671268 g= [array(1.1671268, dtype=float32), array(1.1671268, dtype=float32), array(0.15765224, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 196 / 390 d1= 1.1659808 d2= 1.1683779 g= [array(1.1683779, dtype=float32), array(1.1683779, dtype=float32), array(0.15768495, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 197 / 390 d1= 1.1672039 d2= 1.1695648 g= [array(1.1695648, dtype=float32), array(1.1695648, dtype=float32), array(0.15763801, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 198 / 390 d1= 1.1684384 d2= 1.170855 g= [array(1.170855, dtype=float32), array(1.170855, dtype=float32), array(0.15731534, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 199 / 390 d1= 1.1697105 d2= 1.1720552 g= [array(1.1720552, dtype=float32), array(1.1720552, dtype=float32), array(0.15719222, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 200 / 390 d1= 1.1709203 d2= 1.1732783 g= [array(1.1732783, dtype=float32), array(1.1732783, dtype=float32), array(0.15734375, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 201 / 390 d1= 1.1721427 d2= 1.1744682 g= [array(1.1744682, dtype=float32), array(1.1744682, dtype=float32), array(0.15702736, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 202 / 390 d1= 1.1733216 d2= 1.175661 g= [array(1.175661, dtype=float32), array(1.175661, dtype=float32), array(0.15706219, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 203 / 390 d1= 1.1745055 d2= 1.1767839 g= [array(1.1767839, dtype=float32), array(1.1767839, dtype=float32), array(0.15725061, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 204 / 390 d1= 1.1756504 d2= 1.1779557 g= [array(1.1779557, dtype=float32), array(1.1779557, dtype=float32), array(0.15716912, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 205 / 390 d1= 1.1768297 d2= 1.1791406 g= [array(1.1791406, dtype=float32), array(1.1791406, dtype=float32), array(0.15716463, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 206 / 390 d1= 1.1780448 d2= 1.1803294 g= [array(1.1803294, dtype=float32), array(1.1803294, dtype=float32), array(0.15685679, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 207 / 390 d1= 1.1791853 d2= 1.1814936 g= [array(1.1814936, dtype=float32), array(1.1814936, dtype=float32), array(0.15692934, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 208 / 390 d1= 1.1803912 d2= 1.1826886 g= [array(1.1826886, dtype=float32), array(1.1826886, dtype=float32), array(0.15651292, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 209 / 390 d1= 1.1815617 d2= 1.1838729 g= [array(1.1838729, dtype=float32), array(1.1838729, dtype=float32), array(0.15654904, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 210 / 390 d1= 1.1827477 d2= 1.1849868 g= [array(1.1849868, dtype=float32), array(1.1849868, dtype=float32), array(0.15658481, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 211 / 390 d1= 1.1838938 d2= 1.1861566 g= [array(1.1861566, dtype=float32), array(1.1861566, dtype=float32), array(0.1563981, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 212 / 390 d1= 1.1850494 d2= 1.1872727 g= [array(1.1872727, dtype=float32), array(1.1872727, dtype=float32), array(0.1564711, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 213 / 390 d1= 1.1861448 d2= 1.1883601 g= [array(1.1883601, dtype=float32), array(1.1883601, dtype=float32), array(0.15669014, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 214 / 390 d1= 1.1872416 d2= 1.1894432 g= [array(1.1894432, dtype=float32), array(1.1894432, dtype=float32), array(0.15668808, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 215 / 390 d1= 1.1883264 d2= 1.1905612 g= [array(1.1905612, dtype=float32), array(1.1905612, dtype=float32), array(0.15686773, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 216 / 390 d1= 1.1894609 d2= 1.1916728 g= [array(1.1916728, dtype=float32), array(1.1916728, dtype=float32), array(0.15679254, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 217 / 390 d1= 1.1905574 d2= 1.192768 g= [array(1.192768, dtype=float32), array(1.192768, dtype=float32), array(0.15697004, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 218 / 390 d1= 1.1916764 d2= 1.1938212 g= [array(1.1938212, dtype=float32), array(1.1938212, dtype=float32), array(0.15700258, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 219 / 390 d1= 1.1927276 d2= 1.194985 g= [array(1.194985, dtype=float32), array(1.194985, dtype=float32), array(0.15703481, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 220 / 390 d1= 1.1938896 d2= 1.1961224 g= [array(1.1961224, dtype=float32), array(1.1961224, dtype=float32), array(0.15685369, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 221 / 390 d1= 1.195034 d2= 1.1972642 g= [array(1.1972642, dtype=float32), array(1.1972642, dtype=float32), array(0.15685096, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 222 / 390 d1= 1.1961708 d2= 1.1983918 g= [array(1.1983918, dtype=float32), array(1.1983918, dtype=float32), array(0.1567075, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 223 / 390 d1= 1.1973069 d2= 1.1994481 g= [array(1.1994481, dtype=float32), array(1.1994481, dtype=float32), array(0.15670544, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 224 / 390 d1= 1.1983467 d2= 1.2005149 g= [array(1.2005149, dtype=float32), array(1.2005149, dtype=float32), array(0.15694754, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 225 / 390 d1= 1.1994407 d2= 1.2016647 g= [array(1.2016647, dtype=float32), array(1.2016647, dtype=float32), array(0.15677084, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 226 / 390 d1= 1.2006183 d2= 1.2028068 g= [array(1.2028068, dtype=float32), array(1.2028068, dtype=float32), array(0.15631914, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 227 / 390 d1= 1.2017354 d2= 1.2039183 g= [array(1.2039183, dtype=float32), array(1.2039183, dtype=float32), array(0.15621558, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 228 / 390 d1= 1.2028258 d2= 1.2049285 g= [array(1.2049285, dtype=float32), array(1.2049285, dtype=float32), array(0.15645559, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 229 / 390 d1= 1.2038611 d2= 1.2059278 g= [array(1.2059278, dtype=float32), array(1.2059278, dtype=float32), array(0.15635234, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 230 / 390 d1= 1.2048604 d2= 1.2070204 g= [array(1.2070204, dtype=float32), array(1.2070204, dtype=float32), array(0.1564538, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 231 / 390 d1= 1.2059773 d2= 1.2081176 g= [array(1.2081176, dtype=float32), array(1.2081176, dtype=float32), array(0.15631764, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 232 / 390 d1= 1.207055 d2= 1.2091206 g= [array(1.2091206, dtype=float32), array(1.2091206, dtype=float32), array(0.15641837, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 233 / 390 d1= 1.2080504 d2= 1.2101337 g= [array(1.2101337, dtype=float32), array(1.2101337, dtype=float32), array(0.15655176, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 234 / 390 d1= 1.2090755 d2= 1.211197 g= [array(1.211197, dtype=float32), array(1.211197, dtype=float32), array(0.15651709, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 235 / 390 d1= 1.2101579 d2= 1.2122169 g= [array(1.2122169, dtype=float32), array(1.2122169, dtype=float32), array(0.15641622, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 236 / 390 d1= 1.211152 d2= 1.213203 g= [array(1.213203, dtype=float32), array(1.213203, dtype=float32), array(0.15648173, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 1 Batch= 237 / 390 d1= 1.2121569 d2= 1.2142384 g= [array(1.2142384, dtype=float32), array(1.2142384, dtype=float32), array(0.1565137, dtype=float32)]
# ...
# Epoch= 6 Batch= 309 / 390 d1= 1.6250627 d2= 1.6253164 g= [array(1.6253164, dtype=float32), array(1.6253164, dtype=float32), array(0.15373576, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 310 / 390 d1= 1.6251134 d2= 1.6253622 g= [array(1.6253622, dtype=float32), array(1.6253622, dtype=float32), array(0.15373686, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 311 / 390 d1= 1.6251597 d2= 1.6254119 g= [array(1.6254119, dtype=float32), array(1.6254119, dtype=float32), array(0.15375525, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 312 / 390 d1= 1.6252098 d2= 1.6254596 g= [array(1.6254596, dtype=float32), array(1.6254596, dtype=float32), array(0.15377362, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 313 / 390 d1= 1.6252575 d2= 1.6255124 g= [array(1.6255124, dtype=float32), array(1.6255124, dtype=float32), array(0.15379198, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 314 / 390 d1= 1.6253114 d2= 1.6255628 g= [array(1.6255628, dtype=float32), array(1.6255628, dtype=float32), array(0.15377927, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 315 / 390 d1= 1.6253614 d2= 1.625616 g= [array(1.625616, dtype=float32), array(1.625616, dtype=float32), array(0.15377, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 316 / 390 d1= 1.6254159 d2= 1.6256756 g= [array(1.6256756, dtype=float32), array(1.6256756, dtype=float32), array(0.1537711, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 317 / 390 d1= 1.6254734 d2= 1.6257277 g= [array(1.6257277, dtype=float32), array(1.6257277, dtype=float32), array(0.15377909, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 318 / 390 d1= 1.6255275 d2= 1.6257828 g= [array(1.6257828, dtype=float32), array(1.6257828, dtype=float32), array(0.15377674, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 319 / 390 d1= 1.6255811 d2= 1.6258302 g= [array(1.6258302, dtype=float32), array(1.6258302, dtype=float32), array(0.1537847, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 320 / 390 d1= 1.6256284 d2= 1.6258883 g= [array(1.6258883, dtype=float32), array(1.6258883, dtype=float32), array(0.15379612, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 321 / 390 d1= 1.6256869 d2= 1.6259415 g= [array(1.6259415, dtype=float32), array(1.6259415, dtype=float32), array(0.15381096, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 322 / 390 d1= 1.6257389 d2= 1.625992 g= [array(1.625992, dtype=float32), array(1.625992, dtype=float32), array(0.1538086, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 323 / 390 d1= 1.6257923 d2= 1.6260425 g= [array(1.6260425, dtype=float32), array(1.6260425, dtype=float32), array(0.15380967, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 324 / 390 d1= 1.6258407 d2= 1.6260978 g= [array(1.6260978, dtype=float32), array(1.6260978, dtype=float32), array(0.15381761, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 325 / 390 d1= 1.6258972 d2= 1.626147 g= [array(1.626147, dtype=float32), array(1.626147, dtype=float32), array(0.15381868, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 326 / 390 d1= 1.6259463 d2= 1.6262031 g= [array(1.6262031, dtype=float32), array(1.6262031, dtype=float32), array(0.15381631, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 327 / 390 d1= 1.6260017 d2= 1.6262529 g= [array(1.6262529, dtype=float32), array(1.6262529, dtype=float32), array(0.15381396, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 328 / 390 d1= 1.6260537 d2= 1.6263014 g= [array(1.6263014, dtype=float32), array(1.6263014, dtype=float32), array(0.15381846, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 329 / 390 d1= 1.6261021 d2= 1.6263579 g= [array(1.6263579, dtype=float32), array(1.6263579, dtype=float32), array(0.15380923, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 330 / 390 d1= 1.6261563 d2= 1.626409 g= [array(1.626409, dtype=float32), array(1.626409, dtype=float32), array(0.15383087, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 331 / 390 d1= 1.6262106 d2= 1.6264637 g= [array(1.6264637, dtype=float32), array(1.6264637, dtype=float32), array(0.1538422, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 332 / 390 d1= 1.6262647 d2= 1.6265134 g= [array(1.6265134, dtype=float32), array(1.6265134, dtype=float32), array(0.1538193, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 333 / 390 d1= 1.6263125 d2= 1.6265684 g= [array(1.6265684, dtype=float32), array(1.6265684, dtype=float32), array(0.15381694, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 334 / 390 d1= 1.62637 d2= 1.6266221 g= [array(1.6266221, dtype=float32), array(1.6266221, dtype=float32), array(0.153818, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 335 / 390 d1= 1.6264229 d2= 1.6266738 g= [array(1.6266738, dtype=float32), array(1.6266738, dtype=float32), array(0.15381223, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 336 / 390 d1= 1.6264741 d2= 1.6267232 g= [array(1.6267232, dtype=float32), array(1.6267232, dtype=float32), array(0.15380646, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 337 / 390 d1= 1.6265247 d2= 1.6267738 g= [array(1.6267738, dtype=float32), array(1.6267738, dtype=float32), array(0.15381095, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 338 / 390 d1= 1.6265744 d2= 1.6268225 g= [array(1.6268225, dtype=float32), array(1.6268225, dtype=float32), array(0.1538086, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 339 / 390 d1= 1.6266227 d2= 1.6268772 g= [array(1.6268772, dtype=float32), array(1.6268772, dtype=float32), array(0.15381308, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 340 / 390 d1= 1.6266778 d2= 1.6269269 g= [array(1.6269269, dtype=float32), array(1.6269269, dtype=float32), array(0.15380731, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 341 / 390 d1= 1.6267271 d2= 1.6269779 g= [array(1.6269779, dtype=float32), array(1.6269779, dtype=float32), array(0.1538118, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 342 / 390 d1= 1.6267786 d2= 1.6270266 g= [array(1.6270266, dtype=float32), array(1.6270266, dtype=float32), array(0.15380603, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 343 / 390 d1= 1.6268293 d2= 1.6270834 g= [array(1.6270834, dtype=float32), array(1.6270834, dtype=float32), array(0.1538003, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 344 / 390 d1= 1.626883 d2= 1.6271315 g= [array(1.6271315, dtype=float32), array(1.6271315, dtype=float32), array(0.15381157, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 345 / 390 d1= 1.6269349 d2= 1.6271853 g= [array(1.6271853, dtype=float32), array(1.6271853, dtype=float32), array(0.15379901, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 346 / 390 d1= 1.626985 d2= 1.6272438 g= [array(1.6272438, dtype=float32), array(1.6272438, dtype=float32), array(0.1538205, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 347 / 390 d1= 1.6270478 d2= 1.627302 g= [array(1.627302, dtype=float32), array(1.627302, dtype=float32), array(0.15380795, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 348 / 390 d1= 1.6271024 d2= 1.6273596 g= [array(1.6273596, dtype=float32), array(1.6273596, dtype=float32), array(0.15381922, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 349 / 390 d1= 1.6271602 d2= 1.6274168 g= [array(1.6274168, dtype=float32), array(1.6274168, dtype=float32), array(0.15382707, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 350 / 390 d1= 1.6272174 d2= 1.6274654 g= [array(1.6274654, dtype=float32), array(1.6274654, dtype=float32), array(0.15381794, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 351 / 390 d1= 1.6272676 d2= 1.6275158 g= [array(1.6275158, dtype=float32), array(1.6275158, dtype=float32), array(0.1538088, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 352 / 390 d1= 1.6273192 d2= 1.6275706 g= [array(1.6275706, dtype=float32), array(1.6275706, dtype=float32), array(0.1537895, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 353 / 390 d1= 1.6273714 d2= 1.6276195 g= [array(1.6276195, dtype=float32), array(1.6276195, dtype=float32), array(0.15380076, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 354 / 390 d1= 1.6274197 d2= 1.6276767 g= [array(1.6276767, dtype=float32), array(1.6276767, dtype=float32), array(0.15382215, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 355 / 390 d1= 1.6274792 d2= 1.627724 g= [array(1.627724, dtype=float32), array(1.627724, dtype=float32), array(0.15381643, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 356 / 390 d1= 1.6275235 d2= 1.6277745 g= [array(1.6277745, dtype=float32), array(1.6277745, dtype=float32), array(0.15383443, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 357 / 390 d1= 1.6275764 d2= 1.6278224 g= [array(1.6278224, dtype=float32), array(1.6278224, dtype=float32), array(0.15383886, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 358 / 390 d1= 1.6276263 d2= 1.6278726 g= [array(1.6278726, dtype=float32), array(1.6278726, dtype=float32), array(0.15382637, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 359 / 390 d1= 1.6276778 d2= 1.6279317 g= [array(1.6279317, dtype=float32), array(1.6279317, dtype=float32), array(0.15381388, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 360 / 390 d1= 1.6277338 d2= 1.627988 g= [array(1.627988, dtype=float32), array(1.627988, dtype=float32), array(0.15381832, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 361 / 390 d1= 1.6277918 d2= 1.6280365 g= [array(1.6280365, dtype=float32), array(1.6280365, dtype=float32), array(0.15381937, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 362 / 390 d1= 1.627841 d2= 1.6280919 g= [array(1.6280919, dtype=float32), array(1.6280919, dtype=float32), array(0.15382043, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 363 / 390 d1= 1.6278951 d2= 1.6281431 g= [array(1.6281431, dtype=float32), array(1.6281431, dtype=float32), array(0.15381472, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 364 / 390 d1= 1.6279485 d2= 1.6281959 g= [array(1.6281959, dtype=float32), array(1.6281959, dtype=float32), array(0.15379551, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 365 / 390 d1= 1.6279973 d2= 1.6282471 g= [array(1.6282471, dtype=float32), array(1.6282471, dtype=float32), array(0.15380332, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 366 / 390 d1= 1.6280497 d2= 1.6283022 g= [array(1.6283022, dtype=float32), array(1.6283022, dtype=float32), array(0.15379426, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 367 / 390 d1= 1.6281056 d2= 1.628355 g= [array(1.628355, dtype=float32), array(1.628355, dtype=float32), array(0.15377846, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 368 / 390 d1= 1.6281585 d2= 1.6284091 g= [array(1.6284091, dtype=float32), array(1.6284091, dtype=float32), array(0.15377279, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 369 / 390 d1= 1.6282133 d2= 1.628463 g= [array(1.628463, dtype=float32), array(1.628463, dtype=float32), array(0.15375027, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 370 / 390 d1= 1.628266 d2= 1.6285172 g= [array(1.6285172, dtype=float32), array(1.6285172, dtype=float32), array(0.15374124, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 371 / 390 d1= 1.6283206 d2= 1.6285692 g= [array(1.6285692, dtype=float32), array(1.6285692, dtype=float32), array(0.15373896, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 372 / 390 d1= 1.6283715 d2= 1.6286206 g= [array(1.6286206, dtype=float32), array(1.6286206, dtype=float32), array(0.15374677, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 373 / 390 d1= 1.6284252 d2= 1.6286803 g= [array(1.6286803, dtype=float32), array(1.6286803, dtype=float32), array(0.1537344, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 374 / 390 d1= 1.6284841 d2= 1.6287344 g= [array(1.6287344, dtype=float32), array(1.6287344, dtype=float32), array(0.15373884, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 375 / 390 d1= 1.6285372 d2= 1.6287893 g= [array(1.6287893, dtype=float32), array(1.6287893, dtype=float32), array(0.15375672, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 376 / 390 d1= 1.628591 d2= 1.628843 g= [array(1.628843, dtype=float32), array(1.628843, dtype=float32), array(0.15377122, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 377 / 390 d1= 1.6286464 d2= 1.6288866 g= [array(1.6288866, dtype=float32), array(1.6288866, dtype=float32), array(0.15378237, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 378 / 390 d1= 1.6286898 d2= 1.6289332 g= [array(1.6289332, dtype=float32), array(1.6289332, dtype=float32), array(0.1537935, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 379 / 390 d1= 1.6287378 d2= 1.6289884 g= [array(1.6289884, dtype=float32), array(1.6289884, dtype=float32), array(0.15379454, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 380 / 390 d1= 1.6287957 d2= 1.6290452 g= [array(1.6290452, dtype=float32), array(1.6290452, dtype=float32), array(0.15377213, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 381 / 390 d1= 1.6288527 d2= 1.6291002 g= [array(1.6291002, dtype=float32), array(1.6291002, dtype=float32), array(0.15374638, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 382 / 390 d1= 1.6289041 d2= 1.6291559 g= [array(1.6291559, dtype=float32), array(1.6291559, dtype=float32), array(0.1537441, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 383 / 390 d1= 1.6289599 d2= 1.6292111 g= [array(1.6292111, dtype=float32), array(1.6292111, dtype=float32), array(0.15373178, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 384 / 390 d1= 1.6290153 d2= 1.6292639 g= [array(1.6292639, dtype=float32), array(1.6292639, dtype=float32), array(0.15373956, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 385 / 390 d1= 1.6290661 d2= 1.6293093 g= [array(1.6293093, dtype=float32), array(1.6293093, dtype=float32), array(0.15374732, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 386 / 390 d1= 1.6291122 d2= 1.6293551 g= [array(1.6293551, dtype=float32), array(1.6293551, dtype=float32), array(0.15377516, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 387 / 390 d1= 1.6291578 d2= 1.6294 g= [array(1.6294, dtype=float32), array(1.6294, dtype=float32), array(0.15377621, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 388 / 390 d1= 1.6292042 d2= 1.6294451 g= [array(1.6294451, dtype=float32), array(1.6294451, dtype=float32), array(0.15377392, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 389 / 390 d1= 1.6292483 d2= 1.6294992 g= [array(1.6294992, dtype=float32), array(1.6294992, dtype=float32), array(0.153785, dtype=float32)]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch= 6 Batch= 390 / 390 d1= 1.6293043 d2= 1.629548 g= [array(1.629548, dtype=float32), array(1.629548, dtype=float32), array(0.15378273, dtype=float32)]

# %%
from tensorflow.keras.models import load_model

# Now, load the generator model and generate images

# Plot generated images function
def show_plot(examples, n):
    for i in range(n * n):
        plt.subplot(n, n, 1 + i)
        plt.axis('off')
        plt.imshow(examples[i, :, :, :])
    plt.show()

# load model
model = load_model(model_filename) #Model trained for n epochs

# generate the latent vector
latent_points = generate_latent_points(150, 25)  #Latent dim and n_samples

# generate images from the latent vector
X = model.predict(latent_points)

# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
X = (X*255).astype(np.uint8)

# plot the generated images
# Note: CIFAR10 classes are: airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck
show_plot(X, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step

# %% [markdown]
# # Observations
#
# Training the GAN with a higher dimension of the latent space and over more epochs does improve the quality of the generated images, as a higher-dimensional latent space can encode more complex variations and nuanced features. And training over more epochs gives the GAN more opportunities to refine its outputs and learn from the feedback of the discriminator.
#
# # What could be done to further improve the quality of the generated output?
#
# 1. Data Augmentation
# By flipping, rotation or color jittering the diversity of the training data could be enhanced, to reduce overfitting. Though if the training data is already relatively diverse, the effect might be marginal.
#
# 2. Adjust the batch size
# Smaller batches could provide more gradient noise which might help with generalization and prevents overfitting.
#
# (Information from https://github.com/soumith/ganhacks)
#
# 3. Noisy Labels
# Label smoothing replaces exact values (1 for real and 0 for fake) with small random variations (e.g. 0.7–1.2 for real and 0.0–0.3 for fake). Occasionally flipping the labels (marking real images as fake and vice versa) adds unpredictability. These techniques prevent the discriminator from becoming overconfident, encouraging the generator to produce more realistic outputs by ensuring a balanced adversarial game.
#
# 4. Hybrid Models
# A VAE+GAN hybrid combines the latent space regularization of VAEs (because of the structured latent space where similar inputs are mapped to nearby points) with the adversarial training of GANs, resulting in more stable training and higher-quality outputs. One could also incorporate a Kullback-Leibler divergence to measure how closely the generated distribution matches the target
